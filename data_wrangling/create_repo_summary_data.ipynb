# %% [markdown]
# # Exploratory Data Analysis - GitHub repo's issues

# %%
import json
import numpy as np
import pandas as pd
import datetime


import warnings
warnings.filterwarnings('ignore')

# # Suppress pandas's warning
# warnings.simplefilter(action='ignore', category=Warning)

## https://stackoverflow.com/questions/20625582/how-to-deal-with-settingwithcopywarning-in-pandas
# pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ## Data requirements

# %% [markdown]
# Below is a list of interested data that we will use in the initial analysis
# * How long the issues open
# * First comment response time
# * Number of comments
# * Number of participants
# * Labels associated with each issue
# * Milestone

# %% [markdown]
# Later will be done in the later part - Find data for each year where
# * Top words in question
# * Top words in answers
# * Top participants + Type and company

# %% [markdown]
# ## Cleaning data - High-level data
#
# * Extract only interested columns which are
# [
# 'issue_id',
# 'title',
# 'contents',
# 'authorLogin',
# 'authorAssociation',
# 'createdAt',
# 'closedAt',
# 'closed',
# 'comments_count',
# 'comments_data',
# 'participants_count',
# 'labels',
# 'milestone'
# ]
#
# * Cast datetime columns to ['createdAt', 'closedAt'] datetime
# * Create a new column 'closedDuration_days' to store a timediff between the columns ['closedAt', 'createdAt'] in days
# * Additional columns for comments data
#   * Create a new column 'firstCommentCreatedAt' to store a datetime object the first comment is created
#   * Create a new column 'firstCommentDuration_days' to store a timediff between the columns 'createdAt' and the creation time of the first comment in days
#   * New columns for the first comment author info ['firstCommentAuthor', 'firstCommentAuthorAssociation']
#   * New columns for total number of unique comment authors based on authorAssociation ['num_unique_comment_author_MEMBER', 'num_unique_comment_author_CONTRIBUTOR', 'num_unique_comment_author_COLLABORATOR', 'num_unique_comment_author_NONE']
# * Extract 'milestone' title and replace the 'milestone' column with this value
# * Perform one-hot encoding to the label column

# %%
def get_comment_info_columns(row):
    '''
    Function to extract data from a dataframe's row that will be used in the function 'create_highlevel_df'
    
    Input argument:
        row: A row of data frame containing github issue info
        
    Output argument:
        a list containing the following information
            [
                'firstCommentCreatedAt', 
                'firstCommentAuthor', 
                'firstCommentAuthorAssociation',
                'num_unique_comment_author_MEMBER',
                'num_unique_comment_author_CONTRIBUTOR',
                'num_unique_comment_author_COLLABORATOR',
                'num_unique_comment_author_NONE'
            ]
        
    '''
    
    # If the comments_count is greater than 0
    if row['comments_count'] > 0:
        
        # --- Extract data for 'firstCommentCreatedAt', 'firstCommentAuthor', 'firstCommentAuthorAssociation'
        
        out = [
            row['comments_data'][0]['createdAt'],
            row['comments_data'][0]['authorLogin'], 
            row['comments_data'][0]['authorAssociation']
        ]
        
        # --- Extract data for 'num_unique_comment_*'
        # We need to extract data from the 'comments_data' column
        
        # Get a list of all comment authors first
        list_comment_authors = []
        for cur_comment in row['comments_data']:
            cur_author = {
                'login': cur_comment['authorLogin'],
                'association': cur_comment['authorAssociation']
            }
            list_comment_authors.append(cur_author)
            
        unique_comment_authors = [dict(y) for y in set(tuple(x.items()) for x in list_comment_authors)]
        
        # Then, get count for each type
        dict_author_assoc = {
            'MEMBER': 0,
            'CONTRIBUTOR': 0,
            'COLLABORATOR': 0,
            'NONE': 0
        }
        
        for cur_comment_author in unique_comment_authors:
            cur_assoc = cur_comment_author['association']
            dict_author_assoc[cur_assoc] += 1
            
        # Append data to the output list
        out = out + [
            dict_author_assoc['MEMBER'],
            dict_author_assoc['CONTRIBUTOR'],
            dict_author_assoc['COLLABORATOR'],
            dict_author_assoc['NONE']
        ]
    else:
        # Otherwise, output a default output list
        out = [None, None, None, 0, 0, 0, 0]

        
    return out

# %%
def create_highlevel_df(json_path):
    '''
    Extract github issues data from the specified path and output an extracted summary data as a new dataframe
    '''
    
    # Load json data and create dataframe
    with open(json_path) as json_file:  
        data_raw = json.load(json_file)

    df_raw = pd.DataFrame.from_dict(data_raw)
    
    # Let's get only columns that we need for the analysis now
    new_cols = [
        'issue_id',
        'title',
        'contents',
        'authorLogin',
        'authorAssociation',
        'createdAt',
        'closedAt',
        'closed',
        'comments_count',
        'participants_count',
        'comments_data',
        'labels',
        'milestone'
     ]
    
    df_out = df_raw[new_cols]
    
    # --- Cast columns to datetime
    df_out[['createdAt', 'closedAt']] = df_out[['createdAt', 'closedAt']].apply(pd.to_datetime)
    
    # --- Find closedDuration_days
    get_diff_days = lambda s: (s.dt.total_seconds() / (24 * 60 * 60)).round(2)
#     df_out['closedDuration_days'] = ((df_out['closedAt'] - df_out['createdAt']).dt.total_seconds() / (24 * 60 * 60)).round(2)
    df_out['closedDuration_days'] = get_diff_days(df_out['closedAt'] - df_out['createdAt'])

    # --- Find comment info
    cols_first_comments = [
        'firstCommentCreatedAt', 
        'firstCommentAuthor', 
        'firstCommentAuthorAssociation',
        'num_unique_comment_author_MEMBER',
        'num_unique_comment_author_CONTRIBUTOR',
        'num_unique_comment_author_COLLABORATOR',
        'num_unique_comment_author_NONE'
    ]
    df_out[cols_first_comments] = pd.DataFrame(
                    df_out.apply(lambda row: get_comment_info_columns(row), axis=1).values.tolist(), 
                     index= df_out.index)

    df_out['firstCommentCreatedAt'] = pd.to_datetime(df_out['firstCommentCreatedAt'])
    df_out['firstCommentDuration_days'] = get_diff_days(df_out['firstCommentCreatedAt'] - df_out['createdAt'])
    
    # --- Extract 'milestone' title and replace the 'milestone' colummn with this value
    df_out['milestone'] = df_out['milestone'].apply(lambda x: x['title'] if x else '')
    
    # --- Perform one hot encoding for the labels columns
    
    # Get a list of labels
    list_labels = []
    for index, row in df_out.iterrows():
        list_labels = list_labels + row['labels']

    list_labels = list(set(list_labels))
    
    # Then, create new columns for each of those labels
    
    # Create a dictionary to map those labels with a boolean value for each record in the dataset
    dict_labels = dict((el,[]) for el in list_labels)
    for index, row in df_out.iterrows():
        for cur_label in list_labels:
            cur_bool = False
            if cur_label in row['labels']:
                cur_bool = True

            dict_labels[cur_label].append(cur_bool)
    
    # Then, create a dataframe for it and merge the newly created dataframe with the current output dataframe
    df_out = pd.concat([df_out, pd.DataFrame.from_dict(dict_labels)], axis=1)
    
    # Finally, prepend those newly added label columns with 'Label_'
    dict_rename = {}
    for cur_label in list_labels:
        dict_rename[cur_label] = 'label_' + cur_label
        
    df_out = df_out.rename(columns=dict_rename)

    
    # --- Reorder columns
    final_cols = [
        'issue_id',
        'title',
        'contents',
        'authorLogin',
        'authorAssociation',
        'createdAt',
        'closed',
        'closedAt',        
        'closedDuration_days',
        'milestone',
        'participants_count',
        'comments_count',
        'firstCommentCreatedAt',
        'firstCommentDuration_days',
        'firstCommentAuthor',
        'firstCommentAuthorAssociation',
        'num_unique_comment_author_MEMBER',
        'num_unique_comment_author_CONTRIBUTOR',
        'num_unique_comment_author_COLLABORATOR',
        'num_unique_comment_author_NONE',
        'labels'
    ]
    
    # Then, append the one hot encoding's label columns
    final_cols = final_cols + ['label_' + cur_label for cur_label in list_labels]
    df_out = df_out[final_cols]
    
    return df_out

# %%
list_libs = [
    'qunit',
    'mocha',
    'jest',
    'jasmine',
    'funcunit',
    'puppeteer',
    'cypress'
]

for cur_lib in list_libs:
    print('***** [{}] START repo#{}" *****'.format(str(datetime.datetime.now()), cur_lib))
        
    json_path = '../data/github_repo_issues_{}.json'.format(cur_lib)
    df_cur = create_highlevel_df(json_path) 
    
    print('|-- Total records: ', df_cur.shape[0])
    
    # --- Save data to csv
    csv_filename = 'temp/repo_issue_summary_{}.csv'.format(cur_lib)
    print('|-- Save data to "{}"...'.format(csv_filename))
    df_cur.to_csv(csv_filename, index=False)
    
    # --- Save data to xlsx since the csv data is not read properly in Tableau due to a usage of ',' in the contents
    xlsx_filename = "temp/repo_issue_summary_{}.xlsx".format(cur_lib)
    print('|-- Save data to "{}"...'.format(xlsx_filename))
    
    writer = pd.ExcelWriter(xlsx_filename,
                engine='xlsxwriter',
                options={'remove_timezone': True})

    df_cur.to_excel(writer, index=False, sheet_name='Sheet1')

    workbook  = writer.book
    worksheet = writer.sheets['Sheet1']

    writer.save()
# Out:
# ***** [2019-07-06 13:37:14.132598] START repo#qunit" *****
# |-- Total records:  708
# |-- Save data to "temp/repo_issue_summary_qunit.csv"...
# |-- Save data to "temp/repo_issue_summary_qunit.xlsx"...
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'http://grab.by/9ojb%20http://grab.by/9ojd
# Ajax%20urls%20are%20wrapped%20in%20the%20url%20function%20in%20unit/ajax.js.%20%20Currently,%20instead%20of%20constructing%20the%20correct%20url,%20many%20of%20them%20end%20up%20as%20get%20params%20with%20each%20letter%20of%20the%20string%20a%20different%20param.%20%20You'll%20see%20in%20the%20second%20photo%20%221=d&2=a&3=b....%20because%20it's%20doing%20a%20for-each%20for%20the%20string.%20%20Perhaps%20something%20got%20broken%20during%20the%20recent%20?filter=*%20url%20changes.' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://jsfiddle.net/xcrh9n3d/
# Since%20we%20verify%20inherited%20properties%20anyway,%20we%20should%20replace%20the%20weird%20constructor-based%20%22function%22%20callback%20with%20a%20simple%20return%20false%20(relying%20solely%20on%20the%20strict%20equality%20check%20in%20innerEquiv).' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://github.com/qunitjs/qunit/blob/master/package.json' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# ***** [2019-07-06 13:37:15.272010] START repo#mocha" *****
# |-- Total records:  2356
# |-- Save data to "temp/repo_issue_summary_mocha.csv"...
# |-- Save data to "temp/repo_issue_summary_mocha.xlsx"...
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'http://stringjs.com/browser.test.html
#
# This%20works%20in%20Safari%205.1.3%20(OS%20X%2010.7.3)
# It%20fails%20in%20Chrome%2017.0.9%20(OS%20X%2010.7.3)
# Looks%20ugly%20in%20Firefox,%20but%20if%20I%20recall%20reading,%20Mocha%20only%20supports%20Webkit%20browsers.
#
# Any%20thoughts%20on%20the%20Chrome/Safari%20discrepancy?' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'http://mochajs.org/' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://github.com/thunks/thunk-mocha
# work%20at%203.1.0
# /Users/tz/Workspaces/eggjs/aliyun-egg/node_modules/.3.1.1@mocha/lib/runnable.js:52
# %20%20this.async%20=%20fn%20&&%20fn.length;
# %20%20%20%20%20%20%20%20%20%20%20%20%20%5e
#
# TypeError:%20Cannot%20set%20property%20async%20of%20' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# ***** [2019-07-06 13:37:20.002149] START repo#jest" *****
# |-- Total records:  4530
# |-- Save data to "temp/repo_issue_summary_jest.csv"...
# |-- Save data to "temp/repo_issue_summary_jest.xlsx"...
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://github.com/facebook/jest/blob/master/src/TestRunner.js' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://github.com/bingomanatee/ReactUserBoilerplate/blob/master/src/components/FormDefField/__tests__/FormDefField-test.js
# the%20error%20returned%20from%20jest%20is
#
# Error:%20Invariant%20Violation:%20The%20style-loader%20must%20be%20configured%20with%20reference-counted%20API.
# at%20invariant%20(../node_modules/fbjs/lib/invariant.js:39:15)
# at%20WithStyles.componentWillMount%20(decorators/withStyles.js:86:47)
#
# This%20is%20a%20build%20based%20on%20react-starter-kit.' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://github.com/gedkins/jest-bugs.git
# jest-bug-1
# The%20setup:
#
# We%20have%20two%20%22libraries%22%20called%20'a'%20and%20'b'.%20Each%20imports%20a%20corresponding%20%22helper%22.
# Then%20we%20run%20jest
# test.js%20will%20mock%20'a'%20and%20unmock%20'b'.%20It%20will%20later%20use%20'b',%20expecting%20to%20see%20the%20unmocked%20version%20of%20b's%20helper.
#
# What%20happens
#
# Mocking%20'a'%20will%20store%20'./helper'%20in%20Jest's%20internal%20shouldMockModuleCache.
# when%20we%20later%20come%20to%20use%20'b',%20Jest%20will%20discover%20that%20'./helper'%20is%20already%20in%20the%20shouldMockModuleCache,%20even%20though%20it%20was%20referring%20to%20a%20completely%20different%20file.
# hence%20we%20end%20up%20with%20the%20mock%20version%20of%20b/helper.js
#
# What%20you%20will%20see:
#
# If%20you%20run%20./run.sh%20you%20will%20see%20the%20test%20case%20fail.
# If%20you%20comment%20out%20the%20require('a')%20line%20in%20tests/test.js,%20you%20will%20see%20the%20test%20case%20pass.
#
# What%20I%20would%20expect%20to%20see%20in%20the%20absense%20of%20a%20bug:
#
# The%20original%20test%20case%20passes.' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://github.com/gedkins/jest-bugs.git
# jest-bug-2
# The%20setup:
#
# We%20have%20three%20libraries,%20'a',%20'b'%20and%20'c'
# 'a'%20includes%20'c'
# 'b'%20includes%20'c'
# There%20are%20two%20test%20files:%20test1.js%20and%20test2.js
# test1.js%20doesn't%20really%20do%20anything,%20but%20tells%20Jest%20to%20mock%20'a'%20and%20not%20mock%20'b'.
# test2.js%20does%20it%20the%20other%20way%20around:%20it%20tells%20Jest%20to%20unmock%20'a'%20but%20mock%20'b'.
# First%20we%20run%20test1.js%20and%20test2.js%20in%20sequence.%20Then%20in%20a%20separate%20invocation%20of%20jest,%20we%20run%20test2.js%20on%20its%20own.
#
# What%20happens:
#
# When%20we%20run%20test1.js,%20Jest%20stores%20'c'%20in%20its%20shouldMockModuleCache
# It%20does%20not%20clear%20this%20cache%20between%20test%20runs
# When%20we%20run%20test2.js,%20Jest%20discovers%20'c'%20in%20its%20shoulMockModuleCache%20and%20assumes%20that%20we%20want%20it%20mocked
#
# What%20you%20will%20see:
# When%20you%20run%20./run.sh%20you%20will%20see%20something%20like%20this:
# Using%20Jest%20CLI%20v11.0.0,%20jasmine2
# PASS%20%20__tests__/test1.js%20(1.017s)
# FAIL%20%20__tests__/test2.js%20(0.015s)
# Using%20Jest%20CLI%20v11.0.0,%20jasmine2
# PASS%20%20__tests__/test2.js%20(0.016s)
#
# Note%20that%20if%20for%20some%20reason%20Jest%20decides%20to%20run%20the%20files%20in%20a%20different%20order,%20you%20will%20not%20see%20the%20failure.%20I%20couldn't%20see%20a%20way%20to%20explictly%20specify%20an%20order,%20so%20I%20put%20in%20a%20kludge%20to%20make%20sure%20it%20happens%20in%20the%20order%20that%20I%20want.
# What%20I%20would%20expect%20to%20see%20in%20the%20absense%20of%20a%20bug:
#
# test2.js%20will%20always%20behave%20the%20same%20way,%20regardless%20of%20what%20other%20tests%20are%20run%20beforehand.' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://travis-ci.org/grommet/grommet/builds/156392643' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'http://stackoverflow.com/questions/43137058/jest-with-react-native-getting-issue
# (%7b%22Object.%22:function(module,exports,require,__dirname,__filename,global,jest)%7bimport%20React,%20%7b%20Component,%20Children,%20PropTypes%20%7d%20from%20'react';
# %5e%5e%5e%5e%5e%5e
# SyntaxError:%20Unexpected%20token%20import
# %20%20at%20transformAndBuildScript%20(node_modules/jest-runtime/build/transform.js:320:12)
# %20%20at%20Object.%3canonymous%3e%20(node_modules/react-native-root-siblings/lib/AppRegistryInjection.js:3:22)
# %20%20at%20Object.%3canonymous%3e%20(node_modules/react-native-root-siblings/lib/SiblingsManager.js:3:27)' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'http://facebook.github.io/jest/docs/en/troubleshooting.html
# this%20instructs%20to%20use%20the%20node-inspector,%20but%20that%20is%20no%20longer%20the%20way%20to%20debug
# https://nodejs.org/en/docs/inspector/
# please%20update%20the%20documentation,%20thank%20you' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://github.com/babel/babel/tree/master/packages/babel-core
# If%20I%20use%20jest%20(21.2.1)%20with%20@babel/core%20(7.0.0-beta.31)%20I%20get%20this%20error:
# %20FAIL%20%20src\index.test.jsx
# %20%20●%20Test%20suite%20failed%20to%20run
#
# %20%20%20%20Couldn't%20find%20preset%20%22@babel/env%22%20relative%20to%20directory%20%22frontend%22
# %20%20%20%20%20%20
# %20%20%20%20%20%20at%20node_modules/babel-core/lib/transformation/file/options/option-manager.js:293:19
# %20%20%20%20%20%20at%20Array.map%20(native)
# %20%20%20%20%20%20at%20OptionManager.resolvePresets%20(node_modules/babel-core/lib/transformation/file/options/option-manager.js:275:20)
# %20%20%20%20%20%20at%20OptionManager.mergePresets%20(node_modules/babel-core/lib/transformation/file/options/option-manager.js:264:10)
# %20%20%20%20%20%20at%20OptionManager.mergeOptions%20(node_modules/babel-core/lib/transformation/file/options/option-manager.js:249:14)
# %20%20%20%20%20%20at%20OptionManager.init%20(node_modules/babel-core/lib/transformation/file/options/option-manager.js:368:12)
# %20%20%20%20%20%20at%20File.initOptions%20(node_modules/babel-core/lib/transformation/file/index.js:212:65)
# %20%20%20%20%20%20at%20new%20File%20(node_modules/babel-core/lib/transformation/file/index.js:135:24)
# %20%20%20%20%20%20at%20Pipeline.transform%20(node_modules/babel-core/lib/transformation/pipeline.js:46:16)
#
# Test%20Suites:%201%20failed,%201%20total
# Tests:%20%20%20%20%20%20%200%20total
# Snapshots:%20%20%200%20total
# Time:%20%20%20%20%20%20%20%202.085s
# Ran%20all%20test%20suites.
# npm%20ERR!%20Test%20failed.%20%20See%20above%20for%20more%20details.
#
# If%20I%20use%20jest@test%20I%20get%20this%20error:
# %20FAIL%20%20src\index.test.jsx
# %20%20●%20Test%20suite%20failed%20to%20run
#
# %20%20%20%20Cannot%20find%20module%20'babel-core'
# %20%20%20%20%20%20
# %20%20%20%20%20%20at%20_load_babelCore%20(node_modules/babel-jest/build/index.js:17:49)
#
# Test%20Suites:%201%20failed,%201%20total
# Tests:%20%20%20%20%20%20%200%20total
# Snapshots:%20%20%200%20total
# Time:%20%20%20%20%20%20%20%202.134s
# Ran%20all%20test%20suites.
# npm%20ERR!%20Test%20failed.%20%20See%20above%20for%20more%20details.
#
# Process%20finished%20with%20exit%20code%201' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://github.com/facebook/jest
# https://github.com/facebook/jest/tree/master/packages/jest-resolve
# https://github.com/facebook/jest/blob/master/packages/jest-resolve/src/node_modules_paths.js
#
# error:
#
# absolute%20paths%20in%20moduleDirectories%20are%20invalid%20in%20Windows%20OS
# results%20in%20CommonJS%20modules%20not%20being%20found
# import%20statements%20throw%20an%20Error
# all%20tests%20fail
#
#
# evidence:
# file:
# packages/jest-resolve/src/node_modules_paths.js
# line:%2054
# insert%20code:
# console.log('dirs:',%20JSON.stringify(dirs,%20null,%202))
#
# patch%20v1:
# file:
# packages/jest-resolve/src/node_modules_paths.js
# line:%2050
# original%20code:
# return%20path.join(prefix,%20aPath,%20moduleDir);
# modified%20code:
# return%20path.isAbsolute(moduleDir)%20?%20moduleDir%20:%20path.join(prefix,%20aPath,%20moduleDir);
# effects:
#
# dirs.length%20will%20not%20change
# dirs%20will%20contain%20paths.length%20duplicates%20of%20each%20absolute%20path%20in%20modules
# absolute%20paths%20will%20be%20valid
# absolute%20paths%20for%20Windows%20OS%20will%20no-longer%20be%20broken
#
#
# patch%20v2:
# file:
# packages/jest-resolve/src/node_modules_paths.js
# lines:%2047%20-%2053
# original%20code:
# %20%20const%20dirs%20=%20paths.reduce((dirs,%20aPath)%20=%3e%20%7b
# %20%20%20%20return%20dirs.concat(
# %20%20%20%20%20%20modules.map(moduleDir%20=%3e%20%7b
# %20%20%20%20%20%20%20%20return%20path.join(prefix,%20aPath,%20moduleDir);
# %20%20%20%20%20%20%7d),
# %20%20%20%20);
# %20%20%7d,%20%5b%5d);
# modified%20code:
# %20%20const%20dirs%20=%20paths
# %20%20%20%20.reduce((dirs,%20aPath)%20=%3e%20%7b
# %20%20%20%20%20%20return%20dirs.concat(
# %20%20%20%20%20%20%20%20modules.map(moduleDir%20=%3e%20%7b
# %20%20%20%20%20%20%20%20%20%20return%20path.isAbsolute(moduleDir)%20?%20((aPath%20===%20basedirAbs)%20?%20moduleDir%20:%20null)%20:%20path.join(prefix,%20aPath,%20moduleDir);
# %20%20%20%20%20%20%20%20%7d),
# %20%20%20%20%20%20);
# %20%20%20%20%7d,%20%5b%5d)
# %20%20%20%20.filter(dir%20=%3e%20(dir%20!==%20null))
# %20%20;
# effects:
#
# each%20absolute%20path%20in%20modules%20is%20only%20returned%20for%20a%20particular%20iteration%20of%20paths.reduce()
# other%20iterations%20inject%20a%20null%20value
# dirs%20is%20then%20filtered%20to%20remove%20these%20null%20values
# dirs.length%20will%20be%20reduced,%20which%20could%20slightly%20boost%20performance
# absolute%20paths%20will%20be%20valid
# absolute%20paths%20for%20Windows%20OS%20will%20no-longer%20be%20broken' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://facebook.github.io/jest/docs/en/puppeteer.html%20shows%20how%20to%20run%20a%20custom%20config%20using%20Puppeteer,%20but%20beginner-level%20Jest%20users%20would%20probably%20have%20a%20much%20better%20time%20with%20https://github.com/smooth-code/jest-puppeteer/'s%20preset.%20Is%20there%20a%20reason%20the%20page%20doesn't%20mention%20jest-puppeteer?
# If%20not,%20I%20can%20add%20it%20in!' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://stackoverflow.com/questions/54558802/jest-has-detected-open-handle-keeping-jest-from-exiting-in-gitlab-ci
# here%20is%20all%20the%20info%20stored.%20it%20looks%20like%20this%20is%20an%20jest%20bug.%20but%20i%20can't%20give%20you%20any%20protocol%20because%20it%20only%20appeares%20in%20gitlab-ci.' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://stackoverflow.com/questions/55619495/random-jest-test-failures-with-error-cannot-read-property-of-undefined
# I%20have%20raised%20the%20same%20question%20on%20stack%20overflow%20but%20exposing%20it%20here%20in%20case%20anyone%20can%20suggest%20something.
# ' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# ***** [2019-07-06 13:37:28.377727] START repo#jasmine" *****
# |-- Total records:  1198
# |-- Save data to "temp/repo_issue_summary_jasmine.csv"...
# |-- Save data to "temp/repo_issue_summary_jasmine.xlsx"...
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'http://stackoverflow.com/questions/15893168/why-in-jasmine-we-cannot-put-the-expect-in-an-outside-function
# If%20using%20Jasmine%201.3.1,%20I%20use
# describe(%22TryTry%22,%20function()%20%7b
#
# %20%20%20%20var%20i;
#
# %20%20%20%20function%20checkForSituation(a)%20%7b
# %20%20%20%20%20%20%20%20//%20say,%20if%20this%20is%20made%20into%20a%20function%20because%20
# %20%20%20%20%20%20%20%20//%20%20%20there%20are%20a%20lot%20of%20processing
#
# %20%20%20%20%20%20%20%20console.log(%22THERE%22,%20a);%20
# %20%20%20%20%20%20%20%20expect(foo(3,%20a)).toEqual(%203%20+%20a%20);
# %20%20%20%20%7d
#
# %20%20%20%20for%20(i%20=%200;%20i%20%3c%205;%20i++)%20%7b
# %20%20%20%20%20%20%20%20console.log(%22HERE%22,%20i);%20
#
# %20%20%20%20%20%20%20%20it(%22should%20add%20for%20%22%20+%20i,%20function()%20%7b
#
# %20%20%20%20%20%20%20%20%20%20%20%20checkForSituation(i);
#
# %20%20%20%20%20%20%20%20%7d);
#
# %20%20%20%20%7d
#
# %7d);
#
# and%20foo%20is%20just:
# function%20foo(a,%20b)%20%7b
# %20%20%20%20return%20a%20+%20b;
# %7d
#
# I%20would%20expect%20it%20to%20check%20for%200%20to%204,%20and%20print%20out
# HERE%200
# THERE%200
# HERE%201
# THERE%201
# %20%20...
#
# but%20instead,%20it%20just%20print%20in%20Chrome's%20console%20as:%20HERE%200,%20HERE%201,%20...%20and%20then%20THERE%205%20five%20times.%20%20Does%20somebody%20know%20why%20an%20expect%20cannot%20be%20put%20in%20an%20outside%20function%20like%20that%20and%20what%20to%20do%20in%20Jasmine%20if%20I%20need%20to%20put%20many%20steps%20into%20a%20function?
# As%20a%20side%20note,%20sometimes%20in%20JavaScript,%20I%20feel%20like%20a%20whole%20new%20language%20is%20developed%20and%20what%20you%20can%20usually%20do%20won't%20work%20--%20and%20wonder%20what%20can%20be%20done%20to%20prevent%20this%20type%20of%20things%20from%20happening,%20something%20without%20knowing%20that%20it%20would%20happen.
# If%20you'd%20like%20to%20try%20it%20out,%20it%20is%20on%20https://github.com/jianlin/jasmine-looping-an-it-calling-function-that-does-expect' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'http://jsfiddle.net/3wfkr/2/
# I'm%20trying%20to%20get%20an%20async%20setup%20to%20generate%20some%20nested%20specs%20,%20the%20specs%20run%20and%20work,%20but%20an%20error%20is%20also%20generated%20%20...
# TypeError:%20'undefined'%20is%20not%20an%20object%20(evaluating%20'this.views.suites')
# (the%20reason%20I'm%20actually%20trying%20to%20do%20it%20is%20..
# I%20want%20to%20call%20an%20API%20retrieve%20a%20list%20of%20resources%20and%20then%20generate%20tests%20for%20each%20one%20at%20runtime%20..)' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'http://jsfiddle.net/3wfkr/3/
# using%20jasmine%202.0.0%20rc2
# I'm%20trying%20to%20get%20an%20async%20setup%20to%20generate%20some%20nested%20specs%20,%20the%20specs%20run%20and%20work,%20but%20an%20error%20is%20also%20generated%20...
# Time's%20out%20..%20no%20response%20..
# Console%20output%20shows%20the%20first%20nested%20test%20is%20actually%20executing%20...
# testSuiteStarted%20name='test-gen-test.js'
# testStarted%20name='Jasmine%20spec%20gen%20Tests%20A%20complex%20call%20to%20a%20dynamic%20API:It%20got%20some%20Guidance'
# testStdOut%20name='Jasmine%20spec%20gen%20Tests%20A%20complex%20call%20to%20a%20dynamic%20API:It%20got%20some%20Guidance'%20out='Passed'
# testFinished%20name='Jasmine%20spec%20gen%20Tests%20A%20complex%20call%20to%20a%20dynamic%20API:It%20got%20some%20Guidance'%20duration='74'
# testStarted%20name='Jasmine%20spec%20gen%20Tests%20A%20complex%20call%20to%20a%20dynamic%20API:with%20nested%20async%20tests'
# testStdOut%20name='Jasmine%20spec%20gen%20Tests%20A%20complex%20call%20to%20a%20dynamic%20API:with%20nested%20async%20tests'%20out='Passed'
# testFinished%20name='Jasmine%20spec%20gen%20Tests%20A%20complex%20call%20to%20a%20dynamic%20API:with%20nested%20async%20tests'%20duration='661'
# testStarted%20name='Jasmine%20spec%20gen%20Tests%20something%20async:completes%20the%20first%20stage'
# testStdOut%20name='Jasmine%20spec%20gen%20Tests%20something%20async:completes%20the%20first%20stage'%20out='Passed'
# testFinished%20name='Jasmine%20spec%20gen%20Tests%20something%20async:completes%20the%20first%20stage'%20duration='0'
# testStarted%20name='dynamically%20adding%20nested%20contexts%20based%20on%20an%20async%20result:this%20one%20should%20pass'
# testStdOut%20name='dynamically%20adding%20nested%20contexts%20based%20on%20an%20async%20result:this%20one%20should%20pass'%20out='Passed'
# testFinished%20name='dynamically%20adding%20nested%20contexts%20based%20on%20an%20async%20result:this%20one%20should%20pass'%20duration='0'
# AppData\Local\NCrunch\7200\10\src\AIMS.Specs\specs\test-gen-test.js
# Chutzpah.Exceptions.ChutzpahTimeoutException:%20Timeout%20occured%20when%20running%20AppData\Local\NCrunch\7200\10\src\AIMS.Specs\specs\test-gen-test.js
# at%20Chutzpah.TestRunner.HandleTestProcessExitCode(Int32%20exitCode,%20String%20inputTestFile)
# at%20Chutzpah.TestRunner.InvokeTestRunner(String%20headlessBrowserPath,%20TestOptions%20options,%20TestContext%20testContext,%20TestRunnerMode%20testRunnerMode,%20ITestMethodRunnerCallback%20callback)
# at%20Chutzpah.TestRunner.%3c%3ec__DisplayClass2.b__1(PathInfo%20testFile)
# testSuiteFinished%20name='test-gen-test.js'
# Child%20test%20failed' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://jsfiddle.net/so2z3gvy/5/
# The%20issue%20here%20is%20that%20the%20shim%20for%20%22olLayerSwitcher%22%20doesn't%20seem%20to%20be%20working%20when%20ran%20through%20Jasmine.
# This%20is%20a%20distilled%20implementation%20of%20a%20project%20I%20am%20trying%20to%20write%20using%20RequireJR%20and%20Jasmine.
# The%20OpenLayers3%20library%20is%20AMD-capable.%20I%20am%20able%20to%20load%20the%20library%20through%20require%20and%20it%20tests%20out%20fine%20in%20Jasmine%20as%20being%20defined.%20However,%20the%20olLayerSwitcher%20OpenLayers3%20plugin%20is%20not%20AMD%20so%20I%20am%20using%20a%20shim%20to%20load%20it.%20It%20requires%20that%20%22ol%22%20be%20a%20variable%20that%20it%20then%20updates%20with%20functionality.
# While%20this%20works%20when%20loading%20the%20application%20itself%20in%20a%20browser%20in%20the%20same%20configuration%20I'm%20using%20in%20this%20fiddle,%20it%20doesn't%20seem%20like%20it%20works%20properly%20using%20Jasmine.
# The%20Spec%20runner%20here%20is%20a%20hybrid%20of%20what%20the%20Jasmine-maven%20plugin%20creates%20(my%20project%20is%20a%20java%20project%20and%20I%20test%20on%20build)%20and%20what%20I%20was%20able%20to%20cobble%20together%20to%20get%20Jasmine%20to%20load%20in%20jsfiddle%20properly.
# So%20the%20question%20here%20is:%20Why%20is%20it%20that%20this%20works%20outside%20of%20Jasmine?%20It%20seems%20like%20Jasmine%20is%20not%20allowing%20RequireJS%20shimming%20to%20work%20properly.' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'http://jasmine.github.io/2.4/introduction.html' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://stackoverflow.com/questions/47588851/waiting-for-stdin-from-a-jasmine-test-script
# pseudo%20code:
# describe(%22Checking%20OTP%22,%20function%20()%20%7b
#
# %20%20%20%20it(%22it%20should%20be%20valid%20%22,%20function%20()%20%7b
# %20%20%20%20%20%20%20%20const%20readline%20=%20require('readline');
# %20%20%20%20%20%20%20%20const%20rl%20=%20readline.createInterface(%7b
# %20%20%20%20%20%20%20%20%20%20%20%20input:%20process.stdin,
# %20%20%20%20%20%20%20%20%20%20%20%20output:%20process.stdout
# %20%20%20%20%20%20%20%20%7d);
#
# %20%20%20%20%20%20%20%20rl.question('Enter%20OTP:',%20(answer)%20=%3e%20%7b
#
# %20%20%20%20%20%20%20%20%20%20%20%20rl.close();
#
# %20%20%20%20%20%20%20%20%20%20%20%20fetch.post(%22/verifyOTP%22,%20%7b
# %20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20otp:%20answer
# %20%20%20%20%20%20%20%20%20%20%20%20%7d).then(response%20=%3e%20%7b
#
# %20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20it(%22..testing%20the%20next%20step%22,%20function%20()%20%7b
# %20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20//...
# %20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7d)
# %20%20%20%20%20%20%20%20%20%20%20%20%7d)
# %20%20%20%20%20%20%20%20%7d);
# %20%20%20%20%7d)
# %7d)' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://jasmine.github.io/api/3.0/Env.html
# %22Documentation%20generated%20by%20JSDoc%203.5.5%20on%20...%22
# Only%20one%20method%20of%20the%20created%20Env%20instance%20has%20JavaDoc%20comments%20on%20it%20(addReporter),%20and%20that's%20the%20only%20one%20documented%20in%20the%20generated%20Env%20page.
# I%20noticed%20this%20because%20Jasmine%203.0%20randomizes%20the%20order%20of%20tests%20by%20default,%20per%20release%20notes.%20%20For%20my%20testing,%20that's%20bad%20because%20I%20often%20place%20simpler%20tests%20earlier%20than%20more%20complex%20ones.%20%20If%20I%20call%20jasmine.getEnv().randomizeTests(false),%20I%20think%20that%20will%20solve%20the%20problem%20for%20me.%20%20But%20I%20am%20not%20sure%20because%20the%20documentation%20doesn't%20say%20anything%20about%20this%20new%20method.' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# ***** [2019-07-06 13:37:30.018581] START repo#funcunit" *****
# |-- Total records:  154
# |-- Save data to "temp/repo_issue_summary_funcunit.csv"...
# |-- Save data to "temp/repo_issue_summary_funcunit.xlsx"...
# ***** [2019-07-06 13:37:30.258316] START repo#puppeteer" *****
# |-- Total records:  3067
# |-- Save data to "temp/repo_issue_summary_puppeteer.csv"...
# |-- Save data to "temp/repo_issue_summary_puppeteer.xlsx"...
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://try-puppeteer.appspot.com/%20explains%20that%20it's%20not%20necessary%20to%20require('puppeteer')%20when%20pasting%20code,%20but%20it%20turns%20out%20it's%20not%20allowed,%20either.%20This%20makes%20it%20(slightly!)%20more%20difficult%20to%20copy%20and%20paste%20code.' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://bugs.chromium.org/p/chromium/issues/detail?id=736452
# Please%20can%20we%20have%20a%20version%20of%20puppeteer%20which%20uses%20the%20new%20Chromium?%20This%20will%20hopefully%20solve%20so%20many%20headaches%20with%20running%20puppeteer%20inside%20Docker%20containers.' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/nongnoochr/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://developer.mozilla.org/en-US/docs/Web/HTML/Element/option%20(and%20all%20versions%20of%20the%20%3coption%3e%20spec)%20specify%20that,%20in%20absence%20of%20a%20defined%20value%20attribute,%20an%20%3coption%3e%20value%20will%20resolve%20to%20the%20contents%20of%20the%20text%20node%20it%20contains.
# However,%20when%20I%20attempt%20to%20call%20select()%20with%20Puppeteer%20on%20an%20element%20with%20no%20value%20attribute,%20it%20is%20unable%20to%20select%20it%20based%20upon%20the%20value%20contained%20within%20the%20text%20node.
# Steps%20to%20reproduce
#
# Puppeteer%20version:%20puppeteer@1.14.0
# Platform%20/%20OS%20version:%20Arch%20Linux
# URLs%20(if%20applicable):%20n/app%20(internal/confidential%20URLs)
# Node.js%20version:%20v11.13.0
#
# What%20steps%20will%20reproduce%20the%20problem?
# HTML
# %3cselect%20id=%22example%22%3e
# %20%20%3coption%3eApples%3c/option%3e
# %20%20%3coption%3eBananas%3c/option%3e
# %20%20%3coption%3eCoconuts%3c/option%3e
# %3c/select%3e
# Node
# await%20page.select('select' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# ***** [2019-07-06 13:37:34.584714] START repo#cypress" *****
# |-- Total records:  3541
# |-- Save data to "temp/repo_issue_summary_cypress.csv"...
# |-- Save data to "temp/repo_issue_summary_cypress.xlsx"...

# %%
df_cur.head()
# Out:
#    issue_id                                              title  \
# 0         1            cy.contains() breaks with single quotes
# 1         2                         Integration with Travis CI
# 2         3  cy.visit() will insert a trailing slash which ...
# 3         4  When doing 2 requests to the same cy.route ali...
# 4         5   allow for aliasing of things beside DOM elements
#
#                                             contents       authorLogin  \
# 0  When passing in a string containing a single q...  jennifer-shehane
# 1  Would love support and documentation for autom...       lorennorman
# 2            Example:\nhttp://localhost:5000/#/map?/   brandon-beacher
# 3  cy.route(/accounts/, {}).as("accountsGet")\n\n...  jennifer-shehane
# 4  I'd like to be able to alias things other than...  jennifer-shehane
#
#   authorAssociation                 createdAt  closed  \
# 0            MEMBER 2015-03-27 15:48:51+00:00    True
# 1       CONTRIBUTOR 2015-03-27 16:42:26+00:00    True
# 2              NONE 2015-03-27 16:44:19+00:00    True
# 3            MEMBER 2015-03-27 17:31:34+00:00    True
# 4            MEMBER 2015-03-27 19:06:23+00:00    True
#
#                    closedAt  closedDuration_days milestone  ...  \
# 0 2015-03-27 23:20:21+00:00                 0.31            ...
# 1 2015-09-14 04:53:51+00:00               170.51            ...
# 2 2015-03-27 23:21:03+00:00                 0.28            ...
# 3 2015-04-27 04:13:20+00:00                30.45            ...
# 4 2015-04-24 16:16:35+00:00                27.88            ...
#
#    label_topic: cy.wait() timeout  label_OS: FreeBSD  \
# 0                           False              False
# 1                           False              False
# 2                           False              False
# 3                           False              False
# 4                           False              False
#
#   label_external: dashboard  label_pkg/driver label_topic: plugins ⚙️  \
# 0                     False             False                   False
# 1                     False             False                   False
# 2                     False             False                   False
# 3                     False             False                   False
# 4                     False             False                   False
#
#   label_topic: visibility 👁  label_topic: drag-and-drop  \
# 0                     False                       False
# 1                     False                       False
# 2                     False                       False
# 3                     False                       False
# 4                     False                       False
#
#    label_external: documentation  label_topic: actionability  \
# 0                          False                       False
# 1                          False                       False
# 2                          False                       False
# 3                          False                       False
# 4                          False                       False
#
#    label_topic: aw snap :slightly_frowning_face:
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
# [5 rows x 144 columns]
