# %% [markdown]
# # Exploratory Data Analysis - GitHub repo's issues

# %%
import json
import numpy as np
import pandas as pd
import datetime


import warnings
warnings.filterwarnings('ignore')

# # Suppress pandas's warning
# warnings.simplefilter(action='ignore', category=Warning)

## https://stackoverflow.com/questions/20625582/how-to-deal-with-settingwithcopywarning-in-pandas
# pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ## Data requirements

# %% [markdown]
# Below is a list of interested data that we will use in the initial analysis
# * How long the issues open
# * First comment response time
# * Number of comments
# * Number of participants
# * Labels associated with each issue
# * Milestone

# %% [markdown]
# Later will be done in the later part - Find data for each year where
# * Top words in question
# * Top words in answers
# * Top participants + Type and company

# %% [markdown]
# ## Cleaning data - High-level data
#
# * Extract only interested columns which are
# [
# 'issue_id',
# 'title',
# 'contents',
# 'authorLogin',
# 'authorAssociation',
# 'createdAt',
# 'closedAt',
# 'closed',
# 'comments_count',
# 'comments_data',
# 'participants_count',
# 'labels',
# 'milestone'
# ]
#
# * Cast datetime columns to ['createdAt', 'closedAt'] datetime
# * Create a new column 'closedDuration_days' to store a timediff between the columns ['closedAt', 'createdAt'] in days
# * Additional columns for comments data
#   * Create a new column 'firstCommentCreatedAt' to store a datetime object the first comment is created
#   * Create a new column 'firstCommentDuration_days' to store a timediff between the columns 'createdAt' and the creation time of the first comment in days
#   * New columns for the first comment author info ['firstCommentAuthor', 'firstCommentAuthorAssociation']
#   * New columns for total number of unique comment authors based on authorAssociation ['num_unique_comment_author_MEMBER', 'num_unique_comment_author_CONTRIBUTOR', 'num_unique_comment_author_COLLABORATOR', 'num_unique_comment_author_NONE']
# * Extract 'milestone' title and replace the 'milestone' column with this value
# * Perform one-hot encoding to the label column

# %%
def save_df_to_xlsx(df, xlsx_filename):
    '''
    Save the input dataframe to the specified file path
    
    Note that the xlsx is needed to create visualizations in Tableau
    because it could not properly read the csv data when the contents contain ','
    '''

    writer = pd.ExcelWriter(xlsx_filename,
                engine='xlsxwriter',
                options={'remove_timezone': True})

    df.to_excel(writer, index=False, sheet_name='Sheet1')

    workbook  = writer.book
    worksheet = writer.sheets['Sheet1']

    writer.save()

# %%
def get_comment_info_columns(row):
    '''
    Function to extract data from a dataframe's row that will be used in the function 'create_highlevel_df'
    
    Input argument:
        row: A row of data frame containing github issue info
        
    Output argument:
        a list containing the following information
            [
                'firstCommentCreatedAt', 
                'firstCommentAuthor', 
                'firstCommentAuthorAssociation',
                'num_unique_comment_author_MEMBER',
                'num_unique_comment_author_CONTRIBUTOR',
                'num_unique_comment_author_COLLABORATOR',
                'num_unique_comment_author_NONE'
            ]
        
    '''
    
    # If the comments_count is greater than 0
    if row['comments_count'] > 0:
        
        # --- Extract data for 'firstCommentCreatedAt', 'firstCommentAuthor', 'firstCommentAuthorAssociation'
        
        out = [
            row['comments_data'][0]['createdAt'],
            row['comments_data'][0]['authorLogin'], 
            row['comments_data'][0]['authorAssociation']
        ]
        
        # --- Extract data for 'num_unique_comment_*'
        # We need to extract data from the 'comments_data' column
        
        # Get a list of all comment authors first
        list_comment_authors = []
        for cur_comment in row['comments_data']:
            cur_author = {
                'login': cur_comment['authorLogin'],
                'association': cur_comment['authorAssociation']
            }
            list_comment_authors.append(cur_author)
            
        unique_comment_authors = [dict(y) for y in set(tuple(x.items()) for x in list_comment_authors)]
        
        # Then, get count for each type
        dict_author_assoc = {
            'MEMBER': 0,
            'CONTRIBUTOR': 0,
            'COLLABORATOR': 0,
            'NONE': 0
        }
        
        for cur_comment_author in unique_comment_authors:
            cur_assoc = cur_comment_author['association']
            dict_author_assoc[cur_assoc] += 1
            
        # Append data to the output list
        out = out + [
            dict_author_assoc['MEMBER'],
            dict_author_assoc['CONTRIBUTOR'],
            dict_author_assoc['COLLABORATOR'],
            dict_author_assoc['NONE']
        ]
    else:
        # Otherwise, output a default output list
        out = [None, None, None, 0, 0, 0, 0]

        
    return out

# %%
def create_highlevel_df(json_path):
    '''
    Extract github issues data from the specified path and output an extracted summary data as a new dataframe
    '''
    
    # Load json data and create dataframe
    with open(json_path) as json_file:  
        data_raw = json.load(json_file)

    df_raw = pd.DataFrame.from_dict(data_raw)
    
    # Let's get only columns that we need for the analysis now
    new_cols = [
        'issue_id',
        'title',
        'contents',
        'authorLogin',
        'authorAssociation',
        'createdAt',
        'closedAt',
        'closed',
        'comments_count',
        'participants_count',
        'comments_data',
        'labels',
        'milestone'
     ]
    
    df_out = df_raw[new_cols]
    
    # --- Cast columns to datetime
    df_out[['createdAt', 'closedAt']] = df_out[['createdAt', 'closedAt']].apply(pd.to_datetime)
    
    # --- Find closedDuration_days
    get_diff_days = lambda s: (s.dt.total_seconds() / (24 * 60 * 60)).round(2)
#     df_out['closedDuration_days'] = ((df_out['closedAt'] - df_out['createdAt']).dt.total_seconds() / (24 * 60 * 60)).round(2)
    df_out['closedDuration_days'] = get_diff_days(df_out['closedAt'] - df_out['createdAt'])

    # --- Find comment info
    cols_first_comments = [
        'firstCommentCreatedAt', 
        'firstCommentAuthor', 
        'firstCommentAuthorAssociation',
        'num_unique_comment_author_MEMBER',
        'num_unique_comment_author_CONTRIBUTOR',
        'num_unique_comment_author_COLLABORATOR',
        'num_unique_comment_author_NONE'
    ]
    df_out[cols_first_comments] = pd.DataFrame(
                    df_out.apply(lambda row: get_comment_info_columns(row), axis=1).values.tolist(), 
                     index= df_out.index)

    df_out['firstCommentCreatedAt'] = pd.to_datetime(df_out['firstCommentCreatedAt'])
    df_out['firstCommentDuration_days'] = get_diff_days(df_out['firstCommentCreatedAt'] - df_out['createdAt'])
    
    # --- Extract 'milestone' title and replace the 'milestone' colummn with this value
    df_out['milestone'] = df_out['milestone'].apply(lambda x: x['title'] if x else '')
    
    # --- Perform one hot encoding for the labels columns
    
    # Get a list of labels
    list_labels = []
    for index, row in df_out.iterrows():
        list_labels = list_labels + row['labels']

    list_labels = list(set(list_labels))
    
    # Then, create new columns for each of those labels
    
    # Create a dictionary to map those labels with a boolean value for each record in the dataset
    dict_labels = dict((el,[]) for el in list_labels)
    for index, row in df_out.iterrows():
        for cur_label in list_labels:
            cur_bool = False
            if cur_label in row['labels']:
                cur_bool = True

            dict_labels[cur_label].append(cur_bool)
    
    # Then, create a dataframe for it and merge the newly created dataframe with the current output dataframe
    df_out = pd.concat([df_out, pd.DataFrame.from_dict(dict_labels)], axis=1)
    
    # Finally, prepend those newly added label columns with 'Label_'
    dict_rename = {}
    for cur_label in list_labels:
        dict_rename[cur_label] = 'label_' + cur_label
        
    df_out = df_out.rename(columns=dict_rename)

    
    # --- Reorder columns
    final_cols = [
        'issue_id',
        'title',
        'contents',
        'authorLogin',
        'authorAssociation',
        'createdAt',
        'closed',
        'closedAt',        
        'closedDuration_days',
        'milestone',
        'participants_count',
        'comments_count',
        'firstCommentCreatedAt',
        'firstCommentDuration_days',
        'firstCommentAuthor',
        'firstCommentAuthorAssociation',
        'num_unique_comment_author_MEMBER',
        'num_unique_comment_author_CONTRIBUTOR',
        'num_unique_comment_author_COLLABORATOR',
        'num_unique_comment_author_NONE',
        'labels'
    ]
    
    # Then, append the one hot encoding's label columns
    final_cols = final_cols + ['label_' + cur_label for cur_label in list_labels]
    df_out = df_out[final_cols]
    
    return df_out

# %%
list_libs = [
    'qunit',
    'mocha',
    'jest',
    'jasmine',
    'funcunit',
    'puppeteer',
    'cypress'
]

all_df = {}

for cur_lib in list_libs:
    print('***** [{}] START repo#{}" *****'.format(str(datetime.datetime.now()), cur_lib))
        
    json_path = '../data/github_repo_issues_{}.json'.format(cur_lib)
    df_cur = create_highlevel_df(json_path) 
    
    all_df[cur_lib] = df_cur
    
    print('|-- Total records: ', df_cur.shape[0])
    
    # --- Save data to csv
    csv_filename = 'temp/repo_issue_summary_{}.csv'.format(cur_lib)
    print('|-- Save data to "{}"...'.format(csv_filename))
    df_cur.to_csv(csv_filename, index=False)
    
    # --- Save data to xlsx since the csv data is not read properly in Tableau due to a usage of ',' in the contents
    xlsx_filename = "temp/repo_issue_summary_{}.xlsx".format(cur_lib)
    print('|-- Save data to "{}"...'.format(xlsx_filename))
    
    writer = pd.ExcelWriter(xlsx_filename,
                engine='xlsxwriter',
                options={'remove_timezone': True})

    df_cur.to_excel(writer, index=False, sheet_name='Sheet1')

    workbook  = writer.book
    worksheet = writer.sheets['Sheet1']

    writer.save()
# Out:
# ***** [2019-07-06 14:05:22.942977] START repo#qunit" *****
# |-- Total records:  708
# |-- Save data to "temp/repo_issue_summary_qunit.csv"...
# |-- Save data to "temp/repo_issue_summary_qunit.xlsx"...
# ***** [2019-07-06 14:05:24.067444] START repo#mocha" *****
# |-- Total records:  2356
# |-- Save data to "temp/repo_issue_summary_mocha.csv"...
# |-- Save data to "temp/repo_issue_summary_mocha.xlsx"...
# ***** [2019-07-06 14:05:28.482844] START repo#jest" *****
# |-- Total records:  4530
# |-- Save data to "temp/repo_issue_summary_jest.csv"...
# |-- Save data to "temp/repo_issue_summary_jest.xlsx"...
# ***** [2019-07-06 14:05:37.159809] START repo#jasmine" *****
# |-- Total records:  1198
# |-- Save data to "temp/repo_issue_summary_jasmine.csv"...
# |-- Save data to "temp/repo_issue_summary_jasmine.xlsx"...
# ***** [2019-07-06 14:05:38.732571] START repo#funcunit" *****
# |-- Total records:  154
# |-- Save data to "temp/repo_issue_summary_funcunit.csv"...
# |-- Save data to "temp/repo_issue_summary_funcunit.xlsx"...
# ***** [2019-07-06 14:05:38.981174] START repo#puppeteer" *****
# |-- Total records:  3067
# |-- Save data to "temp/repo_issue_summary_puppeteer.csv"...
# |-- Save data to "temp/repo_issue_summary_puppeteer.xlsx"...
# ***** [2019-07-06 14:05:42.529885] START repo#cypress" *****
# |-- Total records:  3541
# |-- Save data to "temp/repo_issue_summary_cypress.csv"...
# |-- Save data to "temp/repo_issue_summary_cypress.xlsx"...

# %%
df_cur.head()
# Out:
#    issue_id                                              title  \
# 0         1            cy.contains() breaks with single quotes
# 1         2                         Integration with Travis CI
# 2         3  cy.visit() will insert a trailing slash which ...
# 3         4  When doing 2 requests to the same cy.route ali...
# 4         5   allow for aliasing of things beside DOM elements
#
#                                             contents       authorLogin  \
# 0  When passing in a string containing a single q...  jennifer-shehane
# 1  Would love support and documentation for autom...       lorennorman
# 2            Example:\nhttp://localhost:5000/#/map?/   brandon-beacher
# 3  cy.route(/accounts/, {}).as("accountsGet")\n\n...  jennifer-shehane
# 4  I'd like to be able to alias things other than...  jennifer-shehane
#
#   authorAssociation                 createdAt  closed  \
# 0            MEMBER 2015-03-27 15:48:51+00:00    True
# 1       CONTRIBUTOR 2015-03-27 16:42:26+00:00    True
# 2              NONE 2015-03-27 16:44:19+00:00    True
# 3            MEMBER 2015-03-27 17:31:34+00:00    True
# 4            MEMBER 2015-03-27 19:06:23+00:00    True
#
#                    closedAt  closedDuration_days milestone  ...  \
# 0 2015-03-27 23:20:21+00:00                 0.31            ...
# 1 2015-09-14 04:53:51+00:00               170.51            ...
# 2 2015-03-27 23:21:03+00:00                 0.28            ...
# 3 2015-04-27 04:13:20+00:00                30.45            ...
# 4 2015-04-24 16:16:35+00:00                27.88            ...
#
#    label_topic: cy.wait() timeout  label_OS: FreeBSD  \
# 0                           False              False
# 1                           False              False
# 2                           False              False
# 3                           False              False
# 4                           False              False
#
#   label_external: dashboard  label_pkg/driver label_topic: plugins ⚙️  \
# 0                     False             False                   False
# 1                     False             False                   False
# 2                     False             False                   False
# 3                     False             False                   False
# 4                     False             False                   False
#
#   label_topic: visibility 👁  label_topic: drag-and-drop  \
# 0                     False                       False
# 1                     False                       False
# 2                     False                       False
# 3                     False                       False
# 4                     False                       False
#
#    label_external: documentation  label_topic: actionability  \
# 0                          False                       False
# 1                          False                       False
# 2                          False                       False
# 3                          False                       False
# 4                          False                       False
#
#    label_topic: aw snap :slightly_frowning_face:
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
# [5 rows x 144 columns]

# %%
# Out:
# {'qunit':      issue_id                                              title  \
#  0           1                    noglobals GET parameter ignored
#  1           2  Test Suite URL Params need their own query string
#  2           3                           module name is not shown
#  3           4  The assesrtions inside an QUnit.asyncTest are ...
#  4           5          qunit throws syntax error on Safari 2.0.4
#  5           6                               Add "start" callback
#  6           7  Modify location.search instead of location.hre...
#  7           8                      Failed tests expanded on load
#  8           9  Should have an assertion for locating an item ...
#  9          10         Show diff if equal() or deepEqual() failed
#  10         11     Remove `init` function from a global namespace
#  11         12                                 "raises" assertion
#  12         13  An element's child nodes will be gone under ce...
#  13         14  misuse of stop()/start() breaks test independence
#  14         15                                  dog-fooding qunit
#  15         16                                start configuration
#  16         17  qunit.js raises 1 JS error and 2 JS warnings i...
#  17         18                          add "notequals" assertion
#  18         19  QUnit.reset() removes global jQuery ajax event...
#  19         20                           Async setup and teardown
#  20         21  not*Equal should show both args in success cas...
#  21         22  Output long expected/actual values with fixed-...
#  22         23  Double-clicking test title shows all tests for...
#  23         24                          BlackBerry 5.0 and stop()
#  24         25                                   Output is broken
#  25         26                             optimize css selectors
#  26         27                               Array equality fails
#  27         29  Output location in addition to useragent for r...
#  28         30                                  Docs page failing
#  29         31                        Output exception stacktrace
#  ..        ...                                                ...
#  678      1342             Reduce size of module dependency graph
#  679      1347     Require Windows tests passing on pull requests
#  680      1348       Require npmjs.org 2FA for package publishing
#  681      1350          Release process without protection bypass
#  682      1351                            Document URL parameters
#  683      1352                            Document deprecated API
#  684      1353  Add "version added" annotations to API documen...
#  685      1354               Document good usage of assert.expect
#  686      1355         Split the documentation on 1.x.x and 2.x.x
#  687      1356    Document failure of assertions ran after done()
#  688      1357      Arrow functions as test/module hook callbacks
#  689      1358        Document callback ordering more explicitly.
#  690      1359                  Make CLI tests passing on Windows
#  691      1364  Figure out autodetect for "grunt qunit" test urls
#  692      1367  Breakage in 2.9.0:  Error: Cannot find module ...
#  693      1371               Parent directories ".." in file path
#  694      1372  `qunit --require` does not find local module i...
#  695      1374  testStart callback does not wait on returned P...
#  696      1375  Semaphore imbalance when returned promise reso...
#  697      1377  Core: hooks invoked after a test is considered...
#  698      1383              CLI should not exit with process.exit
#  699      1386  Tests involving window scrolling fails in iOS ...
#  700      1387  Elect / Nominate representative(s) to the Open...
#  701      1389  assert.throws fails when expected is an arrow ...
#  702      1390             Provide a way to reset the test server
#  703      1392                 Add support for Google Apps Script
#  704      1393  Community Invitation to the OpenJS Collaborato...
#  705      1394  Display progress in test runner during test su...
#  706      1396           Consider renaming "Main assertions" page
#  707      1399  Can the test file name be passed in the "suite...
#
#                                                contents       authorLogin  \
#  0    QUnit.init overrides the config var, resetting...           kassens
#  1    If you use qunit with testswarm it fails to ru...             RyanS
#  2    When modules are defined, their names do not a...             smith
#  3    Hi!\nAs far as I can understand from the code*...           gurdiga
#  4    It is not possible to use qunit to run tests i...           micmath
#  5    The browser automation integration callbacks a...             runeh
#  6    Double-clicking a test when the URL has a hash...           eligrey
#  7    For the UI - how do people feel about having t...              phae
#  8    I've found this to be very useful in my work, ...     nickretallack
#  9    Quickly, can you figure out what's wrong here?...                NV
#  10   QUnit puts a lot of functions to the global na...                NV
#  11   It would be useful for QUnit to provide an ass...               FND
#  12   Consider a test page with a main section as fo...      timmolendijk
#  13   Accidentally calling start() twice in an async...          csosborn
#  14   I would like for all the private functions to ...         gutzofter
#  15   when the page initially displays it has the 'H...         gutzofter
#  16   Hello,\nIty is a minot thing but today I found...          gaddlord
#  17   It would be nice if we could test for inequality.          gminuses
#  18   While testing my global ajax event support lib...         salomvary
#  19   Guys,\nI've had to run some async code on my s...            fgrehm
#  20   E.g. strictEqual gives both args, if the compa...          hartrock
#  21   A full diff library would be overkill, but the...        jzaefferer
#  22   I think this is a regression error, as before ...      andybeeching
#  23   In unit testing jQuery hashchange event in Bla...            cowboy
#  24                 http://elv1s.ru/x/qunit/equals.html                NV
#  25   definitely something minor but the css selecto...          leeoniya
#  26   The following assertion fails, and shouldn't. ...               rdw
#  27   It would be handy to get the URL into the mark...        jzaefferer
#  28   See\nhttp://img529.imageshack.us/img529/5835/p...  fernandezpablo85
#  29   Currently exceptions will get logged to the co...        jzaefferer
#  ..                                                 ...               ...
#  678  The qunit npm package has quite a lot of depen...           Krinkle
#  679  To avoid #1346 in the future, and to embrace W...           Krinkle
#  680  Reading through RELEASE.md (Thanks @trentmwill...           Krinkle
#  681  Reading through RELEASE.md (Thanks @trentmwill...           Krinkle
#  682  Assuming the QUnit URL parameters are to be tr...         gibson042
#  683  List all the deprecated parts of the API.\nRef...         leobalter
#  684  Similar to http://api.jquery.com/on/\n\nversio...           Krinkle
#  685  Based on the discussion in #666, there are som...        jzaefferer
#  686  As we are in the way to 2.x.x, we should think...         leobalter
#  687  From qunitjs/qunitjs.com#84 (comment):\n\nWe n...        jzaefferer
#  688  The API documentation for QUnit.module mention...     platinumazure
#  689  The ordering of callbacks is not very obvious ...           rwjblue
#  690  As part of #1347 I tried to consolidate the ma...           Krinkle
#  691  What are you trying to do?\nRunning tests via ...           Krinkle
#  692  Tell us about your runtime:\n\nQUnit version: ...      jacekkopecky
#  693  Tell us about your runtime:\n\nQUnit version: ...     Zocker1999NET
#  694  Tell us about your runtime:\n\nQUnit version: ...       jeremiahlee
#  695  Tell us about your runtime:\n\nQUnit version: ...          jeberger
#  696  Tell us about your runtime:\n\nQUnit version:2...           rwjblue
#  697  Tell us about your runtime:\n\nQUnit version: ...          scalvert
#  698  Tell us about your runtime:\n\nQUnit version: ...        krisselden
#  699  Tell us about your runtime:\n\nQUnit version:\...            pudupa
#  700  Context\nAs part of the new OpenJS Foundation'...        jorydotcom
#  701  Tell us about your runtime:\n\nQUnit version: ...              ohze
#  702  Tell us about your runtime:\n\nQUnit version: ...           sduquej
#  703  It would be great, if QUnit could be used as t...       ahochsteger
#  704  Hi all! In an effort to make sure we're fully ...        jorydotcom
#  705  It would be an excellent enhancement to add in...          ghaagsma
#  706  Almost every time I navigate to https://api.qu...           Krinkle
#  707  Hi,\nI have a use case where I want to print t...         muthu90ec
#
#      authorAssociation                 createdAt  closed  \
#  0         CONTRIBUTOR 2009-10-02 14:16:41+00:00    True
#  1         CONTRIBUTOR 2009-10-12 14:41:46+00:00    True
#  2                NONE 2009-10-25 03:48:40+00:00    True
#  3                NONE 2009-11-05 13:43:37+00:00    True
#  4                NONE 2009-11-13 16:37:04+00:00    True
#  5         CONTRIBUTOR 2009-12-21 21:38:33+00:00    True
#  6                NONE 2009-12-22 03:17:52+00:00    True
#  7                NONE 2010-01-04 16:24:18+00:00    True
#  8                NONE 2010-01-31 09:04:46+00:00    True
#  9         CONTRIBUTOR 2010-02-09 18:26:16+00:00    True
#  10        CONTRIBUTOR 2010-02-13 22:00:22+00:00    True
#  11               NONE 2010-02-25 10:10:45+00:00    True
#  12               NONE 2010-03-11 23:54:30+00:00    True
#  13               NONE 2010-03-21 00:20:24+00:00    True
#  14               NONE 2010-03-23 04:36:42+00:00    True
#  15               NONE 2010-03-23 04:40:20+00:00    True
#  16               NONE 2010-05-17 09:08:36+00:00    True
#  17               NONE 2010-05-19 03:51:42+00:00    True
#  18               NONE 2010-06-01 08:28:50+00:00    True
#  19        CONTRIBUTOR 2010-06-14 17:15:46+00:00    True
#  20               NONE 2010-07-14 23:18:29+00:00    True
#  21             MEMBER 2010-07-19 16:10:18+00:00    True
#  22               NONE 2010-07-20 09:40:18+00:00    True
#  23               NONE 2010-07-20 19:45:39+00:00    True
#  24        CONTRIBUTOR 2010-07-21 21:44:48+00:00    True
#  25        CONTRIBUTOR 2010-07-22 15:05:23+00:00    True
#  26               NONE 2010-08-08 09:58:21+00:00    True
#  27             MEMBER 2010-08-25 16:38:26+00:00    True
#  28               NONE 2010-08-25 20:30:50+00:00    True
#  29             MEMBER 2010-08-27 18:32:32+00:00    True
#  ..                ...                       ...     ...
#  678            MEMBER 2018-12-22 20:59:15+00:00    True
#  679            MEMBER 2018-12-28 06:34:07+00:00    True
#  680            MEMBER 2018-12-29 03:17:04+00:00   False
#  681            MEMBER 2018-12-29 05:50:51+00:00   False
#  682            MEMBER 2015-12-15 16:27:02+00:00   False
#  683            MEMBER 2016-02-01 13:43:33+00:00   False
#  684            MEMBER 2015-02-10 00:28:04+00:00   False
#  685            MEMBER 2014-09-24 16:00:53+00:00   False
#  686            MEMBER 2014-09-22 15:24:35+00:00    True
#  687            MEMBER 2014-11-06 15:06:14+00:00   False
#  688       CONTRIBUTOR 2016-08-23 21:38:08+00:00   False
#  689       CONTRIBUTOR 2016-09-16 01:43:28+00:00   False
#  690            MEMBER 2018-12-30 19:32:37+00:00   False
#  691            MEMBER 2019-01-06 22:42:10+00:00   False
#  692              NONE 2019-01-07 10:27:44+00:00    True
#  693              NONE 2019-01-23 22:02:40+00:00   False
#  694              NONE 2019-01-24 13:58:04+00:00   False
#  695              NONE 2019-02-13 08:41:11+00:00    True
#  696       CONTRIBUTOR 2019-02-20 14:12:41+00:00    True
#  697       CONTRIBUTOR 2019-02-22 00:21:09+00:00   False
#  698              NONE 2019-03-13 20:53:04+00:00   False
#  699              NONE 2019-04-01 21:18:33+00:00    True
#  700              NONE 2019-04-07 19:59:30+00:00   False
#  701              NONE 2019-04-17 18:56:59+00:00   False
#  702              NONE 2019-04-19 10:07:32+00:00   False
#  703              NONE 2019-05-01 10:07:06+00:00   False
#  704              NONE 2019-05-01 14:55:50+00:00    True
#  705       CONTRIBUTOR 2019-05-13 22:53:27+00:00    True
#  706            MEMBER 2019-06-10 15:33:13+00:00   False
#  707              NONE 2019-06-20 23:29:44+00:00   False
#
#                       closedAt  closedDuration_days milestone  ...  label_meta  \
#  0   2009-11-05 13:16:45+00:00                33.96            ...       False
#  1   2009-11-05 13:09:47+00:00                23.94            ...       False
#  2   2009-11-05 13:08:48+00:00                11.39            ...       False
#  3   2009-11-15 04:05:09+00:00                 9.60            ...       False
#  4   2009-11-15 04:27:56+00:00                 1.49            ...       False
#  5   2010-07-26 16:12:38+00:00               216.77            ...       False
#  6   2010-07-26 16:17:16+00:00               216.54            ...       False
#  7   2010-07-26 16:21:14+00:00               203.00            ...       False
#  8   2010-07-26 16:23:07+00:00               176.30            ...       False
#  9   2010-07-26 17:02:50+00:00               166.94            ...       False
#  10  2010-07-26 17:09:45+00:00               162.80            ...       False
#  11  2010-07-26 17:44:12+00:00               151.31            ...       False
#  12  2010-07-18 18:39:22+00:00               128.78            ...       False
#  13  2010-07-19 16:12:27+00:00               120.66            ...       False
#  14  2010-07-27 00:32:52+00:00               125.83            ...       False
#  15  2010-03-23 04:40:48+00:00                 0.00            ...       False
#  16  2010-07-27 00:33:46+00:00                70.64            ...       False
#  17  2010-05-19 07:29:32+00:00                 0.15            ...       False
#  18  2010-07-27 09:29:58+00:00                56.04            ...       False
#  19  2010-07-15 16:07:23+00:00                30.95            ...       False
#  20  2010-07-15 22:48:09+00:00                 0.98            ...       False
#  21  2010-07-20 04:03:14+00:00                 0.50            ...       False
#  22  2010-07-26 17:51:01+00:00                 6.34            ...       False
#  23  2010-07-29 07:24:59+00:00                 8.49            ...       False
#  24  2010-07-22 12:17:10+00:00                 0.61            ...       False
#  25  2010-07-29 13:24:09+00:00                 6.93            ...       False
#  26  2010-08-09 00:29:05+00:00                 0.60            ...       False
#  27  2010-08-29 18:04:48+00:00                 4.06            ...       False
#  28  2010-08-26 09:14:50+00:00                 0.53            ...       False
#  29  2010-11-03 15:17:12+00:00                67.86            ...       False
#  ..                        ...                  ...       ...  ...         ...
#  678 2018-12-28 22:00:19+00:00                 6.04       2.9  ...        True
#  679 2019-01-02 00:11:01+00:00                 4.73       2.9  ...        True
#  680                       NaT                  NaN            ...        True
#  681                       NaT                  NaN            ...        True
#  682                       NaT                  NaN            ...       False
#  683                       NaT                  NaN            ...       False
#  684                       NaT                  NaN            ...       False
#  685                       NaT                  NaN            ...       False
#  686 2018-12-29 06:08:35+00:00              1558.61            ...       False
#  687                       NaT                  NaN            ...       False
#  688                       NaT                  NaN            ...       False
#  689                       NaT                  NaN            ...       False
#  690                       NaT                  NaN            ...       False
#  691                       NaT                  NaN            ...       False
#  692 2019-01-07 16:47:01+00:00                 0.26       2.9  ...       False
#  693                       NaT                  NaN            ...       False
#  694                       NaT                  NaN            ...       False
#  695 2019-02-14 08:57:36+00:00                 1.01            ...       False
#  696 2019-02-21 04:52:18+00:00                 0.61            ...       False
#  697                       NaT                  NaN            ...       False
#  698                       NaT                  NaN            ...       False
#  699 2019-05-07 23:05:35+00:00                36.07            ...       False
#  700                       NaT                  NaN            ...        True
#  701                       NaT                  NaN            ...       False
#  702                       NaT                  NaN            ...       False
#  703                       NaT                  NaN            ...       False
#  704 2019-06-14 00:05:39+00:00                43.38            ...        True
#  705 2019-06-18 17:42:10+00:00                35.78            ...       False
#  706                       NaT                  NaN            ...       False
#  707                       NaT                  NaN            ...       False
#
#       label_help wanted label_good for new contributors  label_category-docs  \
#  0                False                           False                False
#  1                False                           False                False
#  2                False                           False                False
#  3                False                           False                False
#  4                False                           False                False
#  5                False                           False                False
#  6                False                           False                False
#  7                False                           False                False
#  8                False                           False                False
#  9                False                           False                False
#  10               False                           False                False
#  11               False                           False                False
#  12               False                           False                False
#  13               False                           False                False
#  14               False                           False                False
#  15               False                           False                False
#  16               False                           False                False
#  17               False                           False                False
#  18               False                           False                False
#  19               False                           False                False
#  20               False                           False                False
#  21               False                           False                False
#  22               False                           False                False
#  23               False                           False                False
#  24               False                           False                False
#  25               False                           False                False
#  26               False                           False                False
#  27               False                           False                False
#  28               False                           False                False
#  29               False                           False                False
#  ..                 ...                             ...                  ...
#  678              False                           False                False
#  679              False                           False                False
#  680              False                           False                False
#  681              False                           False                False
#  682               True                           False                 True
#  683              False                           False                 True
#  684              False                           False                 True
#  685              False                           False                 True
#  686              False                           False                 True
#  687              False                           False                 True
#  688              False                           False                 True
#  689              False                           False                 True
#  690              False                           False                False
#  691              False                           False                False
#  692              False                           False                False
#  693              False                           False                False
#  694              False                           False                False
#  695              False                           False                False
#  696              False                           False                False
#  697              False                           False                False
#  698              False                           False                False
#  699              False                           False                False
#  700              False                           False                False
#  701              False                           False                False
#  702              False                           False                False
#  703              False                           False                False
#  704              False                           False                False
#  705              False                           False                False
#  706              False                           False                 True
#  707              False                           False                False
#
#      label_category-tests label_component-reporter  label_status-stalled  \
#  0                  False                    False                 False
#  1                  False                    False                 False
#  2                  False                    False                 False
#  3                  False                    False                 False
#  4                  False                    False                 False
#  5                  False                    False                 False
#  6                  False                    False                 False
#  7                  False                    False                 False
#  8                  False                    False                 False
#  9                  False                    False                 False
#  10                 False                    False                 False
#  11                 False                    False                 False
#  12                 False                    False                 False
#  13                 False                    False                 False
#  14                 False                    False                 False
#  15                 False                    False                 False
#  16                 False                    False                 False
#  17                 False                    False                 False
#  18                 False                    False                 False
#  19                 False                    False                 False
#  20                 False                    False                 False
#  21                 False                    False                 False
#  22                 False                    False                 False
#  23                 False                    False                 False
#  24                 False                    False                 False
#  25                 False                    False                 False
#  26                 False                    False                 False
#  27                 False                    False                 False
#  28                 False                    False                 False
#  29                 False                    False                 False
#  ..                   ...                      ...                   ...
#  678                False                    False                 False
#  679                 True                    False                 False
#  680                False                    False                 False
#  681                False                    False                 False
#  682                False                    False                 False
#  683                False                    False                 False
#  684                False                    False                 False
#  685                False                    False                 False
#  686                False                    False                 False
#  687                False                    False                 False
#  688                False                    False                 False
#  689                False                    False                 False
#  690                 True                    False                 False
#  691                 True                    False                 False
#  692                False                    False                 False
#  693                False                    False                 False
#  694                False                    False                 False
#  695                False                    False                 False
#  696                False                    False                 False
#  697                False                    False                 False
#  698                False                    False                  True
#  699                False                    False                 False
#  700                False                    False                 False
#  701                False                    False                 False
#  702                False                    False                 False
#  703                False                    False                 False
#  704                False                    False                 False
#  705                False                     True                 False
#  706                False                    False                 False
#  707                False                    False                 False
#
#       label_type-support  label_component-dump  label_category-release
#  0                 False                 False                   False
#  1                 False                 False                   False
#  2                 False                 False                   False
#  3                 False                 False                   False
#  4                 False                 False                   False
#  5                 False                 False                   False
#  6                 False                 False                   False
#  7                 False                 False                   False
#  8                 False                 False                   False
#  9                 False                 False                   False
#  10                False                 False                   False
#  11                False                 False                   False
#  12                False                 False                   False
#  13                False                 False                   False
#  14                False                 False                   False
#  15                False                 False                   False
#  16                False                 False                   False
#  17                False                 False                   False
#  18                False                 False                   False
#  19                False                 False                   False
#  20                False                 False                   False
#  21                False                 False                   False
#  22                False                 False                   False
#  23                False                 False                   False
#  24                False                 False                   False
#  25                False                 False                   False
#  26                False                 False                   False
#  27                False                 False                   False
#  28                False                 False                   False
#  29                False                 False                   False
#  ..                  ...                   ...                     ...
#  678               False                 False                   False
#  679               False                 False                   False
#  680               False                 False                    True
#  681               False                 False                    True
#  682               False                 False                   False
#  683               False                 False                   False
#  684               False                 False                   False
#  685               False                 False                   False
#  686               False                 False                   False
#  687               False                 False                   False
#  688               False                 False                   False
#  689               False                 False                   False
#  690               False                 False                   False
#  691               False                 False                   False
#  692               False                 False                    True
#  693                True                 False                   False
#  694               False                 False                   False
#  695               False                 False                   False
#  696               False                 False                   False
#  697               False                 False                   False
#  698               False                 False                   False
#  699               False                 False                   False
#  700               False                 False                   False
#  701               False                 False                   False
#  702               False                 False                   False
#  703               False                 False                   False
#  704               False                 False                   False
#  705               False                 False                   False
#  706               False                 False                   False
#  707               False                 False                   False
#
#  [708 rows x 40 columns],
#  'mocha':       issue_id                                              title  \
#  0            1                                        Add tagging
#  1            2                base other reporters on JSON-Stream
#  2            3  Default all to serial / parallel, toggle with ...
#  3            4                             before/after callbacks
#  4            5                                           test cov
#  5            6                                       mutation cov
#  6            7                             finish browser support
#  7            8                             expect(n) and matchers
#  8            9                                      html reporter
#  9           10                                     xunit reporter
#  10          11                 optional parallelism via processes
#  11          12                              global leak reporting
#  12          13  ability to target specific tests / suites for ...
#  13          14               hook for when all tests are complete
#  14          15         ensure passing of flags to node(1) is easy
#  15          17                                   switch to stderr
#  16          18                                       object diffs
#  17          19                                  Fix async support
#  18          20                               TextMate etc support
#  19          21  report errors thrown / uncaught / passed in ho...
#  20          22            hook uncaught exception error reporting
#  21          23        Color duration green/yellow/red accordingly
#  22          24                                 node-growl support
#  23          25                         test for errors/exceptions
#  24          26                                    "spec" reporter
#  25          27                      add support for pending tests
#  26          28                     merge identically named suites
#  27          29                             declarative js example
#  28          30                      cascade [before/after]Each()
#  29          31         consider supporting a test/mocha.opts file
#  ...        ...                                                ...
#  2326      3904       retry does not work with uncaught exceptions
#  2327      3907    Is it possible to parallel run the test cases ?
#  2328      3908          Push required module options not possible
#  2329      3909  Timeout 2000 ms exceeded. for async tests and ...
#  2330      3910                        Soft deprecate "mocha.opts"
#  2331      3911      Soft deprecate comments within "mocharc.json"
#  2332      3912                              Improve file watching
#  2333      3913  new Mocha(options) only honors options.globals...
#  2334      3916     Does the extending configuration feature work?
#  2335      3917  Crashes that happen after test completion are ...
#  2336      3920  Tests teardown is unnecessary delayed (creates...
#  2337      3921       Stacktraces don't filter mocha when minified
#  2338      3923  Can we get a mention in the docs somewhere for...
#  2339      3924                               Pass object to error
#  2340      3925                                          Pass meta
#  2341      3926          Testing interpreter written in JavaScript
#  2342      3928                    Adding data to the Error object
#  2343      3932  Why does describe.skip still execute code in t...
#  2344      3933  Mocha constructor creates duplicate entries in...
#  2345      3935  Specify setup/teardown for each test individually
#  2346      3936  Crash or issue warnings on invalid config para...
#  2347      3938  Uncaught exceptions are silenced if happen in ...
#  2348      3941  No test files found even though one specified ...
#  2349      3943                 migrate to codecov from coveralls?
#  2350      3946                       [feature] introduce subtests
#  2351      3949                    fix: mocha grep RegExp instance
#  2352      3951  regression bug: command line reporter-options ...
#  2353      3954                Mocha exits after await method call
#  2354      3958                             Mocha 4 security issue
#  2355      3959      async await execution crash no error reported
#
#                                                 contents      authorLogin  \
#  0     like visionmedia/expresso#127 something simila...               tj
#  1     this way we could add a --concurrency <n> flag...               tj
#  2     add flag(s) to mocha(1), as well as  interface...               tj
#  3                setup / teardown for TDD interface etc               tj
#  4                           write a proper test cov lib               tj
#  5                                                                     tj
#  6     make sure not to use things that I normally do...               tj
#  7         come up with an interface for TDD etc as well               tj
#  8                                                                     tj
#  9                                                                     tj
#  10                                  for cpu-bound tests               tj
#  11                                   with whitelist etc               tj
#  12                 this would work into tagging as well               tj
#  13    to manually exit the process, kill connections...               tj
#  14                                                                    tj
#  15    output is getting munged quite a bit since nod...               tj
#  16    when loose equality is performed it's pretty a...               tj
#  17           few things breaking, and add more test cov               tj
#  18                                                                    tj
#  19                       "some error in setup hook" etc               tj
#  20                                   map hooks to these               tj
#  21    add thresholds and do this for a few of the re...               tj
#  22                                                                    tj
#  23    The testing for a Method to cause a error woul...             sebs
#  24                                    nesting blah blah               tj
#  25                                                                    tj
#  26    shouldn't have two of the same, this makes it ...               tj
#  27                                                                    tj
#  28    ex:\nvar app;\n\ndescribe('config', function()...               tj
#  29                                       like spec.opts               tj
#  ...                                                 ...              ...
#  2326  mocha 6.1.4\nchai 4.2\nconst {expect} = requir...      ClarkMiaguo
#  2327  There are multiple the separate  JS files, if ...         RyanLiuF
#  2328  For example we use @babel/register.\nIn this m...     martinoppitz
#  2329  describe('POST /startConvo', function(done) { ...        agarkathe
#  2330  Since v6.0.0 "mocha.opts" is considered "legac...          juergba
#  2331  JSON: Create a .mocharc.json (or .mocharc.json...          juergba
#  2332  Is your feature request related to a problem o...    geigerzaehler
#  2333  Prerequisites\n\n\n Checked that your issue ha...         pascalpp
#  2334  Opening this as a question as I'm not yet sure...  calebcartwright
#  2335  Description\nSort of follow up to #3226 which ...          medikoo
#  2336  When running tests in Node.js, to avoid long s...          medikoo
#  2337  Prerequisites\n\n\n Checked that your issue ha...   brian-lagerman
#  2338  Question\nWe have created a wrapper for existi...     silkentrance
#  2339                                                     Chris-Eckersley
#  2340                                                     Chris-Eckersley
#  2341  My question is this, can I use mocha to test s...           jcubic
#  2342  Hello all- awesome code base to read!\nIs ther...  Chris-Eckersley
#  2343  In a test file I have code similar to this:\nd...   oliversalzburg
#  2344  Prerequisites\n\n\n Checked that your issue ha...         pascalpp
#  2345  Is your feature request related to a problem o...          eight04
#  2346  By mistake I've setup a configuration in packa...          medikoo
#  2347  Possibly related to #3740\nSteps to Reproduce\...          medikoo
#  2348  Prerequisites\n\n Checked that your issue hasn...     gabegorelick
#  2349  I like the output codecov.io gives in its inte...        boneskull
#  2350  Is your feature request related to a problem o...         andykais
#  2351  On creating an instance of RegExp if the given...         mrastiak
#  2352  Prerequisites\n\n Checked that your issue hasn...            stalb
#  2353  I have a file with test cases of an async func...       shabin5785
#  2354  Prerequisites\n\n\n Checked that your issue ha...           octref
#  2355  Prerequisites\n\n\n Checked that your issue ha...        adrianwix
#
#       authorAssociation                 createdAt  closed  \
#  0          CONTRIBUTOR 2011-09-01 19:44:41+00:00    True
#  1          CONTRIBUTOR 2011-09-01 19:55:07+00:00    True
#  2          CONTRIBUTOR 2011-09-06 16:41:43+00:00    True
#  3          CONTRIBUTOR 2011-09-06 16:42:29+00:00    True
#  4          CONTRIBUTOR 2011-09-06 16:43:19+00:00    True
#  5          CONTRIBUTOR 2011-09-06 16:43:33+00:00    True
#  6          CONTRIBUTOR 2011-09-06 16:43:59+00:00    True
#  7          CONTRIBUTOR 2011-09-06 16:44:21+00:00    True
#  8          CONTRIBUTOR 2011-09-06 16:44:28+00:00    True
#  9          CONTRIBUTOR 2011-09-06 16:44:33+00:00    True
#  10         CONTRIBUTOR 2011-09-06 16:44:53+00:00    True
#  11         CONTRIBUTOR 2011-09-06 16:45:14+00:00    True
#  12         CONTRIBUTOR 2011-09-06 16:45:37+00:00    True
#  13         CONTRIBUTOR 2011-09-06 16:45:55+00:00    True
#  14         CONTRIBUTOR 2011-09-08 19:21:15+00:00    True
#  15         CONTRIBUTOR 2011-09-13 22:38:08+00:00    True
#  16         CONTRIBUTOR 2011-09-13 22:43:44+00:00    True
#  17         CONTRIBUTOR 2011-09-13 23:59:52+00:00    True
#  18         CONTRIBUTOR 2011-09-14 05:06:40+00:00    True
#  19         CONTRIBUTOR 2011-09-22 07:47:49+00:00    True
#  20         CONTRIBUTOR 2011-09-22 08:03:17+00:00    True
#  21         CONTRIBUTOR 2011-10-04 04:49:46+00:00    True
#  22         CONTRIBUTOR 2011-10-12 15:02:22+00:00    True
#  23                NONE 2011-10-13 08:29:09+00:00    True
#  24         CONTRIBUTOR 2011-11-03 02:48:54+00:00    True
#  25         CONTRIBUTOR 2011-11-03 02:50:27+00:00    True
#  26         CONTRIBUTOR 2011-11-03 04:22:15+00:00    True
#  27         CONTRIBUTOR 2011-11-03 04:22:23+00:00    True
#  28         CONTRIBUTOR 2011-11-08 23:35:36+00:00    True
#  29         CONTRIBUTOR 2011-11-09 02:37:58+00:00    True
#  ...                ...                       ...     ...
#  2326              NONE 2019-05-09 04:10:27+00:00    True
#  2327              NONE 2019-05-10 01:48:48+00:00    True
#  2328              NONE 2019-05-10 16:50:14+00:00    True
#  2329              NONE 2019-05-11 14:05:43+00:00    True
#  2330            MEMBER 2019-05-13 06:12:39+00:00   False
#  2331            MEMBER 2019-05-13 06:22:16+00:00   False
#  2332       CONTRIBUTOR 2019-05-13 19:12:59+00:00   False
#  2333       CONTRIBUTOR 2019-05-13 21:42:39+00:00    True
#  2334              NONE 2019-05-14 23:41:45+00:00   False
#  2335              NONE 2019-05-16 19:25:19+00:00   False
#  2336              NONE 2019-05-17 11:39:53+00:00    True
#  2337       CONTRIBUTOR 2019-05-17 13:18:02+00:00    True
#  2338              NONE 2019-05-17 19:46:50+00:00    True
#  2339              NONE 2019-05-18 15:07:53+00:00    True
#  2340              NONE 2019-05-18 15:09:03+00:00    True
#  2341              NONE 2019-05-20 07:25:54+00:00    True
#  2342              NONE 2019-05-20 17:14:28+00:00    True
#  2343              NONE 2019-05-24 12:34:52+00:00   False
#  2344       CONTRIBUTOR 2019-05-28 16:22:34+00:00    True
#  2345              NONE 2019-05-29 03:56:14+00:00   False
#  2346              NONE 2019-05-29 10:51:55+00:00   False
#  2347              NONE 2019-06-04 13:48:40+00:00   False
#  2348       CONTRIBUTOR 2019-06-05 19:38:34+00:00    True
#  2349            MEMBER 2019-06-05 22:26:35+00:00   False
#  2350              NONE 2019-06-06 18:09:45+00:00   False
#  2351              NONE 2019-06-10 14:07:25+00:00    True
#  2352              NONE 2019-06-11 23:02:20+00:00   False
#  2353              NONE 2019-06-21 04:25:33+00:00    True
#  2354              NONE 2019-06-24 17:30:32+00:00    True
#  2355              NONE 2019-06-25 11:25:39+00:00    True
#
#                        closedAt  closedDuration_days milestone  ...  \
#  0    2011-11-03 04:15:20+00:00                62.35            ...
#  1    2011-11-15 17:31:34+00:00                74.90            ...
#  2    2011-11-03 04:15:11+00:00                57.48            ...
#  3    2011-09-13 23:57:31+00:00                 7.30            ...
#  4    2012-02-24 05:00:34+00:00               170.51            ...
#  5    2015-07-04 21:42:04+00:00              1397.21            ...
#  6    2011-12-23 04:48:10+00:00               107.50            ...
#  7    2011-09-22 06:34:57+00:00                15.58            ...
#  8    2011-11-18 23:48:45+00:00                73.29            ...
#  9    2013-12-13 23:08:12+00:00               829.27            ...
#  10   2011-11-15 17:31:12+00:00                70.03            ...
#  11   2011-10-04 04:45:58+00:00                27.50            ...
#  12   2011-11-03 04:15:41+00:00                57.48            ...
#  13   2011-10-04 04:29:54+00:00                27.49            ...
#  14   2011-11-03 04:15:33+00:00                55.37            ...
#  15   2011-11-03 02:57:35+00:00                50.18            ...
#  16   2011-11-16 23:00:12+00:00                64.01            ...
#  17   2011-09-22 06:56:44+00:00                 8.29            ...
#  18   2011-11-16 22:52:41+00:00                63.74            ...
#  19   2011-09-22 07:56:56+00:00                 0.01            ...
#  20   2011-11-03 04:14:56+00:00                41.84            ...
#  21   2011-10-18 23:47:03+00:00                14.79            ...
#  22   2011-10-18 23:47:02+00:00                 6.36            ...
#  23   2011-10-13 08:29:58+00:00                 0.00            ...
#  24   2011-11-03 03:48:43+00:00                 0.04            ...
#  25   2011-11-03 03:23:55+00:00                 0.02            ...
#  26   2011-11-16 23:50:50+00:00                13.81            ...
#  27   2012-02-03 03:21:24+00:00                91.96            ...
#  28   2011-11-19 23:32:55+00:00                11.00     0.0.1  ...
#  29   2011-11-15 17:54:12+00:00                 6.64            ...
#  ...                        ...                  ...       ...  ...
#  2326 2019-05-10 08:38:13+00:00                 1.19            ...
#  2327 2019-05-12 14:13:33+00:00                 2.52            ...
#  2328 2019-06-17 19:39:33+00:00                38.12            ...
#  2329 2019-05-22 05:52:38+00:00                10.66            ...
#  2330                       NaT                  NaN            ...
#  2331                       NaT                  NaN            ...
#  2332                       NaT                  NaN            ...
#  2333 2019-06-06 05:36:27+00:00                23.33            ...
#  2334                       NaT                  NaN            ...
#  2335                       NaT                  NaN            ...
# ...
#  4                        False             False                   False
#  5                        False             False                   False
#  6                        False             False                   False
#  7                        False             False                   False
#  8                        False              True                   False
#  9                        False             False                   False
#  10                       False             False                   False
#  11                       False             False                   False
#  12                       False             False                   False
#  13                       False             False                   False
#  14                       False             False                   False
#  15                       False             False                   False
#  16                       False             False                   False
#  17                       False             False                   False
#  18                       False             False                   False
#  19                       False             False                   False
#  20                       False             False                   False
#  21                       False             False                   False
#  22                       False             False                   False
#  23                       False              True                   False
#  24                       False             False                   False
#  25                       False              True                   False
#  26                       False             False                   False
#  27                       False             False                   False
#  28                       False             False                   False
#  29                       False             False                   False
#  ...                        ...               ...                     ...
#  3511                     False             False                   False
#  3512                     False             False                   False
#  3513                     False             False                   False
#  3514                     False             False                   False
#  3515                     False             False                   False
#  3516                     False             False                   False
#  3517                     False             False                   False
#  3518                     False             False                   False
#  3519                     False             False                   False
#  3520                     False             False                   False
#  3521                     False             False                   False
#  3522                     False             False                   False
#  3523                     False             False                   False
#  3524                     False             False                   False
#  3525                     False             False                   False
#  3526                     False             False                   False
#  3527                     False             False                   False
#  3528                     False             False                   False
#  3529                     False             False                   False
#  3530                     False             False                   False
#  3531                     False             False                   False
#  3532                     False             False                   False
#  3533                     False             False                   False
#  3534                     False             False                   False
#  3535                     False             False                   False
#  3536                     False             False                   False
#  3537                     False             False                   False
#  3538                     False             False                   False
#  3539                     False             False                   False
#  3540                     False             False                   False
#
#       label_topic: visibility 👁  label_topic: drag-and-drop  \
#  0                        False                       False
#  1                        False                       False
#  2                        False                       False
#  3                        False                       False
#  4                        False                       False
#  5                        False                       False
#  6                        False                       False
#  7                        False                       False
#  8                        False                       False
#  9                        False                       False
#  10                       False                       False
#  11                       False                       False
#  12                       False                       False
#  13                       False                       False
#  14                       False                       False
#  15                       False                       False
#  16                       False                       False
#  17                       False                       False
#  18                       False                       False
#  19                       False                       False
#  20                       False                       False
#  21                       False                       False
#  22                       False                       False
#  23                       False                       False
#  24                       False                       False
#  25                       False                       False
#  26                       False                       False
#  27                       False                       False
#  28                       False                       False
#  29                       False                       False
#  ...                        ...                         ...
#  3511                     False                       False
#  3512                     False                       False
#  3513                     False                       False
#  3514                     False                       False
#  3515                     False                       False
#  3516                     False                       False
#  3517                     False                       False
#  3518                     False                       False
#  3519                     False                       False
#  3520                     False                       False
#  3521                     False                       False
#  3522                     False                       False
#  3523                     False                       False
#  3524                     False                       False
#  3525                     False                       False
#  3526                     False                       False
#  3527                     False                       False
#  3528                     False                       False
#  3529                     False                       False
#  3530                     False                       False
#  3531                     False                       False
#  3532                     False                       False
#  3533                     False                       False
#  3534                     False                       False
#  3535                     False                       False
#  3536                     False                       False
#  3537                     False                       False
#  3538                     False                       False
#  3539                     False                       False
#  3540                     False                       False
#
#        label_external: documentation  label_topic: actionability  \
#  0                             False                       False
#  1                             False                       False
#  2                             False                       False
#  3                             False                       False
#  4                             False                       False
#  5                             False                       False
#  6                             False                       False
#  7                             False                       False
#  8                             False                       False
#  9                             False                       False
#  10                            False                       False
#  11                            False                       False
#  12                            False                       False
#  13                            False                       False
#  14                            False                       False
#  15                            False                       False
#  16                            False                       False
#  17                            False                       False
#  18                            False                       False
#  19                            False                       False
#  20                            False                       False
#  21                            False                       False
#  22                            False                       False
#  23                            False                       False
#  24                            False                       False
#  25                            False                       False
#  26                            False                       False
#  27                            False                       False
#  28                            False                       False
#  29                            False                       False
#  ...                             ...                         ...
#  3511                          False                       False
#  3512                          False                       False
#  3513                          False                       False
#  3514                          False                       False
#  3515                          False                       False
#  3516                          False                       False
#  3517                          False                       False
#  3518                          False                       False
#  3519                          False                       False
#  3520                          False                       False
#  3521                          False                       False
#  3522                          False                       False
#  3523                          False                       False
#  3524                          False                       False
#  3525                          False                       False
#  3526                          False                       False
#  3527                          False                       False
#  3528                          False                       False
#  3529                          False                       False
#  3530                          False                       False
#  3531                          False                       False
#  3532                          False                       False
#  3533                          False                       False
#  3534                          False                       False
#  3535                          False                       False
#  3536                          False                       False
#  3537                          False                       False
#  3538                          False                       False
#  3539                          False                       False
#  3540                          False                       False
#
#        label_topic: aw snap :slightly_frowning_face:
#  0                                             False
#  1                                             False
#  2                                             False
#  3                                             False
#  4                                             False
#  5                                             False
#  6                                             False
#  7                                             False
#  8                                             False
#  9                                             False
#  10                                            False
#  11                                            False
#  12                                            False
#  13                                            False
#  14                                            False
#  15                                            False
#  16                                            False
#  17                                            False
#  18                                            False
#  19                                            False
#  20                                            False
#  21                                            False
#  22                                            False
#  23                                            False
#  24                                            False
#  25                                            False
#  26                                            False
#  27                                            False
#  28                                            False
#  29                                            False
#  ...                                             ...
#  3511                                          False
#  3512                                          False
#  3513                                          False
#  3514                                          False
#  3515                                          False
#  3516                                          False
#  3517                                          False
#  3518                                          False
#  3519                                          False
#  3520                                          False
#  3521                                          False
#  3522                                          False
#  3523                                          False
#  3524                                          False
#  3525                                          False
#  3526                                          False
#  3527                                          False
#  3528                                          False
#  3529                                          False
#  3530                                          False
#  3531                                          False
#  3532                                          False
#  3533                                          False
#  3534                                          False
#  3535                                          False
#  3536                                          False
#  3537                                          False
#  3538                                          False
#  3539                                          False
#  3540                                          False
#
#  [3541 rows x 144 columns]}

# %%
cols_final_no_encoding = [
        'repo',
        'issue_id',
        'title',
        'contents',
        'authorLogin',
        'authorAssociation',
        'createdAt',
        'closed',
        'closedAt',        
        'closedDuration_days',
        'milestone',
        'participants_count',
        'comments_count',
        'firstCommentCreatedAt',
        'firstCommentDuration_days',
        'firstCommentAuthor',
        'firstCommentAuthorAssociation',
        'num_unique_comment_author_MEMBER',
        'num_unique_comment_author_CONTRIBUTOR',
        'num_unique_comment_author_COLLABORATOR',
        'num_unique_comment_author_NONE',
        'labels'
];

df_combined = pd.DataFrame(columns=cols_final_no_encoding)

for cur_lib in list_libs:
    df_temp = all_df[cur_lib]
    df_temp['repo'] = cur_lib
    
    df_combined = pd.concat([df_combined, df_temp[cols_final_no_encoding]], ignore_index=True)

# %%
# Save the combinded dataframe to xlsx
save_df_to_xlsx(df_combined, 'temp/repo_issue_summary_combined.xlsx')
