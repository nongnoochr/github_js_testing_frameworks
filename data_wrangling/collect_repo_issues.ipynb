# %% [markdown]
# # Collect data of issues in github repositories

# %%
import json
import time
import datetime

import pandas as pd
import numpy as np

import requests
import re
from collections import OrderedDict

# %% [markdown]
# ### Gather data via GitHub's GraphQL

# %%
# # See how to get a token here: https://github.blog/2013-05-16-personal-api-tokens/
api_token = "<Your Token>"

headers = {'Authorization': 'token %s' % api_token}

# %%
def run_query(query): 
    ''' A simple function to use requests.post to make the API call. Note the json= section. '''
    
    request = requests.post('https://api.github.com/graphql', json={'query': query}, headers=headers)
    if request.status_code == 200:
        return request.json()
    else:
        raise Exception("Query failed to run by returning code of {}. {}".format(request.status_code, query))

# %%
# Create a GraphQL query that we will use to collect data        
def create_query(repo_name, hasNextPage=True, afterCursor=None):
    
    if hasNextPage and afterCursor:
        strAfter = ' after:"{}",'.format(afterCursor)
    else:
        strAfter = ''
        
    query = '''
    {
      rateLimit {
        cost
        remaining
        resetAt
      }
      search(first: 50,%s type: ISSUE, query: "repo:%s is:issue") {
        issueCount
        pageInfo {
          hasNextPage
          endCursor
        }
        edges {
          node {
            ... on Issue {
              number
              title
              url
              createdAt
              updatedAt
              closedAt
              state
              closed
              locked
              author {
                login
              }
              authorAssociation
              participants(first:50) {
                totalCount
                nodes {
                  login
                  company
                }
              }
              comments(first:50) {
                totalCount
                nodes {
                  author {
                    login
                  }
                  authorAssociation
                  createdAt
                  bodyText
                }
              }
              labels(first:50) {
                nodes {
                  name
                }
              }
              activeLockReason
            }
          }
        }
      }
    }
    ''' % (strAfter, repo_name)
    
    return query

# %%
query = create_query("bitovi/funcunit")
# Get a result of the test query
result = run_query(query) # Execute the query
remaining_rate_limit = result["data"]["rateLimit"]["remaining"] # Drill down the dictionary
print("Remaining rate limit - {}".format(remaining_rate_limit))
# Out:
# Remaining rate limit - 4999

# %%
result
# Out:
# {'data': {'rateLimit': {'cost': 1,
#    'remaining': 4999,
#    'resetAt': '2019-07-02T04:01:46Z'},
#   'search': {'issueCount': 151,
#    'pageInfo': {'hasNextPage': True, 'endCursor': 'Y3Vyc29yOjUw'},
#    'edges': [{'node': {'number': 246,
#       'title': 'invalid usage of delete operator',
#       'url': 'https://github.com/bitovi/funcunit/issues/246',
#       'createdAt': '2019-05-29T04:20:32Z',
#       'updatedAt': '2019-05-30T17:31:52Z',
#       'closedAt': None,
#       'state': 'OPEN',
#       'closed': False,
#       'locked': False,
#       'author': {'login': 'koalixCZ'},
#       'authorAssociation': 'NONE',
#       'participants': {'totalCount': 3,
#        'nodes': [{'login': 'koalixCZ', 'company': None},
#         {'login': 'matthewp', 'company': 'Bitovi'},
#         {'login': 'chasenlehara', 'company': '@bitovi'}]},
#       'comments': {'totalCount': 1,
#        'nodes': [{'author': {'login': 'matthewp'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2019-05-29T10:22:22Z',
#          'bodyText': 'Probably should set it to null instead'}]},
#       'labels': {'nodes': [{'name': 'bug'},
#         {'name': 'help wanted'},
#         {'name': 'p2'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 242,
#       'title': "You can't run getters after actions and waits. Please put your getters in a callback or at the beginning of the test.",
#       'url': 'https://github.com/bitovi/funcunit/issues/242',
#       'createdAt': '2019-04-24T00:57:40Z',
#       'updatedAt': '2019-04-25T01:21:58Z',
#       'closedAt': '2019-04-24T15:39:35Z',
#       'state': 'CLOSED',
#       'closed': True,
#       'locked': False,
#       'author': {'login': 'beshoo'},
#       'authorAssociation': 'NONE',
#       'participants': {'totalCount': 2,
#        'nodes': [{'login': 'beshoo', 'company': None},
#         {'login': 'chasenlehara', 'company': '@bitovi'}]},
#       'comments': {'totalCount': 2,
#        'nodes': [{'author': {'login': 'chasenlehara'},
#          'authorAssociation': 'MEMBER',
#          'createdAt': '2019-04-24T15:39:35Z',
#          'bodyText': 'That error is thrown here: \n  \n    \n      funcunit/browser/getters.js\n    \n    \n         Line 557\n      in\n      f9e31a3\n    \n    \n    \n    \n\n        \n          \n           console && console.error("You can\'t run getters after actions and waits. Please put your getters in a callback or at the beginning of the test.") \n        \n    \n  \n\n\nFuncUnit is built for running tests for your own site, not simulating actions on another site. I believe the way you’re trying to use it is unsupported.'},
#         {'author': {'login': 'beshoo'},
#          'authorAssociation': 'NONE',
#          'createdAt': '2019-04-25T01:21:58Z',
#          'bodyText': 'No that not the case, we are testing on our account...\nAnd i know that the  thrown place, but how to use gater in correct way?'}]},
#       'labels': {'nodes': []},
#       'activeLockReason': None}},
#     {'node': {'number': 238,
#       'title': 'Lint all the files',
#       'url': 'https://github.com/bitovi/funcunit/issues/238',
#       'createdAt': '2019-04-10T19:18:29Z',
#       'updatedAt': '2019-04-10T19:18:29Z',
#       'closedAt': None,
#       'state': 'OPEN',
#       'closed': False,
#       'locked': False,
#       'author': {'login': 'chasenlehara'},
#       'authorAssociation': 'MEMBER',
#       'participants': {'totalCount': 1,
#        'nodes': [{'login': 'chasenlehara', 'company': '@bitovi'}]},
#       'comments': {'totalCount': 0, 'nodes': []},
#       'labels': {'nodes': [{'name': 'cleanup'}, {'name': 'help wanted'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 236,
#       'title': 'jQuery is not defined',
#       'url': 'https://github.com/bitovi/funcunit/issues/236',
#       'createdAt': '2019-03-14T18:35:56Z',
#       'updatedAt': '2019-03-15T12:51:52Z',
#       'closedAt': None,
#       'state': 'OPEN',
#       'closed': False,
#       'locked': False,
#       'author': {'login': 'kdillon'},
#       'authorAssociation': 'CONTRIBUTOR',
#       'participants': {'totalCount': 3,
#        'nodes': [{'login': 'kdillon', 'company': 'MathWorks'},
#         {'login': 'chasenlehara', 'company': '@bitovi'},
#         {'login': 'matthewp', 'company': 'Bitovi'}]},
#       'comments': {'totalCount': 4,
#        'nodes': [{'author': {'login': 'chasenlehara'},
#          'authorAssociation': 'MEMBER',
#          'createdAt': '2019-03-14T18:54:46Z',
#          'bodyText': "A little more info… here’s what the built file looks like:\ndefine('global', function (require, exports, module) {\n    require('funcunit');\n    var FuncUnit = window.FuncUnit || {};\n    window.jQuery = jQuery;\n    module.exports = FuncUnit;\n});\nI put a debugger statement before window.jQuery = jQuery to see the value of jQuery\n\n3.5.0: jQuery is undefined\n3.6.2: jQuery isn’t defined, hence the reference error"},
#         {'author': {'login': 'matthewp'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2019-03-14T20:13:40Z',
#          'bodyText': "Sounds like the global module is wrong then. I don't know where this module is but if it wants to set jQuery on the window it should be importing it from within FuncUnit now.\nHaving jQuery be a global in the non-global build was a longstanding cause of pain for people."},
#         {'author': {'login': 'chasenlehara'},
#          'authorAssociation': 'MEMBER',
#          'createdAt': '2019-03-14T21:37:09Z',
#          'bodyText': 'Here’s that issue I think: Do not set window.jQuery\nI think this is the global module: https://github.com/bitovi/funcunit/blob/master/global.js\nIs the solution to add var jQuery = require("funcunit/browser/jquery"); to the global build?\nOr should this line: \n  \n    \n      funcunit/global.js\n    \n    \n         Line 4\n      in\n      bbc3c16\n    \n    \n    \n    \n\n        \n          \n           window.jQuery = jQuery; \n        \n    \n  \n\n\n…be changed to:\nwindow.jQuery = FuncUnit.jQuery;\n…or should the global build not set window.jQuery at all?\nI’m not familiar with how FuncUnit is supposed to work with its own version of jQuery vs. imported versions, hence the uncertainty on my end. 😬'},
#         {'author': {'login': 'matthewp'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2019-03-15T12:51:52Z',
#          'bodyText': "I'd say not set window.jQuery at all. FuncUnit uses it internally, but uses its own version now that is gets through the module loader. So I don't think setting window.jQuery is a good idea. The reason for getting rid of it was that it interfered with other jQuerys on the page."}]},
#       'labels': {'nodes': []},
#       'activeLockReason': None}},
#     {'node': {'number': 234,
#       'title': "Can't do async operations in QUnit2 before/after hooks",
#       'url': 'https://github.com/bitovi/funcunit/issues/234',
#       'createdAt': '2019-02-08T15:51:23Z',
#       'updatedAt': '2019-02-14T20:32:00Z',
#       'closedAt': None,
#       'state': 'OPEN',
#       'closed': False,
#       'locked': False,
#       'author': {'login': 'smcclure15'},
#       'authorAssociation': 'NONE',
#       'participants': {'totalCount': 1,
#        'nodes': [{'login': 'smcclure15', 'company': '@MathWorks'}]},
#       'comments': {'totalCount': 0, 'nodes': []},
#       'labels': {'nodes': []},
#       'activeLockReason': None}},
#     {'node': {'number': 232,
#       'title': 'dist folder not included on npm',
#       'url': 'https://github.com/bitovi/funcunit/issues/232',
#       'createdAt': '2019-01-09T17:59:40Z',
#       'updatedAt': '2019-01-25T16:08:36Z',
#       'closedAt': '2019-01-25T16:08:36Z',
#       'state': 'CLOSED',
#       'closed': True,
#       'locked': False,
#       'author': {'login': 'danielhusar'},
#       'authorAssociation': 'NONE',
#       'participants': {'totalCount': 3,
#        'nodes': [{'login': 'danielhusar', 'company': '@intercom'},
#         {'login': 'cherifGsoul', 'company': 'Interactive Bits'},
#         {'login': 'chasenlehara', 'company': '@bitovi'}]},
#       'comments': {'totalCount': 1,
#        'nodes': [{'author': {'login': 'cherifGsoul'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2019-01-15T19:29:13Z',
#          'bodyText': 'Fixed and released'}]},
#       'labels': {'nodes': [{'name': 'p1'}, {'name': 'regression'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 229,
#       'title': 'Make FuncUnit use async/await rather than a queue system',
#       'url': 'https://github.com/bitovi/funcunit/issues/229',
#       'createdAt': '2018-11-01T16:23:51Z',
#       'updatedAt': '2018-11-01T16:40:11Z',
#       'closedAt': None,
#       'state': 'OPEN',
#       'closed': False,
#       'locked': False,
#       'author': {'login': 'matthewp'},
#       'authorAssociation': 'CONTRIBUTOR',
#       'participants': {'totalCount': 2,
#        'nodes': [{'login': 'matthewp', 'company': 'Bitovi'},
#         {'login': 'justinbmeyer', 'company': 'Bitovi'}]},
#       'comments': {'totalCount': 1,
#        'nodes': [{'author': {'login': 'justinbmeyer'},
#          'authorAssociation': 'MEMBER',
#          'createdAt': '2018-11-01T16:40:11Z',
#          'bodyText': 'I\'d also like to throw in making it very functional.\nimport FuncUnit as F from "funcunit"\n\ntest(async function(){\n  await F.click( querySelector("#button") )\n  await F.textContent( querySelector("#details"), "Hi there" )\n  assert(true, "text is hi there")\n})\nF would just expose functions that return promises.  await use would be expected.  We\'d have functions that would be similar to what we have now, but more DOM-focused APIs and less jQuery-focused APIs:\n\ntextContent instead of text\ninnerHTML instead of html\nvalue instead val\n\nI think we could get rid of many traversal methods. For example\nawait F.click( querySelector("#button") )\nawait F.textContent( querySelector("#details").parentNode , "Hi there" )\nassert(true, "text is hi there")\nThough we still might want some form of "wait" with traversal:\nawait F.click( querySelector("#button") )\n\ndetails = await F.querySelector("#details")\nchild = await F.querySelector(child, ".someElement"); // obviously this could be done with one call\nawait F.textContent( child, "Hi there" )\nassert(true, "text is hi there")'}]},
#       'labels': {'nodes': []},
#       'activeLockReason': None}},
#     {'node': {'number': 228,
#       'title': 'Remove the dependency on jquery',
#       'url': 'https://github.com/bitovi/funcunit/issues/228',
#       'createdAt': '2018-11-01T16:23:01Z',
#       'updatedAt': '2018-11-01T16:23:01Z',
#       'closedAt': None,
#       'state': 'OPEN',
#       'closed': False,
#       'locked': False,
#       'author': {'login': 'matthewp'},
#       'authorAssociation': 'CONTRIBUTOR',
#       'participants': {'totalCount': 1,
#        'nodes': [{'login': 'matthewp', 'company': 'Bitovi'}]},
#       'comments': {'totalCount': 0, 'nodes': []},
#       'labels': {'nodes': []},
#       'activeLockReason': None}},
#     {'node': {'number': 224,
#       'title': 'FuncUnit + iframe: click() on link (<a>) tage produces false positive. ',
#       'url': 'https://github.com/bitovi/funcunit/issues/224',
#       'createdAt': '2018-06-08T20:40:05Z',
#       'updatedAt': '2018-06-13T20:12:56Z',
#       'closedAt': '2018-06-13T20:12:56Z',
#       'state': 'CLOSED',
#       'closed': True,
#       'locked': False,
#       'author': {'login': 'pawanpe'},
#       'authorAssociation': 'NONE',
#       'participants': {'totalCount': 1,
#        'nodes': [{'login': 'pawanpe', 'company': None}]},
#       'comments': {'totalCount': 1,
#        'nodes': [{'author': {'login': 'pawanpe'},
#          'authorAssociation': 'NONE',
#          'createdAt': '2018-06-13T20:12:56Z',
#          'bodyText': 'Closing this. I got this working with querying specific elements with index values.'}]},
#       'labels': {'nodes': []},
#       'activeLockReason': None}},
#     {'node': {'number': 223,
#       'title': 'Failure while using F.attach(Qunit)',
#       'url': 'https://github.com/bitovi/funcunit/issues/223',
#       'createdAt': '2018-05-18T09:08:47Z',
#       'updatedAt': '2018-06-25T14:29:07Z',
#       'closedAt': '2018-06-25T14:29:07Z',
#       'state': 'CLOSED',
#       'closed': True,
#       'locked': False,
#       'author': {'login': 'mgarg1'},
#       'authorAssociation': 'NONE',
#       'participants': {'totalCount': 2,
#        'nodes': [{'login': 'mgarg1', 'company': None},
#         {'login': 'chasenlehara', 'company': '@bitovi'}]},
#       'comments': {'totalCount': 2,
#        'nodes': [{'author': {'login': 'chasenlehara'},
#          'authorAssociation': 'MEMBER',
#          'createdAt': '2018-05-18T15:57:32Z',
#          'bodyText': 'I think this is the line that needs to be updated: \n  \n    \n      funcunit/browser/adapters/qunit2.js\n    \n    \n         Line 17\n      in\n      7ec6932\n    \n    \n    \n    \n\n        \n          \n           return test.apply(this, arugments); \n        \n    \n  \n\n\n@mgarg1 Would you be willing to submit a PR that fixes that line?'},
#         {'author': {'login': 'mgarg1'},
#          'authorAssociation': 'NONE',
#          'createdAt': '2018-05-23T09:25:09Z',
#          'bodyText': '@chasenlehara  The issue is very complex then fixing this line. After fixing that line to :\n return test.apply(this,(arguments === undefined ? assert : arguments));\nI am seeing the failure in the same module at line 8879 which is because of the currentTestAssert is not being assigned prior to the execution of before hook.\n<!DOCTYPE html>\n<html>\n<head>\n  <meta charset="utf-8">\n  <meta name="viewport" content="width=device-width">\n  <title>QUnit Example</title>\n  <link rel="stylesheet" href="https://code.jquery.com/qunit/qunit-2.6.1.css">\n</head>\n<body>\n  <div id="qunit"></div>\n  <div id="qunit-fixture"></div>\n  <script src="https://code.jquery.com/qunit/qunit-2.6.1.js"></script>\n  <script type="text/javascript" src="https://rawgit.com/bitovi/funcunit/v3.4.2/dist/funcunit.js"></script>\n\n  <script type="text/javascript">\n    F.attach(QUnit);\n\n    QUnit.module("MainTestModule", {\n        before: function()\n        {\n            console.log("In Before");\n            F.open("google.com",function(){});\n        }\n    });\n    \n    QUnit.test( "hello test", function( assert ) {\n      assert.ok( 1 == "1", "Passed!" );\n    });\n  \n  </script>\n</body>\n</html>\n\nThe adapter is taking care of the case when a test is executed but it fails to capture the correct assert when hooks are executed.In order to fix this issue just changing the QUnit.test won\'t suffice. We need to somehow do the same for module hooks.'}]},
#       'labels': {'nodes': []},
#       'activeLockReason': None}},
#     {'node': {'number': 220,
#       'title': 'dist folder not included on npm',
#       'url': 'https://github.com/bitovi/funcunit/issues/220',
#       'createdAt': '2017-10-16T18:52:44Z',
#       'updatedAt': '2017-10-24T15:51:39Z',
#       'closedAt': '2017-10-24T15:51:39Z',
#       'state': 'CLOSED',
#       'closed': True,
#       'locked': False,
#       'author': {'login': 'chasenlehara'},
#       'authorAssociation': 'MEMBER',
#       'participants': {'totalCount': 2,
#        'nodes': [{'login': 'chasenlehara', 'company': '@bitovi'},
#         {'login': 'mckenna', 'company': 'Intercom'}]},
#       'comments': {'totalCount': 4,
#        'nodes': [{'author': {'login': 'mckenna'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2017-10-23T23:03:44Z',
#          'bodyText': "I'd love to help with this. Currently blocked from upgrading from v3.0.0 (the last version to include dist/ in source). The preversion script should be run via the npm lifecycle hooks.\nI don't have a tonne of experience working with npm, but I cloned the repository and published  funcunit to my own namespace to see what happens. When I published, I noticed that the preversion script never ran. Do you have any visibility on whether this script runs for you on publish?"},
#         {'author': {'login': 'chasenlehara'},
#          'authorAssociation': 'MEMBER',
#          'createdAt': '2017-10-23T23:23:27Z',
#          'bodyText': 'Thanks for the help @mckenna, it’s really appreciated!\npreversionshould definitely run; I thought I did when I tried republishing last week.\nI’ve been looking at can-param for reference because it does publish dist correctly. These npm scripts look the same to me as what FuncUnit has, but I just noticed that the repo has a .npmignore file and this FuncUnit repo doesn’t.\nWould you mind adding that file to your test repo and republishing? If it works and you could submit a PR, I can get it merged and released today.'},
#         {'author': {'login': 'mckenna'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2017-10-24T06:25:35Z',
#          'bodyText': "Good call. I added the .npmignore file to my test repo and when I deployed it, the dist/ folder was included. I've submitted a PR to include it."},
#         {'author': {'login': 'chasenlehara'},
#          'authorAssociation': 'MEMBER',
#          'createdAt': '2017-10-24T15:51:39Z',
#          'bodyText': 'Just published v3.4.4 with your fix. Thank you @mckenna!'}]},
#       'labels': {'nodes': [{'name': 'help wanted'}, {'name': 'p1'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 219,
#       'title': 'Advertise the community survey on funcunit.com',
#       'url': 'https://github.com/bitovi/funcunit/issues/219',
#       'createdAt': '2017-09-11T22:14:16Z',
#       'updatedAt': '2017-09-18T01:44:57Z',
#       'closedAt': '2017-09-18T01:44:57Z',
#       'state': 'CLOSED',
#       'closed': True,
#       'locked': False,
#       'author': {'login': 'chasenlehara'},
#       'authorAssociation': 'MEMBER',
#       'participants': {'totalCount': 1,
#        'nodes': [{'login': 'chasenlehara', 'company': '@bitovi'}]},
#       'comments': {'totalCount': 1,
#        'nodes': [{'author': {'login': 'chasenlehara'},
#          'authorAssociation': 'MEMBER',
#          'createdAt': '2017-09-18T01:44:57Z',
#          'bodyText': 'Closing this because we won’t have questions on the survey related to this project.'}]},
#       'labels': {'nodes': [{'name': 'developer relations'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 218,
#       'title': 'how can i install funcit from github?',
#       'url': 'https://github.com/bitovi/funcunit/issues/218',
#       'createdAt': '2017-07-25T19:07:58Z',
#       'updatedAt': '2017-07-25T20:44:38Z',
#       'closedAt': '2017-07-25T20:44:38Z',
#       'state': 'CLOSED',
#       'closed': True,
#       'locked': False,
#       'author': {'login': 'debajyoti3061'},
#       'authorAssociation': 'NONE',
#       'participants': {'totalCount': 2,
#        'nodes': [{'login': 'debajyoti3061', 'company': None},
#         {'login': 'chasenlehara', 'company': '@bitovi'}]},
#       'comments': {'totalCount': 1,
#        'nodes': [{'author': {'login': 'chasenlehara'},
#          'authorAssociation': 'MEMBER',
#          'createdAt': '2017-07-25T20:44:38Z',
#          'bodyText': 'Hi @debajyoti3061, https://github.com/jupiterjs/funcit is no longer actively maintained and no one is supporting it.'}]},
#       'labels': {'nodes': []},
#       'activeLockReason': None}},
#     {'node': {'number': 215,
#       'title': 'Set up Google Analytics',
#       'url': 'https://github.com/bitovi/funcunit/issues/215',
#       'createdAt': '2017-07-18T23:36:15Z',
#       'updatedAt': '2017-07-20T15:47:06Z',
#       'closedAt': '2017-07-20T15:47:06Z',
#       'state': 'CLOSED',
#       'closed': True,
#       'locked': False,
#       'author': {'login': 'chasenlehara'},
#       'authorAssociation': 'MEMBER',
#       'participants': {'totalCount': 1,
#        'nodes': [{'login': 'chasenlehara', 'company': '@bitovi'}]},
#       'comments': {'totalCount': 0, 'nodes': []},
#       'labels': {'nodes': [{'name': 'developer relations'},
#         {'name': 'website'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 213,
#       'title': 'Test against Node 8',
#       'url': 'https://github.com/bitovi/funcunit/issues/213',
#       'createdAt': '2017-06-28T16:11:11Z',
#       'updatedAt': '2018-06-22T23:43:15Z',
#       'closedAt': '2018-06-22T23:43:15Z',
#       'state': 'CLOSED',
#       'closed': True,
#       'locked': False,
#       'author': {'login': 'andrejewski'},
#       'authorAssociation': 'CONTRIBUTOR',
#       'participants': {'totalCount': 1,
#        'nodes': [{'login': 'andrejewski', 'company': '@stripe'}]},
#       'comments': {'totalCount': 0, 'nodes': []},
#       'labels': {'nodes': []},
#       'activeLockReason': None}},
#     {'node': {'number': 211,
#       'title': 'Function.caller does not work strict mode',
#       'url': 'https://github.com/bitovi/funcunit/issues/211',
#       'createdAt': '2017-06-28T15:47:15Z',
#       'updatedAt': '2017-06-28T18:39:03Z',
#       'closedAt': '2017-06-28T18:39:03Z',
#       'state': 'CLOSED',
#       'closed': True,
#       'locked': False,
#       'author': {'login': 'andrejewski'},
#       'authorAssociation': 'CONTRIBUTOR',
#       'participants': {'totalCount': 1,
#        'nodes': [{'login': 'andrejewski', 'company': '@stripe'}]},
#       'comments': {'totalCount': 0, 'nodes': []},
#       'labels': {'nodes': []},
#       'activeLockReason': None}},
#     {'node': {'number': 210,
#       'title': 'CI Failing',
#       'url': 'https://github.com/bitovi/funcunit/issues/210',
#       'createdAt': '2017-06-28T14:25:50Z',
#       'updatedAt': '2017-06-28T16:11:36Z',
#       'closedAt': '2017-06-28T16:11:36Z',
#       'state': 'CLOSED',
#       'closed': True,
#       'locked': False,
#       'author': {'login': 'andrejewski'},
#       'authorAssociation': 'CONTRIBUTOR',
#       'participants': {'totalCount': 1,
#        'nodes': [{'login': 'andrejewski', 'company': '@stripe'}]},
#       'comments': {'totalCount': 1,
#        'nodes': [{'author': {'login': 'andrejewski'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2017-06-28T16:11:36Z',
#          'bodyText': 'Closed by #212, however Node 8 should be supported so the issue #213 addresses that.'}]},
#       'labels': {'nodes': [{'name': 'p0'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 208,
#       'title': 'Add a Press Kit page',
#       'url': 'https://github.com/bitovi/funcunit/issues/208',
#       'createdAt': '2017-06-27T14:04:12Z',
#       'updatedAt': '2017-06-27T14:04:12Z',
#       'closedAt': None,
#       'state': 'OPEN',
#       'closed': False,
#       'locked': False,
#       'author': {'login': 'chasenlehara'},
#       'authorAssociation': 'MEMBER',
#       'participants': {'totalCount': 2,
#        'nodes': [{'login': 'chasenlehara', 'company': '@bitovi'},
#         {'login': 'jamiemccue', 'company': 'Architexture'}]},
#       'comments': {'totalCount': 0, 'nodes': []},
#       'labels': {'nodes': [{'name': 'design'},
#         {'name': 'developer relations'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 207,
#       'title': 'Set up SauceLabs for browser testing',
#       'url': 'https://github.com/bitovi/funcunit/issues/207',
#       'createdAt': '2017-05-11T15:18:28Z',
#       'updatedAt': '2017-05-31T14:29:08Z',
#       'closedAt': None,
#       'state': 'OPEN',
#       'closed': False,
#       'locked': False,
#       'author': {'login': 'phillipskevin'},
#       'authorAssociation': 'CONTRIBUTOR',
#       'participants': {'totalCount': 3,
#        'nodes': [{'login': 'phillipskevin', 'company': 'Bitovi'},
#         {'login': 'morrme', 'company': None},
#         {'login': 'chasenlehara', 'company': '@bitovi'}]},
#       'comments': {'totalCount': 3,
#        'nodes': [{'author': {'login': 'morrme'},
#          'authorAssociation': 'NONE',
#          'createdAt': '2017-05-30T22:46:26Z',
#          'bodyText': '@phillipskevin can I try this one?'},
#         {'author': {'login': 'phillipskevin'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2017-05-31T14:26:57Z',
#          'bodyText': "Yeah, definitely. I'll assign it to you, @morrme."},
#         {'author': {'login': 'phillipskevin'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2017-05-31T14:29:08Z',
#          'bodyText': "Ok, I can't assign it to you, but it's all yours."}]},
#       'labels': {'nodes': [{'name': 'developer relations'},
#         {'name': 'help wanted'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 206,
#       'title': 'Throws error when using the click method on the document',
#       'url': 'https://github.com/bitovi/funcunit/issues/206',
#       'createdAt': '2017-05-09T02:49:48Z',
#       'updatedAt': '2017-05-12T00:36:30Z',
#       'closedAt': '2017-05-12T00:36:30Z',
#       'state': 'CLOSED',
#       'closed': True,
#       'locked': False,
#       'author': {'login': 'imaustink'},
#       'authorAssociation': 'CONTRIBUTOR',
#       'participants': {'totalCount': 3,
#        'nodes': [{'login': 'imaustink', 'company': '@bitovi '},
#         {'login': 'chasenlehara', 'company': '@bitovi'},
#         {'login': 'justinbmeyer', 'company': 'Bitovi'}]},
#       'comments': {'totalCount': 3,
#        'nodes': [{'author': {'login': 'chasenlehara'},
#          'authorAssociation': 'MEMBER',
#          'createdAt': '2017-05-09T16:39:25Z',
#          'bodyText': 'That looks like an issue in Syn, is it not?'},
#         {'author': {'login': 'justinbmeyer'},
#          'authorAssociation': 'MEMBER',
#          'createdAt': '2017-05-09T16:51:31Z',
#          'bodyText': 'Try on the document.documentElement or document.body then.'},
#         {'author': {'login': 'imaustink'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2017-05-12T00:36:30Z',
#          'bodyText': 'Issue moved to bitovi/syn #140 via ZenHub'}]},
#       'labels': {'nodes': [{'name': 'bug'},
#         {'name': 'help wanted'},
#         {'name': 'p1'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 201,
#       'title': 'Provide a range of jQuery versions',
#       'url': 'https://github.com/bitovi/funcunit/issues/201',
#       'createdAt': '2017-04-17T16:55:17Z',
#       'updatedAt': '2017-04-17T16:55:17Z',
#       'closedAt': None,
#       'state': 'OPEN',
#       'closed': False,
#       'locked': False,
#       'author': {'login': 'mickmcgrath13'},
#       'authorAssociation': 'CONTRIBUTOR',
#       'participants': {'totalCount': 1,
#        'nodes': [{'login': 'mickmcgrath13', 'company': 'Bitovi'}]},
#       'comments': {'totalCount': 0, 'nodes': []},
#       'labels': {'nodes': []},
#       'activeLockReason': None}},
#     {'node': {'number': 200,
#       'title': "System.import funcunit somehow stops qunit's beforeEach hook to run",
#       'url': 'https://github.com/bitovi/funcunit/issues/200',
#       'createdAt': '2017-04-12T21:58:11Z',
#       'updatedAt': '2017-04-17T14:56:20Z',
#       'closedAt': None,
#       'state': 'OPEN',
#       'closed': False,
#       'locked': False,
#       'author': {'login': 'mickmcgrath13'},
#       'authorAssociation': 'CONTRIBUTOR',
#       'participants': {'totalCount': 2,
#        'nodes': [{'login': 'mickmcgrath13', 'company': 'Bitovi'},
#         {'login': 'matthewp', 'company': 'Bitovi'}]},
#       'comments': {'totalCount': 11,
#        'nodes': [{'author': {'login': 'mickmcgrath13'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2017-04-12T22:03:26Z',
#          'bodyText': "Here's a branch with some tests: https://github.com/bitovi/funcunit/tree/200-system-import-funcunit\nThis passes: ES6 Import ( html file )\nThis Fails: System.import ( html file )"},
#         {'author': {'login': 'matthewp'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2017-04-12T23:05:57Z',
#          'bodyText': "I'm a little confused, it fails because you never attach a test runner, right? You have to attach QUnit or FuncUnit doesn't have a test runner to use.  Maybe I'm misunderstanding the bug though."},
#         {'author': {'login': 'mickmcgrath13'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2017-04-12T23:16:33Z',
#          'bodyText': "It fails with or without the F.attach(QUnit).  It is commented out to show that it isn't anything within the attachment of QUnit to Funcunit that is causing the issue."},
#         {'author': {'login': 'mickmcgrath13'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2017-04-12T23:21:06Z',
#          'bodyText': "More specifically, we're not actually using anything from FuncUnit in this test.  We're simply wrapping our QUnit test in a System.import of funcunit, and that in itself seems to cause QUnit to not behave as expected (namely, the beforeEach runs for the first test but not for the second)."},
#         {'author': {'login': 'matthewp'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2017-04-12T23:28:31Z',
#          'bodyText': "Oh, I see. steal-qunit will automatically run your tests once the main has finished loading. Since you are adding tests after the main has loaded, steal-qunit has already started QUnit before those tests are defined.\nI'm not really sure what a good workaround for that might be."},
#         {'author': {'login': 'mickmcgrath13'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2017-04-12T23:31:28Z',
#          'bodyText': 'there\'s not a way to tell steal-qunit to wait?  something like\nimport QUnit from \'steal-qunit\';\nQUnit.dontStartTestsUntil(System.import("funcunit")).then((F) => { \n  /* ... */ \n});\n..maybe?'},
#         {'author': {'login': 'matthewp'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2017-04-12T23:46:45Z',
#          'bodyText': 'No, maybe steal-qunit could check if QUnit.config.autostart !== false before doing its thing, or something like that, in which case you would have to start the tests yourself.'},
#         {'author': {'login': 'matthewp'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2017-04-13T12:36:30Z',
#          'bodyText': "Have you tried using start/stop in your test directly?\nimport QUnit from 'steal-qunit';\n\nQUnit.stop();\n\nSystem.import('funcunit').then(function(){\n  // add tests here\n  \n  QUnit.start();\n});"},
#         {'author': {'login': 'mickmcgrath13'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2017-04-17T14:05:33Z',
#          'bodyText': "I'll try that and let you know; thanks!"},
#         {'author': {'login': 'mickmcgrath13'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2017-04-17T14:35:16Z',
#          'bodyText': 'That gets:'},
#         {'author': {'login': 'matthewp'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2017-04-17T14:56:19Z',
#          'bodyText': 'I that case we need some feature added to steal-qunit like described here that will delay starting the tests until you tell it to.'}]},
#       'labels': {'nodes': []},
#       'activeLockReason': None}},
#     {'node': {'number': 198,
#       'title': 'point to global.js in build but not in package.json',
#       'url': 'https://github.com/bitovi/funcunit/issues/198',
#       'createdAt': '2017-04-11T18:03:10Z',
#       'updatedAt': '2017-04-11T22:05:27Z',
#       'closedAt': '2017-04-11T22:05:27Z',
#       'state': 'CLOSED',
#       'closed': True,
#       'locked': False,
#       'author': {'login': 'mickmcgrath13'},
#       'authorAssociation': 'CONTRIBUTOR',
#       'participants': {'totalCount': 1,
#        'nodes': [{'login': 'mickmcgrath13', 'company': 'Bitovi'}]},
#       'comments': {'totalCount': 0, 'nodes': []},
#       'labels': {'nodes': []},
#       'activeLockReason': None}},
#     {'node': {'number': 196,
#       'title': 'Improve the FuncUnit.com build',
#       'url': 'https://github.com/bitovi/funcunit/issues/196',
#       'createdAt': '2017-04-06T23:30:40Z',
#       'updatedAt': '2017-07-20T00:07:20Z',
#       'closedAt': None,
#       'state': 'OPEN',
#       'closed': False,
#       'locked': False,
#       'author': {'login': 'chasenlehara'},
#       'authorAssociation': 'MEMBER',
#       'participants': {'totalCount': 2,
#        'nodes': [{'login': 'chasenlehara', 'company': '@bitovi'},
#         {'login': 'imaustink', 'company': '@bitovi '}]},
#       'comments': {'totalCount': 3,
#        'nodes': [{'author': {'login': 'chasenlehara'},
#          'authorAssociation': 'MEMBER',
#          'createdAt': '2017-05-12T16:28:15Z',
#          'bodyText': 'make doesn’t work out of the box on Windows. In the 2017-05-12 contributors meeting we discussed converting it to a Node.js script and using ShellJS.'},
#         {'author': {'login': 'chasenlehara'},
#          'authorAssociation': 'MEMBER',
#          'createdAt': '2017-06-26T20:02:47Z',
#          'bodyText': 'Building the site is not working for me on Node 8 and npm 5 (it spits out an error about not being able to find brace-expansion).'},
#         {'author': {'login': 'chasenlehara'},
#          'authorAssociation': 'MEMBER',
#          'createdAt': '2017-07-20T00:06:09Z',
#          'bodyText': 'Basically everything in the original issue description still needs to be done, but we’re part way to making things better with Replace the Makefile with a Node script.\nI’m moving this issue to the backlog because the rest of the fixes are not as urgent.\nAnother note: with the above PR, I was able to deploy the site with Node 8.1.4 and npm 5.3.0'}]},
#       'labels': {'nodes': [{'name': 'cleanup'},
#         {'name': 'developer relations'},
#         {'name': 'help wanted'},
#         {'name': 'p2'},
#         {'name': 'website'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 192,
#       'title': 'Automatically update the version number on the home page',
#       'url': 'https://github.com/bitovi/funcunit/issues/192',
#       'createdAt': '2017-03-01T22:06:35Z',
#       'updatedAt': '2017-04-04T19:14:00Z',
#       'closedAt': '2017-04-04T19:14:00Z',
#       'state': 'CLOSED',
#       'closed': True,
#       'locked': False,
#       'author': {'login': 'chasenlehara'},
#       'authorAssociation': 'MEMBER',
#       'participants': {'totalCount': 2,
#        'nodes': [{'login': 'chasenlehara', 'company': '@bitovi'},
#         {'login': 'bitwhiz', 'company': None}]},
#       'comments': {'totalCount': 0, 'nodes': []},
#       'labels': {'nodes': [{'name': 'developer relations'},
#         {'name': 'enhancement'},
#         {'name': 'help wanted'},
#         {'name': 'p1'},
#         {'name': 'website'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 190,
#       'title': 'Update Syn',
#       'url': 'https://github.com/bitovi/funcunit/issues/190',
#       'createdAt': '2017-02-23T01:23:06Z',
#       'updatedAt': '2017-02-24T18:01:49Z',
#       'closedAt': '2017-02-24T18:01:44Z',
#       'state': 'CLOSED',
#       'closed': True,
#       'locked': False,
#       'author': {'login': 'chasenlehara'},
#       'authorAssociation': 'MEMBER',
#       'participants': {'totalCount': 1,
#        'nodes': [{'login': 'chasenlehara', 'company': '@bitovi'}]},
#       'comments': {'totalCount': 0, 'nodes': []},
#       'labels': {'nodes': []},
#       'activeLockReason': None}},
#     {'node': {'number': 188,
#       'title': 'Document how to test mouseover',
#       'url': 'https://github.com/bitovi/funcunit/issues/188',
#       'createdAt': '2017-02-21T17:14:52Z',
#       'updatedAt': '2017-07-31T15:46:04Z',
#       'closedAt': None,
#       'state': 'OPEN',
#       'closed': False,
#       'locked': False,
#       'author': {'login': 'chasenlehara'},
#       'authorAssociation': 'MEMBER',
#       'participants': {'totalCount': 2,
#        'nodes': [{'login': 'chasenlehara', 'company': '@bitovi'},
#         {'login': 'bitwhiz', 'company': None}]},
#       'comments': {'totalCount': 0, 'nodes': []},
#       'labels': {'nodes': [{'name': 'documentation'},
#         {'name': 'help wanted'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 187,
#       'title': 'Do not set window.jQuery',
#       'url': 'https://github.com/bitovi/funcunit/issues/187',
#       'createdAt': '2017-02-13T16:23:58Z',
#       'updatedAt': '2017-04-10T19:15:00Z',
#       'closedAt': '2017-04-10T19:15:00Z',
#       'state': 'CLOSED',
#       'closed': True,
#       'locked': False,
#       'author': {'login': 'mickmcgrath13'},
#       'authorAssociation': 'CONTRIBUTOR',
#       'participants': {'totalCount': 4,
#        'nodes': [{'login': 'mickmcgrath13', 'company': 'Bitovi'},
#         {'login': 'matthewp', 'company': 'Bitovi'},
#         {'login': 'jeroencornelissen', 'company': None},
#         {'login': 'chasenlehara', 'company': '@bitovi'}]},
#       'comments': {'totalCount': 2,
#        'nodes': [{'author': {'login': 'matthewp'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2017-02-13T16:32:49Z',
#          'bodyText': "LGTM, just need a different entry point for the global build, create a global.js that imports FuncUnit's main and then sets window.jQuery = jQuery."},
#         {'author': {'login': 'jeroencornelissen'},
#          'authorAssociation': 'NONE',
#          'createdAt': '2017-02-28T07:26:17Z',
#          'bodyText': '+1\nWe have a simular issue when importing jquery-ui.'}]},
#       'labels': {'nodes': [{'name': 'bug'}, {'name': 'p1'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 186,
#       'title': '[ctrl/alt/cmd/shift]-click support',
#       'url': 'https://github.com/bitovi/funcunit/issues/186',
#       'createdAt': '2017-02-07T08:10:07Z',
#       'updatedAt': '2017-04-19T15:31:08Z',
#       'closedAt': '2017-04-19T15:31:08Z',
#       'state': 'CLOSED',
#       'closed': True,
#       'locked': False,
#       'author': {'login': 'jeroencornelissen'},
#       'authorAssociation': 'NONE',
#       'participants': {'totalCount': 3,
#        'nodes': [{'login': 'jeroencornelissen', 'company': None},
#         {'login': 'matthewp', 'company': 'Bitovi'},
#         {'login': 'kdillon', 'company': 'MathWorks'}]},
#       'comments': {'totalCount': 2,
#        'nodes': [{'author': {'login': 'matthewp'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2017-02-07T12:54:25Z',
#          'bodyText': 'Can you do something like this? https://github.com/bitovi/syn/blob/master/test/key_test.js#L423'},
#         {'author': {'login': 'kdillon'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2017-04-18T20:15:35Z',
#          'bodyText': 'There was a bug in ctrl. It should be fixed in the latest version of Syn'}]},
#       'labels': {'nodes': []},
#       'activeLockReason': None}},
#     {'node': {'number': 182,
#       'title': 'Add blur action for testing blur events.',
#       'url': 'https://github.com/bitovi/funcunit/issues/182',
#       'createdAt': '2016-12-21T21:30:48Z',
#       'updatedAt': '2017-05-03T20:43:30Z',
#       'closedAt': None,
#       'state': 'OPEN',
#       'closed': False,
#       'locked': False,
#       'author': {'login': 'ilyavf'},
#       'authorAssociation': 'NONE',
#       'participants': {'totalCount': 3,
#        'nodes': [{'login': 'ilyavf', 'company': None},
#         {'login': 'justinbmeyer', 'company': 'Bitovi'},
#         {'login': 'imaustink', 'company': '@bitovi '}]},
#       'comments': {'totalCount': 1,
#        'nodes': [{'author': {'login': 'justinbmeyer'},
#          'authorAssociation': 'MEMBER',
#          'createdAt': '2016-12-22T04:04:11Z',
#          'bodyText': "I think you can click the document as a shorthand for what the user would do.\n…\nSent from my iPhone\n On Dec 21, 2016, at 3:30 PM, Ilya Fadeev ***@***.***> wrote:\n\n If in a component's event we listen to a blur even like this:\n\n Component.extend({\n         tag : 'my-component',\n         viewModel : myVM,\n         events : {\n             '.my-message blur': function (element) {\n                 this.viewModel.doSmth();\n             }\n         }\n it would be nice to be able to:\n\n F('.my-message').blur( function() {\n        // ...\n });\n —\n You are receiving this because you are subscribed to this thread.\n Reply to this email directly, view it on GitHub, or mute the thread."}]},
#       'labels': {'nodes': []},
#       'activeLockReason': None}},
#     {'node': {'number': 181,
#       'title': 'FuncUnit.com audit',
#       'url': 'https://github.com/bitovi/funcunit/issues/181',
#       'createdAt': '2016-11-15T23:55:32Z',
#       'updatedAt': '2017-03-03T06:56:28Z',
#       'closedAt': None,
#       'state': 'OPEN',
#       'closed': False,
#       'locked': False,
#       'author': {'login': 'chasenlehara'},
#       'authorAssociation': 'MEMBER',
#       'participants': {'totalCount': 1,
#        'nodes': [{'login': 'chasenlehara', 'company': '@bitovi'}]},
#       'comments': {'totalCount': 0, 'nodes': []},
#       'labels': {'nodes': [{'name': 'developer relations'}, {'name': 'p3'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 173,
#       'title': 'Use continuous deployment with travis',
#       'url': 'https://github.com/bitovi/funcunit/issues/173',
#       'createdAt': '2016-11-01T16:55:36Z',
#       'updatedAt': '2016-11-01T16:55:36Z',
#       'closedAt': None,
#       'state': 'OPEN',
#       'closed': False,
#       'locked': False,
#       'author': {'login': 'mickmcgrath13'},
#       'authorAssociation': 'CONTRIBUTOR',
#       'participants': {'totalCount': 1,
#        'nodes': [{'login': 'mickmcgrath13', 'company': 'Bitovi'}]},
#       'comments': {'totalCount': 0, 'nodes': []},
#       'labels': {'nodes': [{'name': 'p4'}, {'name': 'website'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 171,
#       'title': 'Update travis.yml firefox version',
#       'url': 'https://github.com/bitovi/funcunit/issues/171',
#       'createdAt': '2016-10-31T17:44:16Z',
#       'updatedAt': '2016-11-02T19:25:39Z',
#       'closedAt': None,
#       'state': 'OPEN',
#       'closed': False,
#       'locked': False,
#       'author': {'login': 'mickmcgrath13'},
#       'authorAssociation': 'CONTRIBUTOR',
#       'participants': {'totalCount': 1,
#        'nodes': [{'login': 'mickmcgrath13', 'company': 'Bitovi'}]},
#       'comments': {'totalCount': 0, 'nodes': []},
#       'labels': {'nodes': [{'name': 'p3'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 170,
#       'title': 'Mixed content errors on docs site when loading over https',
#       'url': 'https://github.com/bitovi/funcunit/issues/170',
#       'createdAt': '2016-10-31T17:10:44Z',
#       'updatedAt': '2016-11-02T22:01:49Z',
#       'closedAt': '2016-11-02T22:01:45Z',
#       'state': 'CLOSED',
#       'closed': True,
#       'locked': False,
#       'author': {'login': 'mickmcgrath13'},
#       'authorAssociation': 'CONTRIBUTOR',
#       'participants': {'totalCount': 1,
#        'nodes': [{'login': 'mickmcgrath13', 'company': 'Bitovi'}]},
#       'comments': {'totalCount': 0, 'nodes': []},
#       'labels': {'nodes': [{'name': 'bug'},
#         {'name': 'documentation'},
#         {'name': 'p1'},
#         {'name': 'website'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 164,
#       'title': 'Update examples to use NPM/Steal',
#       'url': 'https://github.com/bitovi/funcunit/issues/164',
#       'createdAt': '2016-10-27T19:36:21Z',
#       'updatedAt': '2016-10-31T19:42:08Z',
#       'closedAt': None,
#       'state': 'OPEN',
#       'closed': False,
#       'locked': False,
#       'author': {'login': 'mickmcgrath13'},
#       'authorAssociation': 'CONTRIBUTOR',
#       'participants': {'totalCount': 1,
#        'nodes': [{'login': 'mickmcgrath13', 'company': 'Bitovi'}]},
#       'comments': {'totalCount': 0, 'nodes': []},
#       'labels': {'nodes': [{'name': 'p3'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 162,
#       'title': 'Get documentation working',
#       'url': 'https://github.com/bitovi/funcunit/issues/162',
#       'createdAt': '2016-10-25T15:52:36Z',
#       'updatedAt': '2016-10-28T13:29:14Z',
#       'closedAt': '2016-10-28T13:29:10Z',
#       'state': 'CLOSED',
#       'closed': True,
#       'locked': False,
#       'author': {'login': 'mickmcgrath13'},
#       'authorAssociation': 'CONTRIBUTOR',
#       'participants': {'totalCount': 1,
#        'nodes': [{'login': 'mickmcgrath13', 'company': 'Bitovi'}]},
#       'comments': {'totalCount': 0, 'nodes': []},
#       'labels': {'nodes': [{'name': 'p1'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 161,
#       'title': 'Write a contributing guide',
#       'url': 'https://github.com/bitovi/funcunit/issues/161',
#       'createdAt': '2016-10-25T15:37:50Z',
#       'updatedAt': '2016-10-28T17:30:43Z',
#       'closedAt': '2016-10-28T17:30:40Z',
#       'state': 'CLOSED',
#       'closed': True,
#       'locked': False,
#       'author': {'login': 'justinbmeyer'},
#       'authorAssociation': 'MEMBER',
#       'participants': {'totalCount': 2,
#        'nodes': [{'login': 'justinbmeyer', 'company': 'Bitovi'},
#         {'login': 'mickmcgrath13', 'company': 'Bitovi'}]},
#       'comments': {'totalCount': 0, 'nodes': []},
#       'labels': {'nodes': [{'name': 'p1'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 159,
#       'title': 'Get CanJS-like release script working',
#       'url': 'https://github.com/bitovi/funcunit/issues/159',
#       'createdAt': '2016-10-24T14:56:59Z',
#       'updatedAt': '2016-10-26T14:32:59Z',
#       'closedAt': '2016-10-26T14:32:54Z',
#       'state': 'CLOSED',
#       'closed': True,
#       'locked': False,
#       'author': {'login': 'justinbmeyer'},
#       'authorAssociation': 'MEMBER',
#       'participants': {'totalCount': 2,
#        'nodes': [{'login': 'justinbmeyer', 'company': 'Bitovi'},
#         {'login': 'mickmcgrath13', 'company': 'Bitovi'}]},
#       'comments': {'totalCount': 0, 'nodes': []},
#       'labels': {'nodes': [{'name': 'enhancement'}, {'name': 'p1'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 158,
#       'title': 'perform a test during a mousedown event',
#       'url': 'https://github.com/bitovi/funcunit/issues/158',
#       'createdAt': '2016-10-14T06:47:06Z',
#       'updatedAt': '2016-10-31T19:45:24Z',
#       'closedAt': None,
#       'state': 'OPEN',
#       'closed': False,
#       'locked': False,
#       'author': {'login': 'swipie'},
#       'authorAssociation': 'NONE',
#       'participants': {'totalCount': 2,
#        'nodes': [{'login': 'swipie', 'company': None},
#         {'login': 'mickmcgrath13', 'company': 'Bitovi'}]},
#       'comments': {'totalCount': 0, 'nodes': []},
#       'labels': {'nodes': [{'name': 'p2'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 156,
#       'title': "F.open() doesn't throw when violating same-origin",
#       'url': 'https://github.com/bitovi/funcunit/issues/156',
#       'createdAt': '2016-08-11T17:56:56Z',
#       'updatedAt': '2016-10-31T19:46:58Z',
#       'closedAt': None,
#       'state': 'OPEN',
#       'closed': False,
#       'locked': False,
#       'author': {'login': 'matthewp'},
#       'authorAssociation': 'CONTRIBUTOR',
#       'participants': {'totalCount': 2,
#        'nodes': [{'login': 'matthewp', 'company': 'Bitovi'},
#         {'login': 'mickmcgrath13', 'company': 'Bitovi'}]},
#       'comments': {'totalCount': 0, 'nodes': []},
#       'labels': {'nodes': [{'name': 'bug'},
#         {'name': 'help wanted'},
#         {'name': 'p3'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 155,
#       'title': 'Qunit2 support?',
#       'url': 'https://github.com/bitovi/funcunit/issues/155',
#       'createdAt': '2016-08-04T13:38:12Z',
#       'updatedAt': '2017-05-21T03:29:06Z',
#       'closedAt': None,
#       'state': 'OPEN',
#       'closed': False,
#       'locked': False,
#       'author': {'login': 'binodpanta'},
#       'authorAssociation': 'CONTRIBUTOR',
#       'participants': {'totalCount': 8,
#        'nodes': [{'login': 'binodpanta', 'company': None},
#         {'login': 'matthewp', 'company': 'Bitovi'},
#         {'login': 'shayaneumar', 'company': 'Mitel Networks'},
#         {'login': 'kdillon', 'company': 'MathWorks'},
#         {'login': 'justinbmeyer', 'company': 'Bitovi'},
#         {'login': 'kjdonahue', 'company': None},
#         {'login': 'm-mujica', 'company': 'Bitovi'},
#         {'login': 'mickmcgrath13', 'company': 'Bitovi'}]},
#       'comments': {'totalCount': 20,
#        'nodes': [{'author': {'login': 'binodpanta'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2016-08-09T15:49:12Z',
#          'bodyText': 'Let alone QUnit2, I think it also does not work with qunit 1.23.1, I tried to upgrade to that version, I got this error in this function,\n"Uncaught Error: Called stop() outside of a test context"\n/funcunit@3.0.0#browser/adapters/qunit/\ndefine(\'funcunit/browser/adapters/qunit\', function (require, exports, module) {\nmodule.exports = function (QUnit) {\nreturn {\npauseTest: function () {\nQUnit.stop();\n},\nresumeTest: function () {\nQUnit.start();\n},\nassertOK: function (assertion, message) {\nQUnit.ok(assertion, message);\n},\nequiv: function (expected, actual) {\nreturn QUnit.equiv(expected, actual);\n}\n};\n};\n});'},
# ...
#         {'name': 'help wanted'},
#         {'name': 'p3'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 140,
#       'title': ".exists() isn't counted as an assertion unless a message is defined",
#       'url': 'https://github.com/bitovi/funcunit/issues/140',
#       'createdAt': '2016-02-26T20:50:38Z',
#       'updatedAt': '2016-02-26T21:08:23Z',
#       'closedAt': '2016-02-26T21:08:23Z',
#       'state': 'CLOSED',
#       'closed': True,
#       'locked': False,
#       'author': {'login': 'akagomez'},
#       'authorAssociation': 'CONTRIBUTOR',
#       'participants': {'totalCount': 2,
#        'nodes': [{'login': 'akagomez', 'company': 'HigherEducation'},
#         {'login': 'matthewp', 'company': 'Bitovi'}]},
#       'comments': {'totalCount': 4,
#        'nodes': [{'author': {'login': 'matthewp'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2016-02-26T20:53:49Z',
#          'bodyText': "This is definitely true, but it's intentional. It's so you can chain a bunch of stuff and only assert at the end:\nF('selection').exists().click().doMoreStuff().foo('ok now assert');"},
#         {'author': {'login': 'akagomez'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2016-02-26T20:55:35Z',
#          'bodyText': 'How would counting the message-less .exists() as an assertion prevent you from doing that?'},
#         {'author': {'login': 'matthewp'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2016-02-26T21:00:45Z',
#          'bodyText': "Because FuncUnit works by retrying over and over. So it runs F('selection').exists() until it is true, and then goes on to the next thing (.click()). it only does assertions when it sees the message."},
#         {'author': {'login': 'akagomez'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2016-02-26T21:08:23Z',
#          'bodyText': 'Message\nThe last (optional) parameter for each wait command is a message. By default, wait conditions will pass silently (without a passed assertion).\nIf a user provides a message string, the wait condition will pass an assertion with the given message when the wait completes. If the wait fails (the timeout is reached), this message will be provided to the failed assertion.\n\nhttps://funcunit.com/guides/Guides.waits.html'}]},
#       'labels': {'nodes': []},
#       'activeLockReason': None}},
#     {'node': {'number': 139,
#       'title': 'Dynamic iframes are considered not loaded',
#       'url': 'https://github.com/bitovi/funcunit/issues/139',
#       'createdAt': '2016-02-24T20:25:51Z',
#       'updatedAt': '2016-10-31T20:22:01Z',
#       'closedAt': None,
#       'state': 'OPEN',
#       'closed': False,
#       'locked': False,
#       'author': {'login': 'akagomez'},
#       'authorAssociation': 'CONTRIBUTOR',
#       'participants': {'totalCount': 3,
#        'nodes': [{'login': 'akagomez', 'company': 'HigherEducation'},
#         {'login': 'matthewp', 'company': 'Bitovi'},
#         {'login': 'mickmcgrath13', 'company': 'Bitovi'}]},
#       'comments': {'totalCount': 1,
#        'nodes': [{'author': {'login': 'matthewp'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2016-08-11T18:00:05Z',
#          'bodyText': 'Thanks! This a good bug, probably easy to write a test for.'}]},
#       'labels': {'nodes': [{'name': 'bug'},
#         {'name': 'help wanted'},
#         {'name': 'p2'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 138,
#       'title': "Chained .find()'s don't work with iframes",
#       'url': 'https://github.com/bitovi/funcunit/issues/138',
#       'createdAt': '2016-02-24T17:20:13Z',
#       'updatedAt': '2016-10-31T20:22:45Z',
#       'closedAt': None,
#       'state': 'OPEN',
#       'closed': False,
#       'locked': False,
#       'author': {'login': 'akagomez'},
#       'authorAssociation': 'CONTRIBUTOR',
#       'participants': {'totalCount': 2,
#        'nodes': [{'login': 'akagomez', 'company': 'HigherEducation'},
#         {'login': 'mickmcgrath13', 'company': 'Bitovi'}]},
#       'comments': {'totalCount': 0, 'nodes': []},
#       'labels': {'nodes': [{'name': 'p3'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 137,
#       'title': 'Typing at the start of input inside an Iframe causes cursor to reset to end',
#       'url': 'https://github.com/bitovi/funcunit/issues/137',
#       'createdAt': '2016-02-10T12:28:51Z',
#       'updatedAt': '2016-10-31T20:23:28Z',
#       'closedAt': None,
#       'state': 'OPEN',
#       'closed': False,
#       'locked': False,
#       'author': {'login': 'MrL0co'},
#       'authorAssociation': 'NONE',
#       'participants': {'totalCount': 3,
#        'nodes': [{'login': 'MrL0co', 'company': None},
#         {'login': 'matthewp', 'company': 'Bitovi'},
#         {'login': 'mickmcgrath13', 'company': 'Bitovi'}]},
#       'comments': {'totalCount': 0, 'nodes': []},
#       'labels': {'nodes': [{'name': 'bug'},
#         {'name': 'help wanted'},
#         {'name': 'p2'}]},
#       'activeLockReason': None}},
#     {'node': {'number': 136,
#       'title': 'Type performs implicit click, why?',
#       'url': 'https://github.com/bitovi/funcunit/issues/136',
#       'createdAt': '2016-02-08T18:16:52Z',
#       'updatedAt': '2016-09-20T17:34:01Z',
#       'closedAt': '2016-09-20T17:32:13Z',
#       'state': 'CLOSED',
#       'closed': True,
#       'locked': False,
#       'author': {'login': 'binodpanta'},
#       'authorAssociation': 'CONTRIBUTOR',
#       'participants': {'totalCount': 3,
#        'nodes': [{'login': 'binodpanta', 'company': None},
#         {'login': 'justinbmeyer', 'company': 'Bitovi'},
#         {'login': 'matthewp', 'company': 'Bitovi'}]},
#       'comments': {'totalCount': 13,
#        'nodes': [{'author': {'login': 'justinbmeyer'},
#          'authorAssociation': 'MEMBER',
#          'createdAt': '2016-02-08T20:23:54Z',
#          'bodyText': "Is there any particular reason type includes a click?\n\nAn element needs focus so it can be typed on.  A user typically gives an element focus by clicking it or tabbing to it.  I suppose the better fix would be to check if the element has focus, if it doesn't, to then click the element to give it."},
#         {'author': {'login': 'binodpanta'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2016-04-24T16:39:41Z',
#          'bodyText': 'Thanks for the update. My preference would be to have click and type be separate so that users can click then type. Alternatively can you provde a sendkeys which only send keys so that those cases I mentioned can be addressed?'},
#         {'author': {'login': 'binodpanta'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2016-06-07T14:17:09Z',
#          'bodyText': 'Any thoughts? Can there be two methods, one that just does a keysend, and another that has the current behavior?'},
#         {'author': {'login': 'justinbmeyer'},
#          'authorAssociation': 'MEMBER',
#          'createdAt': '2016-06-07T14:24:46Z',
#          'bodyText': "@binodpanta the primary design goal of FuncUnit is to mimic what users do.  An element must be focused before it can receive key events.  That traditionally happens with a click or a [tab] so I'm not sure how to enable this with the standard type method.\nHowever, I'd be fine exposing a method that just does a keysend if you want to submit a pull request."},
#         {'author': {'login': 'binodpanta'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2016-08-17T17:10:37Z',
#          'bodyText': "Hi there, we are preparing a change to add a new method F.sendkeys which would be exactly the same usage as type except it won't have the click, we will send a pull request. Is there anything else to the process?"},
#         {'author': {'login': 'matthewp'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2016-08-17T17:48:56Z',
#          'bodyText': 'Sounds good!  I think this would probably be a change in syn first? https://github.com/bitovi/syn\nsyn is what implements type and click and that sort of stuff.\nI would go with sendKeys camelcased, otherwise sounds like a reasonable change to me.'},
#         {'author': {'login': 'binodpanta'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2016-08-17T18:27:05Z',
#          'bodyText': 'Thanks @matthewp . I will cameCase the function.\nWould we need a syn change? I was going along the lines of just adding a new method that looks like this in actions.js\nsendKeys: function( keys, success ) {\n    this._addExists();\n    var selector = this.selector;\n    // type("") is a shortcut for clearing out a text input\n    if(keys === ""){\n      keys = "[ctrl]a[ctrl-up]\\b"\n    }\n    FuncUnit.add({\n      method : function(success, error){\n        syn("_type", this.bind[0], keys, success);\n\n      },\n      success : success,\n      error : "Could not send the keys " + keys + " into " + this.selector,\n      bind : this,\n      type: "action"\n    });\n    return this;\n  },\n\nMy current test listed below, is setup to fail if I replace sendKeys() with type(), as it detects any clicks and fails if click was ever registered\nQUnit.test("SendKeys without click", function(){\nF.open("test/myapp.html");\nF("#typehereexpectnoclick").sendKeys("javascriptmvc");\n// if this shows up it means that we definitely did not receive a click\nF("#seewhatyoutyped").text("typed javascriptmvc","type still works");\n})'},
#         {'author': {'login': 'binodpanta'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2016-08-23T18:14:03Z',
#          'bodyText': 'hi there, any thoughts? If not, I will go ahead and submit a pull request'},
#         {'author': {'login': 'binodpanta'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2016-09-15T17:32:07Z',
#          'bodyText': 'Hello, I tried to submit my changes into a new branch sendkeys and I get this when I run git push -u origin sendkeys\nerror: The requested URL returned error: 403 while accessing https://github.com/bitovi/funcunit.git/info/refs\nIs there a whitelist of users who can submit? Do I need to get added?'},
#         {'author': {'login': 'matthewp'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2016-09-15T17:36:13Z',
#          'bodyText': '@binodpanta You should be able to fork the repo here:\n\npush your changes to your fork, and then submit a pull request. Thanks!'},
#         {'author': {'login': 'binodpanta'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2016-09-16T02:50:26Z',
#          'bodyText': 'oh of course, what am I thinking, got it here\n#157'},
#         {'author': {'login': 'binodpanta'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2016-09-20T16:28:48Z',
#          'bodyText': 'Any idea if this change can be part of an upcoming release? and whenabouts that release will occur?\nThanks!'},
#         {'author': {'login': 'justinbmeyer'},
#          'authorAssociation': 'MEMBER',
#          'createdAt': '2016-09-20T17:34:01Z',
#          'bodyText': "@binodpanta I just merged this.  We'll release it once the new CanJS is out.  Look for it maybe next week.\nWe're looking for people to help on FuncUnit.  If you're interested in becoming a contributor ... and all the fame and glory that entails, let us/me know (justin@bitovi.com).  Thanks!"}]},
#       'labels': {'nodes': []},
#       'activeLockReason': None}},
#     {'node': {'number': 135,
#       'title': 'Touch Support',
#       'url': 'https://github.com/bitovi/funcunit/issues/135',
#       'createdAt': '2016-01-20T17:51:26Z',
#       'updatedAt': '2017-04-19T15:31:08Z',
#       'closedAt': '2017-04-19T15:31:08Z',
#       'state': 'CLOSED',
#       'closed': True,
#       'locked': False,
#       'author': {'login': 'victor-xiong'},
#       'authorAssociation': 'NONE',
#       'participants': {'totalCount': 6,
#        'nodes': [{'login': 'victor-xiong', 'company': '@google'},
#         {'login': 'matthewp', 'company': 'Bitovi'},
#         {'login': 'binodpanta', 'company': None},
#         {'login': 'justinbmeyer', 'company': 'Bitovi'},
#         {'login': 'chinmaywanpal', 'company': 'The MathWorks Inc'},
#         {'login': 'mickmcgrath13', 'company': 'Bitovi'}]},
#       'comments': {'totalCount': 5,
#        'nodes': [{'author': {'login': 'matthewp'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2016-01-20T18:29:43Z',
#          'bodyText': "It's something we've wanted for a long time, however probably will need someone in the community to take on development."},
#         {'author': {'login': 'binodpanta'},
#          'authorAssociation': 'CONTRIBUTOR',
#          'createdAt': '2016-11-28T20:36:02Z',
#          'bodyText': 'I am interested to explore this as long as we can be clear about what can do next in touch and funcunit. An example test page is this which shows that using dojo.touch api, manual clicks will trigger both touch and click callbacks, but funcunit clicks will only generate click callbacks\n<html>\n\n<body>\n<script type="text/javascript" src="jquery.js"></script>\n<script type="text/javascript" src="funcunit.js"></script>\n<script type="text/javascript" src="qunit.js"></script>\n<script type="text/javascript" src="dojo.js"></script>\n\n<textarea id="testbox"></textarea>\n\n<script type="text/javascript">\nrequire([\n\t"dojo/dom",\n\t"dojo/on",\n\t"dojo/touch"\n\t], function (dom, on, touch) {\n\n\tvar node = dom.byId("testbox");\n\n\ton(node, touch.press, function (event) {\n\t\tconsole.log("Touch event registered");\n\t});\n\n\ton(node, "click", function (event) {\n\t\tconsole.log("Click event registered");\n\t});\n\n\tF(\'#testbox\').click();\n});\n\n</script>\n</body>\n</html>\n\nI will propose it as a topic in an upcoming meeting'},
#         {'author': {'login': 'justinbmeyer'},
#          'authorAssociation': 'MEMBER',
#          'createdAt': '2016-11-30T04:32:47Z',
#          'bodyText': 'Sounds good. We can setup some time to pair on this too.\n…\nSent from my iPhone\n On Nov 28, 2016, at 2:36 PM, binodpanta ***@***.***> wrote:\n\n I am interested to explore this as long as we can be clear about what can do next in touch and funcunit. An example test page is this which shows that using dojo.touch api, manual clicks will trigger both touch and click callbacks, but funcunit clicks will only generate click callbacks\n\n `\n\n <script type="text/javascript" src="../../../../../test/tools/javascript/libs/funcunit/jquery.js"></script> <script type="text/javascript" src="../../../../../test/tools/javascript/libs/funcunit/funcunit.js"></script> <script type="text/javascript" src="../../../../../test/tools/javascript/libs/qunit/qunit.js"></script> <script type="text/javascript" src="../derived/ui/dojo/dojo.js"></script>\n <textarea id="testbox"></textarea>\n\n <script type="text/javascript"> require([ "dojo/dom", "dojo/on", "dojo/touch" ], function (dom, on, touch) { var node = dom.byId("testbox"); on(node, touch.press, function (event) { console.log("Touch event registered"); }); on(node, "click", function (event) { console.log("Click event registered"); }); F(\'#testbox\').click(); }); </script> `\n I will propose it as a topic in an upcoming meeting\n\n —\n You are receiving this because you are subscribed to this thread.\n Reply to this email directly, view it on GitHub, or mute the thread.'},
#         {'author': {'login': 'chinmaywanpal'},
#          'authorAssociation': 'NONE',
#          'createdAt': '2016-12-02T04:28:07Z',
#          'bodyText': 'Did you folks start working on this? I was also interested in knowing more/ contributing. I came across bitovi/syn#25 from a conversation about pointer events. May be that could be a good place to start about thinking of touch support. What do you think?'},
#         {'author': {'login': 'justinbmeyer'},
#          'authorAssociation': 'MEMBER',
#          'createdAt': '2016-12-02T15:20:22Z',
#          'bodyText': '@chinmaywanpal yes, syn is where the basic behavior would need to be added first.'}]},
#       'labels': {'nodes': [{'name': 'enhancement'}, {'name': 'p3'}]},
#       'activeLockReason': None}}]}}}

# %%
hasNextPage = result2['data']['search']['pageInfo']['hasNextPage']
endCursor = result2['data']['search']['pageInfo']['endCursor']

# %%
query2 = create_query("bitovi/funcunit", hasNextPage=hasNextPage, afterCursor=endCursor)
# Get a result of the test query
result2 = run_query(query2) # Execute the query

# %%
result2
# Out:
# {'data': {'rateLimit': {'cost': 1, 'remaining': 4996, 'resetAt': '2019-07-02T04:07:17Z'}, 'search': {'issueCount': 151, 'pageInfo': {'hasNextPage': False, 'endCursor': 'Y3Vyc29yOjE1MQ=='}, 'edges': [{'node': {'number': 2, 'title': 'Syn Click in IE8', 'url': 'https://github.com/bitovi/funcunit/issues/2', 'createdAt': '2010-08-30T20:49:08Z', 'updatedAt': '2010-10-07T15:07:01Z', 'closedAt': '2010-10-07T15:07:01Z', 'state': 'CLOSED', 'closed': True, 'locked': False, 'author': {'login': 'arian'}, 'authorAssociation': 'NONE', 'participants': {'totalCount': 3, 'nodes': [{'login': 'arian', 'company': 'Symbaloo'}, {'login': 'jupiterjs', 'company': None}, {'login': 'cpojer', 'company': 'Facebook'}]}, 'comments': {'totalCount': 10, 'nodes': [{'author': None, 'authorAssociation': 'NONE', 'createdAt': '2010-08-30T21:14:53Z', 'bodyText': 'This is happening outside of jsfiddle?'}, {'author': None, 'authorAssociation': 'NONE', 'createdAt': '2010-08-30T21:37:04Z', 'bodyText': 'Ah, if I do the test without Mootools, and changing onload to load, it works.  Mootools must be overwriting something that Syn depends on.'}, {'author': {'login': 'arian'}, 'authorAssociation': 'NONE', 'createdAt': '2010-08-30T23:49:13Z', 'bodyText': "aah, dammit, i'll keep searching, hope I can find it where it collides... or do you have an idea (where to start)?"}, {'author': None, 'authorAssociation': 'NONE', 'createdAt': '2010-08-31T00:14:16Z', 'bodyText': "it's got to be fireEvent or attachEvent"}, {'author': {'login': 'arian'}, 'authorAssociation': 'NONE', 'createdAt': '2010-08-31T11:27:04Z', 'bodyText': "MooTools overwrites the IE element fireEvent\ntherefore we should get the old fireEvent, for example with this right after (function($){\nvar fireEvent = document.createElement('div').fireEvent;\n\nand then use this in Syn.dispatch:\nreturn element.sourceIndex <= 0 || fireEvent.call(element, 'on'+type, event)\n\nI think this fixes our errors with MooTools in our Specs runner, you might consider to use this too of course :)"}, {'author': {'login': 'arian'}, 'authorAssociation': 'NONE', 'createdAt': '2010-08-31T11:34:14Z', 'bodyText': 'probably a better solution is:\nvar fireEvent = document.documentElement.fireEvent;'}, {'author': None, 'authorAssociation': 'NONE', 'createdAt': '2010-08-31T13:20:05Z', 'bodyText': "Why is mootools overwriting this?\nI can probably make this change, but I don't want to get in the habit of coding around the quirks of other libraries. If syn is being wrapped by mootools, it's probably possible to pass it unmodified elements."}, {'author': {'login': 'cpojer'}, 'authorAssociation': 'NONE', 'createdAt': '2010-08-31T15:37:11Z', 'bodyText': "MooTools chose to overwrite the native IE fireEvent method years ago and we are not able to change that in the current version for compatibility reasons. Please note that this is the only native method in any browser that we are overwriting on the Element.prototype. If you could make this one single change, we would greatly appreciate it. We really don't want to start maintaining our own fork of Syn.js\nThank you"}, {'author': None, 'authorAssociation': 'NONE', 'createdAt': '2010-08-31T15:54:21Z', 'bodyText': 'Ok, I will make the change.'}, {'author': {'login': 'cpojer'}, 'authorAssociation': 'NONE', 'createdAt': '2010-09-04T11:11:35Z', 'bodyText': 'We have investigated the problem some more and it is better not to change this in Syn.js :) Thank you for your time looking into the issue.'}]}, 'labels': {'nodes': []}, 'activeLockReason': None}}]}}}

# %%
hasNextPage = result2['data']['search']['pageInfo']['hasNextPage']
endCursor = result2['data']['search']['pageInfo']['endCursor']

# %%
result2['data']['search']['edges']
# Out:
# [{'node': {'number': 2, 'title': 'Syn Click in IE8', 'url': 'https://github.com/bitovi/funcunit/issues/2', 'createdAt': '2010-08-30T20:49:08Z', 'updatedAt': '2010-10-07T15:07:01Z', 'closedAt': '2010-10-07T15:07:01Z', 'state': 'CLOSED', 'closed': True, 'locked': False, 'author': {'login': 'arian'}, 'authorAssociation': 'NONE', 'participants': {'totalCount': 3, 'nodes': [{'login': 'arian', 'company': 'Symbaloo'}, {'login': 'jupiterjs', 'company': None}, {'login': 'cpojer', 'company': 'Facebook'}]}, 'comments': {'totalCount': 10, 'nodes': [{'author': None, 'authorAssociation': 'NONE', 'createdAt': '2010-08-30T21:14:53Z', 'bodyText': 'This is happening outside of jsfiddle?'}, {'author': None, 'authorAssociation': 'NONE', 'createdAt': '2010-08-30T21:37:04Z', 'bodyText': 'Ah, if I do the test without Mootools, and changing onload to load, it works.  Mootools must be overwriting something that Syn depends on.'}, {'author': {'login': 'arian'}, 'authorAssociation': 'NONE', 'createdAt': '2010-08-30T23:49:13Z', 'bodyText': "aah, dammit, i'll keep searching, hope I can find it where it collides... or do you have an idea (where to start)?"}, {'author': None, 'authorAssociation': 'NONE', 'createdAt': '2010-08-31T00:14:16Z', 'bodyText': "it's got to be fireEvent or attachEvent"}, {'author': {'login': 'arian'}, 'authorAssociation': 'NONE', 'createdAt': '2010-08-31T11:27:04Z', 'bodyText': "MooTools overwrites the IE element fireEvent\ntherefore we should get the old fireEvent, for example with this right after (function($){\nvar fireEvent = document.createElement('div').fireEvent;\n\nand then use this in Syn.dispatch:\nreturn element.sourceIndex <= 0 || fireEvent.call(element, 'on'+type, event)\n\nI think this fixes our errors with MooTools in our Specs runner, you might consider to use this too of course :)"}, {'author': {'login': 'arian'}, 'authorAssociation': 'NONE', 'createdAt': '2010-08-31T11:34:14Z', 'bodyText': 'probably a better solution is:\nvar fireEvent = document.documentElement.fireEvent;'}, {'author': None, 'authorAssociation': 'NONE', 'createdAt': '2010-08-31T13:20:05Z', 'bodyText': "Why is mootools overwriting this?\nI can probably make this change, but I don't want to get in the habit of coding around the quirks of other libraries. If syn is being wrapped by mootools, it's probably possible to pass it unmodified elements."}, {'author': {'login': 'cpojer'}, 'authorAssociation': 'NONE', 'createdAt': '2010-08-31T15:37:11Z', 'bodyText': "MooTools chose to overwrite the native IE fireEvent method years ago and we are not able to change that in the current version for compatibility reasons. Please note that this is the only native method in any browser that we are overwriting on the Element.prototype. If you could make this one single change, we would greatly appreciate it. We really don't want to start maintaining our own fork of Syn.js\nThank you"}, {'author': None, 'authorAssociation': 'NONE', 'createdAt': '2010-08-31T15:54:21Z', 'bodyText': 'Ok, I will make the change.'}, {'author': {'login': 'cpojer'}, 'authorAssociation': 'NONE', 'createdAt': '2010-09-04T11:11:35Z', 'bodyText': 'We have investigated the problem some more and it is better not to change this in Syn.js :) Thank you for your time looking into the issue.'}]}, 'labels': {'nodes': []}, 'activeLockReason': None}}]

# %%
list_repos = [
    "qunitjs/qunit",
    "mochajs/mocha",
    "facebook/jest",
    "jasmine/jasmine",
    "bitovi/funcunit",
    "GoogleChrome/puppeteer",
    "cypress-io/cypress"
]

# %%
raw_data_file = 'temp/raw_issues_data.txt'

# %%
with open(raw_data_file, 'w') as myfile:
    
    for cur_idx, cur_repo in enumerate(list_repos):
        
        hasNextPage = True
        endCursor = None
        
        cnt_nextPage = 0
        
        print('***** [{}] START repo#{}-{}" *****'.format(str(datetime.datetime.now()), cur_idx, cur_repo))
        
        while hasNextPage:

            # Slow down the requests
            time.sleep(1)
            
            cnt_nextPage += 1
            print('|-- [{}] page#{}" *****'.format(str(datetime.datetime.now()), cnt_nextPage))

            try:
                query = create_query(cur_repo, hasNextPage=hasNextPage, afterCursor=endCursor)
                # Get a result of the test query
                result = run_query(query) # Execute the query


                # See whether we need to go to the next page
                hasNextPage = result['data']['search']['pageInfo']['hasNextPage']
                endCursor = result['data']['search']['pageInfo']['endCursor']

                # Write data to file
                queried_data = result['data']['search']['edges']
                for cur_data in queried_data:
                    cur_json_str = json.dumps(cur_data['node'])
                    myfile.write(cur_json_str + '\n')
            except:
                print('There are errors when retrieving data!')
# Out:
# ***** [2019-07-01 23:30:58.197355] START repo#0-qunitjs/qunit" *****
# |-- [2019-07-01 23:30:59.202638] page#1" *****
# |-- [2019-07-01 23:31:02.222314] page#2" *****
# |-- [2019-07-01 23:31:07.841660] page#3" *****
# |-- [2019-07-01 23:31:12.522847] page#4" *****
# |-- [2019-07-01 23:31:19.097989] page#5" *****
# |-- [2019-07-01 23:31:23.402208] page#6" *****
# |-- [2019-07-01 23:31:28.689065] page#7" *****
# |-- [2019-07-01 23:31:34.034337] page#8" *****
# |-- [2019-07-01 23:31:41.188897] page#9" *****
# |-- [2019-07-01 23:31:46.234173] page#10" *****
# |-- [2019-07-01 23:31:52.261595] page#11" *****
# |-- [2019-07-01 23:31:56.707553] page#12" *****
# |-- [2019-07-01 23:32:01.282281] page#13" *****
# |-- [2019-07-01 23:32:04.958036] page#14" *****
# |-- [2019-07-01 23:32:08.693634] page#15" *****
# ***** [2019-07-01 23:32:09.285224] START repo#1-mochajs/mocha" *****
# |-- [2019-07-01 23:32:10.290591] page#1" *****
# |-- [2019-07-01 23:32:13.866720] page#2" *****
# |-- [2019-07-01 23:32:20.111684] page#3" *****
# |-- [2019-07-01 23:32:23.800771] page#4" *****
# |-- [2019-07-01 23:32:28.460758] page#5" *****
# |-- [2019-07-01 23:32:33.617795] page#6" *****
# |-- [2019-07-01 23:32:37.347220] page#7" *****
# |-- [2019-07-01 23:32:42.120770] page#8" *****
# |-- [2019-07-01 23:32:47.702215] page#9" *****
# |-- [2019-07-01 23:32:51.171486] page#10" *****
# |-- [2019-07-01 23:32:55.775834] page#11" *****
# |-- [2019-07-01 23:33:00.002228] page#12" *****
# |-- [2019-07-01 23:33:08.038956] page#13" *****
# |-- [2019-07-01 23:33:14.231236] page#14" *****
# |-- [2019-07-01 23:33:19.193966] page#15" *****
# |-- [2019-07-01 23:33:23.849089] page#16" *****
# |-- [2019-07-01 23:33:27.847554] page#17" *****
# |-- [2019-07-01 23:33:32.197699] page#18" *****
# |-- [2019-07-01 23:33:38.279240] page#19" *****
# |-- [2019-07-01 23:33:44.498909] page#20" *****
# ***** [2019-07-01 23:33:47.962892] START repo#2-facebook/jest" *****
# |-- [2019-07-01 23:33:48.966013] page#1" *****
# |-- [2019-07-01 23:33:51.956653] page#2" *****
# |-- [2019-07-01 23:33:55.235237] page#3" *****
# |-- [2019-07-01 23:34:00.172076] page#4" *****
# |-- [2019-07-01 23:34:04.783851] page#5" *****
# |-- [2019-07-01 23:34:10.068827] page#6" *****
# |-- [2019-07-01 23:34:13.566987] page#7" *****
# |-- [2019-07-01 23:34:19.678055] page#8" *****
# |-- [2019-07-01 23:34:24.347024] page#9" *****
# |-- [2019-07-01 23:34:29.820209] page#10" *****
# |-- [2019-07-01 23:34:35.093383] page#11" *****
# |-- [2019-07-01 23:34:39.830849] page#12" *****
# |-- [2019-07-01 23:34:44.187194] page#13" *****
# |-- [2019-07-01 23:34:49.264719] page#14" *****
# |-- [2019-07-01 23:34:53.736747] page#15" *****
# |-- [2019-07-01 23:34:58.533127] page#16" *****
# |-- [2019-07-01 23:35:03.059483] page#17" *****
# |-- [2019-07-01 23:35:08.870646] page#18" *****
# |-- [2019-07-01 23:35:13.300606] page#19" *****
# |-- [2019-07-01 23:35:17.569935] page#20" *****
# ***** [2019-07-01 23:35:21.299544] START repo#3-jasmine/jasmine" *****
# |-- [2019-07-01 23:35:22.300657] page#1" *****
# |-- [2019-07-01 23:35:25.238805] page#2" *****
# |-- [2019-07-01 23:35:29.780436] page#3" *****
# |-- [2019-07-01 23:35:33.653102] page#4" *****
# |-- [2019-07-01 23:35:37.598159] page#5" *****
# |-- [2019-07-01 23:35:42.015204] page#6" *****
# |-- [2019-07-01 23:35:46.342827] page#7" *****
# |-- [2019-07-01 23:35:50.533705] page#8" *****
# |-- [2019-07-01 23:35:56.079027] page#9" *****
# |-- [2019-07-01 23:36:00.059853] page#10" *****
# |-- [2019-07-01 23:36:03.877118] page#11" *****
# |-- [2019-07-01 23:36:07.659027] page#12" *****
# |-- [2019-07-01 23:36:12.044614] page#13" *****
# |-- [2019-07-01 23:36:16.559708] page#14" *****
# |-- [2019-07-01 23:36:20.678276] page#15" *****
# |-- [2019-07-01 23:36:25.262073] page#16" *****
# |-- [2019-07-01 23:36:29.517011] page#17" *****
# |-- [2019-07-01 23:36:35.210256] page#18" *****
# |-- [2019-07-01 23:36:40.255003] page#19" *****
# |-- [2019-07-01 23:36:43.885111] page#20" *****
# ***** [2019-07-01 23:36:47.170337] START repo#4-bitovi/funcunit" *****
# |-- [2019-07-01 23:36:48.175545] page#1" *****
# |-- [2019-07-01 23:36:51.743316] page#2" *****
# |-- [2019-07-01 23:36:54.510394] page#3" *****
# |-- [2019-07-01 23:36:57.331252] page#4" *****
# ***** [2019-07-01 23:36:57.781785] START repo#5-GoogleChrome/puppeteer" *****
# |-- [2019-07-01 23:36:58.784962] page#1" *****
# |-- [2019-07-01 23:37:01.188894] page#2" *****
# |-- [2019-07-01 23:37:05.461122] page#3" *****
# |-- [2019-07-01 23:37:09.076469] page#4" *****
# |-- [2019-07-01 23:37:12.136569] page#5" *****
# |-- [2019-07-01 23:37:16.557314] page#6" *****
# |-- [2019-07-01 23:37:21.396794] page#7" *****
# |-- [2019-07-01 23:37:25.370740] page#8" *****
# |-- [2019-07-01 23:37:29.355279] page#9" *****
# |-- [2019-07-01 23:37:34.481661] page#10" *****
# |-- [2019-07-01 23:37:38.465392] page#11" *****
# |-- [2019-07-01 23:37:41.843771] page#12" *****
# |-- [2019-07-01 23:37:45.330908] page#13" *****
# |-- [2019-07-01 23:37:49.318786] page#14" *****
# |-- [2019-07-01 23:37:53.544960] page#15" *****
# |-- [2019-07-01 23:37:57.175889] page#16" *****
# |-- [2019-07-01 23:38:02.121030] page#17" *****
# |-- [2019-07-01 23:38:06.215132] page#18" *****
# |-- [2019-07-01 23:38:11.146862] page#19" *****
# |-- [2019-07-01 23:38:16.657913] page#20" *****
# ***** [2019-07-01 23:38:20.170822] START repo#6-cypress-io/cypress" *****
# |-- [2019-07-01 23:38:21.171480] page#1" *****
# |-- [2019-07-01 23:38:23.774985] page#2" *****
# |-- [2019-07-01 23:38:27.474182] page#3" *****
# |-- [2019-07-01 23:38:32.670610] page#4" *****
# |-- [2019-07-01 23:38:38.636758] page#5" *****
# |-- [2019-07-01 23:38:44.340136] page#6" *****
# |-- [2019-07-01 23:38:50.463107] page#7" *****
# |-- [2019-07-01 23:38:54.968964] page#8" *****
# |-- [2019-07-01 23:38:59.076271] page#9" *****
# |-- [2019-07-01 23:39:04.852791] page#10" *****
# |-- [2019-07-01 23:39:09.319064] page#11" *****
# |-- [2019-07-01 23:39:13.885627] page#12" *****
# |-- [2019-07-01 23:39:18.389808] page#13" *****
# |-- [2019-07-01 23:39:22.414371] page#14" *****
# |-- [2019-07-01 23:39:28.015418] page#15" *****
# |-- [2019-07-01 23:39:32.766321] page#16" *****
# |-- [2019-07-01 23:39:36.634202] page#17" *****
# |-- [2019-07-01 23:39:41.241629] page#18" *****
# |-- [2019-07-01 23:39:45.654464] page#19" *****
# |-- [2019-07-01 23:39:50.481887] page#20" *****

# %%
with open(raw_data_file) as f:
    raw_content = f.readlines()

# %%
out_json_name_raw = 'temp/github_repo_issues_raw.json'

# %%
# Remove whitespace characters like `\n` at the end of each line
all_content = [x.strip() for x in raw_content] 

# Assemble json
all_json_str = ','.join(all_content)
out_json_str = '[{}]'.format(all_json_str)


with open(out_json_name_raw, 'w') as f:  
    f.write(out_json_str)

# %%
with open(out_json_name_raw) as json_file:  
    data_repo = json.load(json_file)

# %%
len(data_repo)
# Out:
# 5851

# %%
data_repo[0]
# Out:
# {'number': 1399, 'title': 'Can the test file name be passed in the "suitestart" and "suiteend" callback ?', 'url': 'https://github.com/qunitjs/qunit/issues/1399', 'createdAt': '2019-06-20T23:29:44Z', 'updatedAt': '2019-06-20T23:29:44Z', 'closedAt': None, 'state': 'OPEN', 'closed': False, 'locked': False, 'author': {'login': 'muthu90ec'}, 'authorAssociation': 'NONE', 'participants': {'totalCount': 1, 'nodes': [{'login': 'muthu90ec', 'company': None}]}, 'comments': {'totalCount': 0, 'nodes': []}, 'labels': {'nodes': []}, 'activeLockReason': None}

# %%
list(data_repo[0].keys())
# Out:
# ['number', 'title', 'url', 'createdAt', 'updatedAt', 'closedAt', 'state', 'closed', 'locked', 'author', 'authorAssociation', 'participants', 'comments', 'labels', 'activeLockReason']

# %%
data_repo[10]['labels']
# Out:
# {'nodes': []}

# %%
cur_data = data_repo[4]

# %%
clean_data = []

for cur_data in data_repo:
    new_data = OrderedDict() 

    cur_url = cur_data['url']
    new_data['repo_name'] = re.findall(r'https:\/\/github.com\/(.*)\/issues/\d', cur_url)[0]
    new_data['issue_id'] = cur_data['number']
    new_data['title'] = cur_data['title']
    new_data['url'] = cur_url
    new_data['createdAt'] = cur_data['createdAt']
    new_data['updatedAt'] = cur_data['updatedAt']
    new_data['closedAt'] = cur_data['closedAt']
    new_data['state'] = cur_data['state']
    new_data['closed'] = cur_data['closed']
    new_data['locked'] = cur_data['locked']
    new_data['activeLockReason'] = cur_data['activeLockReason']

    new_data['authorLogin']= cur_data['author']['login'] if cur_data['author'] else ''
    new_data['authorAssociation'] = cur_data['authorAssociation']

    new_data['participants'] = OrderedDict() 
    new_data['participants']['totalCount'] = cur_data['participants']['totalCount']
    new_data['participants']['data'] = cur_data['participants']['nodes']

    new_data['comments'] = OrderedDict() 
    new_data['comments']['totalCount'] = cur_data['comments']['totalCount']

    cur_all_comments = cur_data['comments']['nodes']
    cur_data_comments = []
    for cur_comment in cur_all_comments:
        new_comment = OrderedDict() 
        new_comment['authorLogin'] = cur_comment['author']['login'] if cur_comment['author'] else ''
        new_comment['authorAssociation'] = cur_comment['authorAssociation']
        new_comment['createdAt'] = cur_comment['createdAt']
        new_comment['contents'] = cur_comment['bodyText']
        cur_data_comments.append(new_comment)


    new_data['comments']['data'] = cur_data_comments

    new_data['labels'] = [x['name'] for x in cur_data['labels']['nodes']]
    
    clean_data.append(new_data)

# %%
len(clean_data)
# Out:
# 5851

# %%
clean_data[2]
# Out:
# OrderedDict([('repo_name', 'qunitjs/qunit'), ('issue_id', 1394), ('title', 'Display progress in test runner during test suite execution'), ('url', 'https://github.com/qunitjs/qunit/issues/1394'), ('createdAt', '2019-05-13T22:53:27Z'), ('updatedAt', '2019-06-18T17:42:10Z'), ('closedAt', '2019-06-18T17:42:10Z'), ('state', 'CLOSED'), ('closed', True), ('locked', False), ('activeLockReason', None), ('authorLogin', 'ghaagsma'), ('authorAssociation', 'CONTRIBUTOR'), ('participants', OrderedDict([('totalCount', 2), ('data', [{'login': 'ghaagsma', 'company': None}, {'login': 'trentmwillis', 'company': '@Netflix'}])])), ('comments', OrderedDict([('totalCount', 1), ('data', [OrderedDict([('authorLogin', 'trentmwillis'), ('authorAssociation', 'MEMBER'), ('createdAt', '2019-05-17T16:12:02Z'), ('contents', 'Seems like a great idea to me! A pull request to implement would be appreciated 🙂')])])])), ('labels', ['component-reporter'])])

# %%
out_json_name_clean = 'temp/github_repo_issues_2019_July_1.json'

# %%
with open(out_json_name_clean, 'w') as fp:
    json.dump(clean_data, fp)

# %%
with open(out_json_name_clean) as json_file:  
    data_new = json.load(json_file)

# %%
len(data_new)
# Out:
# 5851

# %%
data_new[704]
# Out:
# {'repo_name': 'mochajs/mocha', 'issue_id': 3959, 'title': 'async await execution crash no error reported', 'url': 'https://github.com/mochajs/mocha/issues/3959', 'createdAt': '2019-06-25T11:25:39Z', 'updatedAt': '2019-06-25T11:43:46Z', 'closedAt': '2019-06-25T11:43:46Z', 'state': 'CLOSED', 'closed': True, 'locked': False, 'activeLockReason': None, 'authorLogin': 'adrianwix', 'authorAssociation': 'NONE', 'participants': {'totalCount': 1, 'data': [{'login': 'adrianwix', 'company': None}]}, 'comments': {'totalCount': 1, 'data': [{'authorLogin': 'adrianwix', 'authorAssociation': 'NONE', 'createdAt': '2019-06-25T11:43:46Z', 'contents': "Hi, I don't know why every time I post an issue a magical light come to me and solve it hahhaaha.\nHere is the explanation of what exactly happened I case it helps someone in the future.\nThis test is from a Free Code Camp project I made months ago using express. I was using chai-http for API testing which requires me to export the index.js file from the server and when starting the test It would use this file to start the server, get the address and execute the API test.\nI wanted to build it now using Koa and Nextjs. Which make a little more complicated exporting the index.js file from the app because Next need to compile every time. For that reason, I started running the server apart and then executing the test.\nBecause of that, the test file could not access the MongoDB connection. So the solution was stupidly simple as running await mongoose.connect(process.env.MONGOLAB_URI, { useNewUrlParser: true }); in the Test file.\nI hope this may help somebody, bye."}]}, 'labels': ['unconfirmed-bug']}
