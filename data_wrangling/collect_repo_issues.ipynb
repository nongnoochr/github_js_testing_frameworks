# %% [markdown]
# # Collect data of issues in github repositories

# %%
import json
import time
import datetime

import pandas as pd
import numpy as np

import requests
import re
from collections import OrderedDict

# %% [markdown]
# ### Gather data via GitHub's GraphQL

# %%
# # See how to get a token here: https://github.blog/2013-05-16-personal-api-tokens/
api_token = "<Your Token>"

headers = {'Authorization': 'token %s' % api_token}

# %%
def run_query(query): 
    ''' A simple function to use requests.post to make the API call. Note the json= section. '''
    
    request = requests.post('https://api.github.com/graphql', json={'query': query}, headers=headers)
    if request.status_code == 200:
        return request.json()
    else:
        raise Exception("Query failed to run by returning code of {}. {}".format(request.status_code, query))

# %%
# Create a GraphQL query that we will use to collect data        
def create_query(repo_name, hasNextPage=True, afterCursor=None):
    
    if hasNextPage and afterCursor:
        strAfter = ', after:"{}",'.format(afterCursor)
    else:
        strAfter = ''
        
    repo_parts = repo_name.split('/')
    repo_owner = repo_parts[0]
    name_of_repo = repo_parts[1]
        
    query = '''
    {
      rateLimit {
        cost
        remaining
        resetAt
      }
      repository(owner: %s, name: %s) {
        issues(first: 100 %s) {
          totalCount
          pageInfo {
            hasNextPage
            startCursor
            endCursor
          }
          edges {
            node {
              repository {
                nameWithOwner
              }
              number
              url
              title
              bodyText
              createdAt
              updatedAt
              closedAt
              state
              closed
              locked
              activeLockReason
              author {
                login

              }
              authorAssociation
              participants(first: 100) {
                totalCount
                nodes {
                  login
                  company
                }
              }
              comments(first: 100) {
                totalCount
                nodes {
                  author {
                    login
                  }
                  authorAssociation
                  createdAt
                  bodyText
                  reactions(first:20) {
                    totalCount
                    nodes {
                      content
                    }
                  }
                }
              }
              reactions(first:100) {
                totalCount
                nodes {
                  content
                }
              }
              labels(first: 100) {
                nodes {
                  name
                }
              }
              milestone {
                id
                title
                description
                createdAt
                dueOn
                number
                closed


              }
            }
          }
        }
      }
    }
    ''' % (repo_owner, name_of_repo, strAfter)
        
#     query = '''
#     {
#       rateLimit {
#         cost
#         remaining
#         resetAt
#       }
#       search(first: 100,%s type: ISSUE, query: "repo:%s is:issue") {
#         issueCount
#         pageInfo {
#           hasNextPage
#           endCursor
#         }
#         edges {
#           node {
#             ... on Issue {
#               number
#               url
#               title
#               bodyText
#               createdAt
#               updatedAt
#               closedAt
#               state
#               closed
#               locked
#               activeLockReason
#               author {
#                 login
#               }
#               authorAssociation
#               participants(first:100) {
#                 totalCount
#                 nodes {
#                   login
#                   company
#                 }
#               }
#               comments(first:100) {
#                 totalCount
#                 nodes {
#                   author {
#                     login
#                   }
#                   authorAssociation
#                   createdAt
#                   bodyText
#                 }
#               }
#               labels(first:100) {
#                 nodes {
#                   name
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#     ''' % (strAfter, repo_name)
    
    return query

# %%
"bitovi/funcunit".split('/')
# Out:
# ['bitovi', 'funcunit']

# %%
query = create_query("qunitjs/qunit")
result = run_query(query)

# %%
result
# Out:
# {'data': {'rateLimit': {'cost': 104, 'remaining': 4581, 'resetAt': '2019-07-03T00:23:18Z'}, 'repository': {'issues': {'totalCount': 708, 'pageInfo': {'hasNextPage': True, 'startCursor': 'Y3Vyc29yOnYyOpHN-sg=', 'endCursor': 'Y3Vyc29yOnYyOpHOABV1Aw=='}, 'edges': [{'node': {'repository': {'nameWithOwner': 'qunitjs/qunit'}, 'number': 1, 'url': 'https://github.com/qunitjs/qunit/issues/1', 'title': 'noglobals GET parameter ignored', 'bodyText': 'QUnit.init overrides the config var, resetting the noglobals config to false. Since the noglobals get parameter is read before QUnit.init, the noglobals parameter is ignored.', 'createdAt': '2009-10-02T14:16:41Z', 'updatedAt': '2014-05-31T10:55:47Z', 'closedAt': '2009-11-05T13:16:45Z', 'state': 'CLOSED', 'closed': True, 'locked': False, 'activeLockReason': None, 'author': {'login': 'kassens'}, 'authorAssociation': 'CONTRIBUTOR', 'participants': {'totalCount': 2, 'nodes': [{'login': 'kassens', 'company': 'Facebook'}, {'login': 'jeresig', 'company': '@Khan '}]}, 'comments': {'totalCount': 1, 'nodes': [{'author': {'login': 'jeresig'}, 'authorAssociation': 'CONTRIBUTOR', 'createdAt': '2009-11-05T13:16:44Z', 'bodyText': "This shouldn't be the case any more - please let me know if it's still a problem, though.", 'reactions': {'totalCount': 0, 'nodes': []}}]}, 'reactions': {'totalCount': 0, 'nodes': []}, 'labels': {'nodes': []}, 'milestone': None}}, {'node': {'repository': {'nameWithOwner': 'qunitjs/qunit'}, 'number': 2, 'url': 'https://github.com/qunitjs/qunit/issues/2', 'title': 'Test Suite URL Params need their own query string', 'bodyText': 'If you use qunit with testswarm it fails to run tests because testswarm adds url params to the tests. So instead of just looking for /test?this is a test, it should be something like /test?t=this is a test', 'createdAt': '2009-10-12T14:41:46Z', 'updatedAt': '2014-05-31T10:55:47Z', 'closedAt': '2009-11-05T13:09:47Z', 'state': 'CLOSED', 'closed': True, 'locked': False, 'activeLockReason': None, 'author': {'login': 'RyanS'}, 'authorAssociation': 'CONTRIBUTOR', 'participants': {'totalCount': 2, 'nodes': [{'login': 'RyanS', 'company': None}, {'login': 'jeresig', 'company': '@Khan '}]}, 'comments': {'totalCount': 2, 'nodes': [{'author': {'login': 'RyanS'}, 'authorAssociation': 'CONTRIBUTOR', 'createdAt': '2009-10-12T15:32:23Z', 'bodyText': 'nm, it expects the first param to be the test. Guess I just need to modify the task that adds the testswarm test ;)', 'reactions': {'totalCount': 0, 'nodes': []}}, {'author': {'login': 'jeresig'}, 'authorAssociation': 'CONTRIBUTOR', 'createdAt': '2009-11-05T13:09:46Z', 'bodyText': 'I merged in your tweak.', 'reactions': {'totalCount': 0, 'nodes': []}}]}, 'reactions': {'totalCount': 0, 'nodes': []}, 'labels': {'nodes': []}, 'milestone': None}}, {'node': {'repository': {'nameWithOwner': 'qunitjs/qunit'}, 'number': 3, 'url': 'https://github.com/qunitjs/qunit/issues/3', 'title': 'module name is not shown', 'bodyText': 'When modules are defined, their names do not appear (for me) next to the test names in the output.\nThe config object is defined on line 353, and config is assigned to in QUnit.init. config.currentModule is set in the module function and accessed in the test function. It looks like a different config object is being referenced in each of the different functions.', 'createdAt': '2009-10-25T03:48:40Z', 'updatedAt': '2009-11-05T13:08:48Z', 'closedAt': '2009-11-05T13:08:48Z', 'state': 'CLOSED', 'closed': True, 'locked': False, 'activeLockReason': None, 'author': {'login': 'smith'}, 'authorAssociation': 'NONE', 'participants': {'totalCount': 3, 'nodes': [{'login': 'smith', 'company': '@newrelic'}, {'login': 'zhaoz', 'company': None}, {'login': 'jeresig', 'company': '@Khan '}]}, 'comments': {'totalCount': 3, 'nodes': [{'author': {'login': 'zhaoz'}, 'authorAssociation': 'NONE', 'createdAt': '2009-10-29T20:52:03Z', 'bodyText': 'This commit seems to have fixed the issue, although it is untested with asyncTest stuff (which is ...

# %%
# Out:
# 3645

# %% [markdown]
# Note that the api only return results update 1000 issues

# %%
list_repos = [
#     "qunitjs/qunit",
#     "mochajs/mocha",
#     "facebook/jest",
#     "jasmine/jasmine",
#     "bitovi/funcunit",
#     "GoogleChrome/puppeteer",
    "cypress-io/cypress"
]

# list_repos = [
#     "jasmine/jasmine",
# ]

# list_repos = ["bitovi/funcunit"]

# %%
get_raw_data_file = lambda x: 'temp/raw_issues_data_{}.txt'.format(x)

# %%
dict_status = {}

for cur_idx, cur_repo in enumerate(list_repos):
    
    dict_status[cur_repo] = {}
    
    print('***** [{}] START repo#{}-{}" *****'.format(str(datetime.datetime.now()), cur_idx, cur_repo))
    
    raw_data_file_cur_repo = get_raw_data_file(cur_repo.split('/')[1])
    with open(raw_data_file_cur_repo, 'w') as myfile:
        
        hasNextPage = True
        endCursor = None
        
        cnt_nextPage = 1
        
        
        while hasNextPage:
            
            print('|-- [{}] page#{}" *****'.format(str(datetime.datetime.now()), cnt_nextPage))

            try:
                query = create_query(cur_repo, hasNextPage=hasNextPage, afterCursor=endCursor)
                # Get a result of the test query
                result = run_query(query) # Execute the query
                
                print('* Remaining RateLimit: ', result['data']['rateLimit']['remaining'])
                
                if cnt_nextPage == 1:
                    dict_status[cur_repo]['issueCount'] = result['data']['repository']['issues']['totalCount']


                # See whether we need to go to the next page
                hasNextPage = result['data']['repository']['issues']['pageInfo']['hasNextPage']
                endCursor = result['data']['repository']['issues']['pageInfo']['endCursor']

                # Write data to file
                queried_data = result['data']['repository']['issues']['edges']
                for cur_data in queried_data:
                    cur_json_str = json.dumps(cur_data['node'])
                    myfile.write(cur_json_str + '\n')
                    
                cnt_nextPage += 1

                    
            except Exception as e: 
                print('There are errors when retrieving data - Retry the same query again if this happens!')
                print(e)
                
            # Slow down the requests
            time.sleep(120)
                
        dict_status[cur_repo]['total_queried_pages'] = cnt_nextPage
# Out:
# ***** [2019-07-02 21:35:11.367109] START repo#0-mochajs/mocha" *****
# |-- [2019-07-02 21:35:11.369093] page#1" *****
# * Remaining RateLimit:  4896
# |-- [2019-07-02 21:37:16.286225] page#2" *****
# * Remaining RateLimit:  4792
# |-- [2019-07-02 21:39:23.146005] page#3" *****
# * Remaining RateLimit:  4896
# |-- [2019-07-02 21:41:31.537777] page#4" *****
# * Remaining RateLimit:  4792
# |-- [2019-07-02 21:43:41.526847] page#5" *****
# * Remaining RateLimit:  4896
# |-- [2019-07-02 21:45:47.600411] page#6" *****
# * Remaining RateLimit:  4792
# |-- [2019-07-02 21:47:53.542685] page#7" *****
# * Remaining RateLimit:  4896
# |-- [2019-07-02 21:49:58.685013] page#8" *****
# * Remaining RateLimit:  4792
# |-- [2019-07-02 21:52:07.280852] page#9" *****
# * Remaining RateLimit:  4896
# |-- [2019-07-02 21:54:14.209111] page#10" *****
# * Remaining RateLimit:  4792
# |-- [2019-07-02 21:56:23.235786] page#11" *****
# * Remaining RateLimit:  4896
# |-- [2019-07-02 21:58:31.286612] page#12" *****
# * Remaining RateLimit:  4792
# |-- [2019-07-02 22:00:37.024959] page#13" *****
# * Remaining RateLimit:  4896
# |-- [2019-07-02 22:02:45.666086] page#14" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# Query failed to run by returning code of 502.
#     {
#       rateLimit {
#         cost
#         remaining
#         resetAt
#       }
#       repository(owner: mochajs, name: mocha) {
#         issues(first: 100 , after:"Y3Vyc29yOnYyOpHOCI8iKA==",) {
#           totalCount
#           pageInfo {
#             hasNextPage
#             startCursor
#             endCursor
#           }
#           edges {
#             node {
#               repository {
#                 nameWithOwner
#               }
#               number
#               url
#               title
#               bodyText
#               createdAt
#               updatedAt
#               closedAt
#               state
#               closed
#               locked
#               activeLockReason
#               author {
#                 login
#
#               }
#               authorAssociation
#               participants(first: 100) {
#                 totalCount
#                 nodes {
#                   login
#                   company
#                 }
#               }
#               comments(first: 100) {
#                 totalCount
#                 nodes {
#                   author {
#                     login
#                   }
#                   authorAssociation
#                   createdAt
#                   bodyText
#                   reactions(first:20) {
#                     totalCount
#                     nodes {
#                       content
#                     }
#                   }
#                 }
#               }
#               reactions(first:100) {
#                 totalCount
#                 nodes {
#                   content
#                 }
#               }
#               labels(first: 100) {
#                 nodes {
#                   name
#                 }
#               }
#               milestone {
#                 id
#                 title
#                 description
#                 createdAt
#                 dueOn
#                 number
#                 closed
#
#
#               }
#             }
#           }
#         }
#       }
#     }
#
# |-- [2019-07-02 22:04:56.209814] page#14" *****
# * Remaining RateLimit:  4896
# |-- [2019-07-02 22:07:03.505269] page#15" *****
# * Remaining RateLimit:  4792
# |-- [2019-07-02 22:09:13.394620] page#16" *****
# * Remaining RateLimit:  4896
# |-- [2019-07-02 22:11:22.071154] page#17" *****
# * Remaining RateLimit:  4792
# |-- [2019-07-02 22:13:29.580799] page#18" *****
# * Remaining RateLimit:  4896
# |-- [2019-07-02 22:15:37.830976] page#19" *****
# * Remaining RateLimit:  4792
# |-- [2019-07-02 22:17:45.185189] page#20" *****
# * Remaining RateLimit:  4896
# |-- [2019-07-02 22:19:51.625456] page#21" *****
# * Remaining RateLimit:  4792
# |-- [2019-07-02 22:22:01.338557] page#22" *****
# * Remaining RateLimit:  4896
# |-- [2019-07-02 22:24:08.450153] page#23" *****
# * Remaining RateLimit:  4792
# |-- [2019-07-02 22:26:16.599118] page#24" *****
# * Remaining RateLimit:  4896
# ***** [2019-07-02 22:28:21.544281] START repo#1-facebook/jest" *****
# |-- [2019-07-02 22:28:21.546541] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# Query failed to run by returning code of 502.
#     {
#       rateLimit {
#         cost
#         remaining
#         resetAt
#       }
#       repository(owner: facebook, name: jest) {
#         issues(first: 100 ) {
#           totalCount
#           pageInfo {
#             hasNextPage
#             startCursor
#             endCursor
#           }
#           edges {
#             node {
#               repository {
#                 nameWithOwner
#               }
#               number
#               url
#               title
#               bodyText
#               createdAt
#               updatedAt
#               closedAt
#               state
#               closed
#               locked
#               activeLockReason
#               author {
#                 login
#
#               }
#               authorAssociation
#               participants(first: 100) {
#                 totalCount
#                 nodes {
#                   login
#                   company
#                 }
#               }
#               comments(first: 100) {
#                 totalCount
#                 nodes {
#                   author {
#                     login
#                   }
#                   authorAssociation
#                   createdAt
#                   bodyText
#                   reactions(first:20) {
#                     totalCount
#                     nodes {
#                       content
#                     }
#                   }
#                 }
#               }
#               reactions(first:100) {
#                 totalCount
#                 nodes {
#                   content
#                 }
#               }
#               labels(first: 100) {
#                 nodes {
#                   name
#                 }
#               }
#               milestone {
#                 id
#                 title
#                 description
#                 createdAt
#                 dueOn
#                 number
#                 closed
#
#
#               }
#             }
#           }
#         }
#       }
#     }
#
# |-- [2019-07-02 22:30:31.927293] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# Query failed to run by returning code of 502.
#     {
#       rateLimit {
#         cost
#         remaining
#         resetAt
#       }
#       repository(owner: facebook, name: jest) {
#         issues(first: 100 ) {
#           totalCount
#           pageInfo {
#             hasNextPage
#             startCursor
#             endCursor
#           }
#           edges {
#             node {
#               repository {
#                 nameWithOwner
#               }
#               number
#               url
#               title
#               bodyText
#               createdAt
#               updatedAt
#               closedAt
#               state
#               closed
#               locked
#               activeLockReason
#               author {
#                 login
#
#               }
#               authorAssociation
#               participants(first: 100) {
#                 totalCount
#                 nodes {
#                   login
#                   company
#                 }
#               }
#               comments(first: 100) {
#                 totalCount
#                 nodes {
#                   author {
#                     login
#                   }
#                   authorAssociation
#                   createdAt
#                   bodyText
#                   reactions(first:20) {
#                     totalCount
#                     nodes {
#                       content
#                     }
#                   }
#                 }
#               }
#               reactions(first:100) {
#                 totalCount
#                 nodes {
#                   content
#                 }
#               }
#               labels(first: 100) {
#                 nodes {
#                   name
#                 }
#               }
#               milestone {
#                 id
#                 title
#                 description
#                 createdAt
#                 dueOn
#                 number
#                 closed
#
#
#               }
#             }
#           }
#         }
#       }
#     }
# |-- [2019-07-02 22:32:42.592378] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# Query failed to run by returning code of 502.
#     {
#       rateLimit {
#         cost
#         remaining
#         resetAt
#       }
#       repository(owner: facebook, name: jest) {
#         issues(first: 100 ) {
#           totalCount
#           pageInfo {
#             hasNextPage
#             startCursor
#             endCursor
#           }
#           edges {
#             node {
#               repository {
#                 nameWithOwner
#               }
#               number
#               url
#               title
#               bodyText
#               createdAt
#               updatedAt
#               closedAt
#               state
#               closed
#               locked
#               activeLockReason
#               author {
#                 login
#
#               }
#               authorAssociation
#               participants(first: 100) {
#                 totalCount
#                 nodes {
#                   login
#                   company
#                 }
#               }
#               comments(first: 100) {
#                 totalCount
#                 nodes {
#                   author {
#                     login
#                   }
#                   authorAssociation
#                   createdAt
#                   bodyText
#                   reactions(first:20) {
#                     totalCount
#                     nodes {
#                       content
#                     }
#                   }
#                 }
#               }
#               reactions(first:100) {
#                 totalCount
#                 nodes {
#                   content
#                 }
#               }
#               labels(first: 100) {
#                 nodes {
#                   name
#                 }
#               }
#               milestone {
#                 id
#                 title
#                 description
#                 createdAt
#                 dueOn
#                 number
#                 closed
#
#
#               }
#             }
#           }
#         }
#       }
#     }
#
# |-- [2019-07-02 22:34:52.948304] page#1" *****
# * Remaining RateLimit:  4896
# |-- [2019-07-02 22:37:03.118454] page#2" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# Query failed to run by returning code of 502.
#     {
#       rateLimit {
#         cost
#         remaining
#         resetAt
#       }
#       repository(owner: facebook, name: jest) {
#         issues(first: 100 , after:"Y3Vyc29yOnYyOpHOAsO7eQ==",) {
#           totalCount
#           pageInfo {
#             hasNextPage
#             startCursor
#             endCursor
#           }
#           edges {
#             node {
#               repository {
#                 nameWithOwner
#               }
#               number
#               url
#               title
#               bodyText
#               createdAt
#               updatedAt
#               closedAt
#               state
#               closed
#               locked
#               activeLockReason
#               author {
#                 login
#
#               }
#               authorAssociation
#               participants(first: 100) {
#                 totalCount
#                 nodes {
#                   login
#                   company
#                 }
#               }
#               comments(first: 100) {
#                 totalCount
#                 nodes {
#                   author {
#                     login
#                   }
#                   authorAssociation
#                   createdAt
#                   bodyText
#                   reactions(first:20) {
#                     totalCount
#                     nodes {
#                       content
#                     }
#                   }
#                 }
#               }
#               reactions(first:100) {
#                 totalCount
#                 nodes {
#                   content
#                 }
#               }
#               labels(first: 100) {
#                 nodes {
#                   name
#                 }
#               }
#               milestone {
#                 id
#                 title
#                 description
#                 createdAt
#                 dueOn
#                 number
#                 closed
#
#
#               }
#             }
#           }
#         }
#       }
#     }
#
# |-- [2019-07-02 22:39:13.487259] page#2" *****
# * Remaining RateLimit:  4896
# |-- [2019-07-02 22:41:21.761789] page#3" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# Query failed to run by returning code of 502.
#     {
#       rateLimit {
#         cost
#         remaining
#         resetAt
#       }
#       repository(owner: facebook, name: jest) {
#         issues(first: 100 , after:"Y3Vyc29yOnYyOpHOBBLvQw==",) {
#           totalCount
#           pageInfo {
#             hasNextPage
#             startCursor
#             endCursor
#           }
#           edges {
#             node {
#               repository {
#                 nameWithOwner
#               }
#               number
#               url
#               title
#               bodyText
#               createdAt
#               updatedAt
#               closedAt
#               state
#               closed
#               locked
#               activeLockReason
#               author {
#                 login
#
#               }
#               authorAssociation
#               participants(first: 100) {
#                 totalCount
#                 nodes {
#                   login
#                   company
#                 }
#               }
#               comments(first: 100) {
#                 totalCount
#                 nodes {
#                   author {
#                     login
#                   }
#                   authorAssociation
#                   createdAt
#                   bodyText
#                   reactions(first:20) {
#                     totalCount
#                     nodes {
#                       content
#                     }
#                   }
#                 }
#               }
#               reactions(first:100) {
#                 totalCount
#                 nodes {
#                   content
#                 }
#               }
#               labels(first: 100) {
#                 nodes {
#                   name
#                 }
#               }
#               milestone {
#                 id
#                 title
#                 description
#                 createdAt
#                 dueOn
#                 number
#                 closed
#
#
#               }
#             }
#           }
#         }
#       }
#     }
#
# |-- [2019-07-02 22:43:32.095706] page#3" *****
# * Remaining RateLimit:  4896
# |-- [2019-07-02 22:45:39.622000] page#4" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# Query failed to run by returning code of 502.
#     {
#       rateLimit {
#         cost
#         remaining
#         resetAt
#       }
#       repository(owner: facebook, name: jest) {
#         issues(first: 100 , after:"Y3Vyc29yOnYyOpHOBk7M9w==",) {
#           totalCount
#           pageInfo {
#             hasNextPage
#             startCursor
#             endCursor
#           }
#           edges {
#             node {
#               repository {
#                 nameWithOwner
#               }
#               number
#               url
#               title
#               bodyText
#               createdAt
#               updatedAt
#               closedAt
#               state
#               closed
#               locked
#               activeLockReason
#               author {
#                 login
#
#               }
#               authorAssociation
#               participants(first: 100) {
#                 totalCount
#                 nodes {
#                   login
#                   company
#                 }
#               }
#               comments(first: 100) {
#                 totalCount
#                 nodes {
#                   author {
#                     login
#                   }
#                   authorAssociation
#                   createdAt
#                   bodyText
#                   reactions(first:20) {
#                     totalCount
#                     nodes {
#                       content
#                     }
#                   }
#                 }
#               }
#               reactions(first:100) {
#                 totalCount
#                 nodes {
#                   content
#                 }
#               }
#               labels(first: 100) {
#                 nodes {
#                   name
#                 }
#               }
#               milestone {
#                 id
#                 title
#                 description
#                 createdAt
#                 dueOn
#                 number
#                 closed
#
#
#               }
#             }
#           }
#         }
#       }
#     }
# |-- [2019-07-02 22:47:50.062577] page#4" *****
# * Remaining RateLimit:  4896
# |-- [2019-07-02 22:49:56.934709] page#5" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# Query failed to run by returning code of 502.
#     {
#       rateLimit {
#         cost
#         remaining
#         resetAt
#       }
#       repository(owner: facebook, name: jest) {
#         issues(first: 100 , after:"Y3Vyc29yOnYyOpHOB5K5aQ==",) {
#           totalCount
#           pageInfo {
#             hasNextPage
#             startCursor
#             endCursor
#           }
#           edges {
#             node {
#               repository {
#                 nameWithOwner
#               }
#               number
#               url
#               title
#               bodyText
#               createdAt
#               updatedAt
#               closedAt
#               state
#               closed
#               locked
#               activeLockReason
#               author {
#                 login
#
#               }
#               authorAssociation
#               participants(first: 100) {
#                 totalCount
#                 nodes {
#                   login
#                   company
#                 }
#               }
#               comments(first: 100) {
#                 totalCount
#                 nodes {
#                   author {
#                     login
#                   }
#                   authorAssociation
#                   createdAt
#                   bodyText
#                   reactions(first:20) {
#                     totalCount
#                     nodes {
#                       content
#                     }
#                   }
#                 }
#               }
#               reactions(first:100) {
#                 totalCount
#                 nodes {
#                   content
#                 }
#               }
#               labels(first: 100) {
#                 nodes {
#                   name
#                 }
#               }
#               milestone {
#                 id
#                 title
#                 description
#                 createdAt
#                 dueOn
#                 number
#                 closed
#
#
#               }
#             }
#           }
#         }
#       }
#     }
#
# |-- [2019-07-02 22:52:07.291188] page#5" *****
# * Remaining RateLimit:  4896
# |-- [2019-07-02 22:54:15.814220] page#6" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# Query failed to run by returning code of 502.
#     {
#       rateLimit {
#         cost
#         remaining
#         resetAt
#       }
#       repository(owner: facebook, name: jest) {
#         issues(first: 100 , after:"Y3Vyc29yOnYyOpHOCMvL4A==",) {
#           totalCount
#           pageInfo {
#             hasNextPage
#             startCursor
#             endCursor
#           }
#           edges {
#             node {
#               repository {
#                 nameWithOwner
#               }
#               number
#               url
#               title
#               bodyText
#               createdAt
#               updatedAt
#               closedAt
#               state
#               closed
#               locked
#               activeLockReason
#               author {
#                 login
#
#               }
#               authorAssociation
#               participants(first: 100) {
#                 totalCount
#                 nodes {
#                   login
#                   company
#                 }
#               }
#               comments(first: 100) {
#                 totalCount
#                 nodes {
#                   author {
#                     login
#                   }
#                   authorAssociation
#                   createdAt
#                   bodyText
#                   reactions(first:20) {
#                     totalCount
#                     nodes {
#                       content
#                     }
#                   }
#                 }
#               }
#               reactions(first:100) {
#                 totalCount
#                 nodes {
#                   content
#                 }
#               }
#               labels(first: 100) {
#                 nodes {
#                   name
#                 }
#               }
#               milestone {
#                 id
#                 title
#                 description
#                 createdAt
#                 dueOn
#                 number
#                 closed
#
#
#               }
#             }
#           }
#         }
#       }
#     }
#
# |-- [2019-07-02 22:56:26.116750] page#6" *****
# * Remaining RateLimit:  4896
# |-- [2019-07-02 22:58:35.527917] page#7" *****
# * Remaining RateLimit:  4792
# |-- [2019-07-02 23:00:44.736903] page#8" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# Query failed to run by returning code of 502.
#     {
#       rateLimit {
#         cost
#         remaining
#         resetAt
#       }
#       repository(owner: facebook, name: jest) {
#         issues(first: 100 , after:"Y3Vyc29yOnYyOpHOChnErQ==",) {
#           totalCount
#           pageInfo {
#             hasNextPage
#             startCursor
#             endCursor
#           }
#           edges {
#             node {
#               repository {
#                 nameWithOwner
#               }
#               number
#               url
#               title
#               bodyText
#               createdAt
#               updatedAt
#               closedAt
#               state
#               closed
#               locked
#               activeLockReason
#               author {
#                 login
#
#               }
#               authorAssociation
#               participants(first: 100) {
#                 totalCount
#                 nodes {
#                   login
#                   company
#                 }
#               }
#               comments(first: 100) {
#                 totalCount
#                 nodes {
#                   author {
#                     login
#                   }
#                   authorAssociation
#                   createdAt
#                   bodyText
#                   reactions(first:20) {
#                     totalCount
#                     nodes {
#                       content
#                     }
#                   }
#                 }
#               }
#               reactions(first:100) {
#                 totalCount
#                 nodes {
#                   content
#                 }
#               }
#               labels(first: 100) {
#                 nodes {
#                   name
#                 }
#               }
#               milestone {
#                 id
#                 title
#                 description
#                 createdAt
#                 dueOn
#                 number
#                 closed
#
#
#               }
#             }
#           }
#         }
#       }
#     }
#
# |-- [2019-07-02 23:02:55.182345] page#8" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# Query failed to run by returning code of 502.
#     {
#       rateLimit {
#         cost
#         remaining
#         resetAt
#       }
#       repository(owner: facebook, name: jest) {
#         issues(first: 100 , after:"Y3Vyc29yOnYyOpHOChnErQ==",) {
#           totalCount
#           pageInfo {
#             hasNextPage
#             startCursor
#             endCursor
#           }
#           edges {
#             node {
#               repository {
#                 nameWithOwner
#               }
#               number
#               url
#               title
#               bodyText
#               createdAt
#               updatedAt
#               closedAt
#               state
#               closed
#               locked
#               activeLockReason
#               author {
#                 login
#
#               }
#               authorAssociation
#               participants(first: 100) {
#                 totalCount
#                 nodes {
#                   login
#                   company
#                 }
#               }
#               comments(first: 100) {
#                 totalCount
#                 nodes {
#                   author {
#                     login
#                   }
#                   authorAssociation
#                   createdAt
#                   bodyText
#                   reactions(first:20) {
#                     totalCount
#                     nodes {
#                       content
#                     }
#                   }
#                 }
#               }
#               reactions(first:100) {
#                 totalCount
#                 nodes {
#                   content
#                 }
#               }
#               labels(first: 100) {
#                 nodes {
#                   name
#                 }
#               }
#               milestone {
#                 id
#                 title
#                 description
#                 createdAt
#                 dueOn
#                 number
#                 closed
#
#
#               }
#             }
#           }
#         }
#       }
#     }
# |-- [2019-07-02 23:05:05.491334] page#8" *****
# * Remaining RateLimit:  4896
# |-- [2019-07-02 23:07:12.800456] page#9" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# Query failed to run by returning code of 502.
#     {
#       rateLimit {
#         cost
#         remaining
#         resetAt
#       }
#       repository(owner: facebook, name: jest) {
#         issues(first: 100 , after:"Y3Vyc29yOnYyOpHOCmw3fQ==",) {
#           totalCount
#           pageInfo {
#             hasNextPage
#             startCursor
#             endCursor
#           }
#           edges {
#             node {
#               repository {
#                 nameWithOwner
#               }
#               number
#               url
#               title
#               bodyText
#               createdAt
#               updatedAt
#               closedAt
#               state
#               closed
#               locked
#               activeLockReason
#               author {
#                 login
#
#               }
#               authorAssociation
#               participants(first: 100) {
#                 totalCount
#                 nodes {
#                   login
#                   company
#                 }
#               }
#               comments(first: 100) {
#                 totalCount
#                 nodes {
#                   author {
#                     login
#                   }
#                   authorAssociation
#                   createdAt
#                   bodyText
#                   reactions(first:20) {
#                     totalCount
#                     nodes {
#                       content
#                     }
#                   }
#                 }
#               }
#               reactions(first:100) {
#                 totalCount
#                 nodes {
#                   content
#                 }
#               }
#               labels(first: 100) {
#                 nodes {
#                   name
#                 }
#               }
#               milestone {
#                 id
#                 title
#                 description
#                 createdAt
#                 dueOn
#                 number
#                 closed
#
#
#               }
#             }
#           }
#         }
#       }
#     }
#
# |-- [2019-07-02 23:09:23.177718] page#9" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# Query failed to run by returning code of 502.
#     {
#       rateLimit {
#         cost
#         remaining
#         resetAt
#       }
#       repository(owner: facebook, name: jest) {
#         issues(first: 100 , after:"Y3Vyc29yOnYyOpHOCmw3fQ==",) {
#           totalCount
#           pageInfo {
#             hasNextPage
#             startCursor
#             endCursor
#           }
#           edges {
#             node {
#               repository {
#                 nameWithOwner
#               }
#               number
#               url
#               title
#               bodyText
#               createdAt
#               updatedAt
#               closedAt
#               state
#               closed
#               locked
#               activeLockReason
#               author {
#                 login
#
#               }
#               authorAssociation
#               participants(first: 100) {
#                 totalCount
#                 nodes {
#                   login
#                   company
#                 }
#               }
#               comments(first: 100) {
#                 totalCount
#                 nodes {
#                   author {
#                     login
#                   }
#                   authorAssociation
#                   createdAt
#                   bodyText
#                   reactions(first:20) {
#                     totalCount
#                     nodes {
#                       content
#                     }
#                   }
#                 }
#               }
#               reactions(first:100) {
#                 totalCount
#                 nodes {
#                   content
#                 }
#               }
#               labels(first: 100) {
#                 nodes {
#                   name
#                 }
#               }
#               milestone {
#                 id
#                 title
#                 description
#                 createdAt
#                 dueOn
#                 number
#                 closed
#
#
#               }
#             }
#           }
#         }
#       }
#     }
#
# |-- [2019-07-02 23:11:33.537901] page#9" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# Query failed to run by returning code of 502.
#     {
#       rateLimit {
#         cost
#         remaining
#         resetAt
#       }
#       repository(owner: facebook, name: jest) {
#         issues(first: 100 , after:"Y3Vyc29yOnYyOpHOCmw3fQ==",) {
#           totalCount
#           pageInfo {
#             hasNextPage
#             startCursor
#             endCursor
#           }
#           edges {
#             node {
#               repository {
#                 nameWithOwner
#               }
#               number
#               url
#               title
#               bodyText
#               createdAt
#               updatedAt
#               closedAt
#               state
#               closed
#               locked
#               activeLockReason
#               author {
#                 login
#
#               }
#               authorAssociation
#               participants(first: 100) {
#                 totalCount
#                 nodes {
#                   login
#                   company
#                 }
#               }
#               comments(first: 100) {
#                 totalCount
#                 nodes {
#                   author {
#                     login
#                   }
#                   authorAssociation
#                   createdAt
#                   bodyText
#                   reactions(first:20) {
#                     totalCount
#                     nodes {
#                       content
#                     }
#                   }
#                 }
#               }
#               reactions(first:100) {
#                 totalCount
#                 nodes {
#                   content
#                 }
#               }
#               labels(first: 100) {
#                 nodes {
#                   name
#                 }
#               }
#               milestone {
#                 id
#                 title
#                 description
#                 createdAt
#                 dueOn
#                 number
#                 closed
#
#
#               }
#             }
#           }
#         }
#       }
#     }
#
# |-- [2019-07-02 23:13:44.019482] page#9" *****
# * Remaining RateLimit:  4896
# |-- [2019-07-02 23:15:52.750078] page#10" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# Query failed to run by returning code of 502.
#     {
#       rateLimit {
#         cost
#         remaining
#         resetAt
#       }
#       repository(owner: facebook, name: jest) {
#         issues(first: 100 , after:"Y3Vyc29yOnYyOpHOCqb_JQ==",) {
#           totalCount
#           pageInfo {
#             hasNextPage
#             startCursor
#             endCursor
#           }
#           edges {
#             node {
#               repository {
#                 nameWithOwner
#               }
#               number
#               url
#               title
#               bodyText
#               createdAt
#               updatedAt
#               closedAt
#               state
#               closed
#               locked
#               activeLockReason
#               author {
#                 login
#
#               }
#               authorAssociation
#               participants(first: 100) {
#                 totalCount
#                 nodes {
#                   login
#                   company
#                 }
#               }
#               comments(first: 100) {
#                 totalCount
#                 nodes {
#                   author {
#                     login
#                   }
#                   authorAssociation
#                   createdAt
#                   bodyText
#                   reactions(first:20) {
#                     totalCount
#                     nodes {
#                       content
#                     }
#                   }
#                 }
#               }
#               reactions(first:100) {
#                 totalCount
#                 nodes {
#                   content
#                 }
#               }
#               labels(first: 100) {
#                 nodes {
#                   name
#                 }
#               }
#               milestone {
#                 id
#                 title
#                 description
#                 createdAt
#                 dueOn
#                 number
#                 closed
#
#
#               }
#             }
#           }
#         }
#       }
#     }
# |-- [2019-07-02 23:18:03.167476] page#10" *****
# * Remaining RateLimit:  4896
# |-- [2019-07-02 23:20:11.685388] page#11" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# Query failed to run by returning code of 502.
#     {
#       rateLimit {
#         cost
#         remaining
#         resetAt
#       }
#       repository(owner: facebook, name: jest) {
#         issues(first: 100 , after:"Y3Vyc29yOnYyOpHOCu2gtA==",) {
#           totalCount
#           pageInfo {
#             hasNextPage
#             startCursor
#             endCursor
#           }
#           edges {
#             node {
#               repository {
#                 nameWithOwner
#               }
#               number
#               url
#               title
#               bodyText
#               createdAt
#               updatedAt
#               closedAt
#               state
#               closed
#               locked
#               activeLockReason
#               author {
#                 login
#
#               }
#               authorAssociation
#               participants(first: 100) {
#                 totalCount
#                 nodes {
#                   login
#                   company
#                 }
#               }
#               comments(first: 100) {
#                 totalCount
#                 nodes {
#                   author {
#                     login
#                   }
#                   authorAssociation
#                   createdAt
#                   bodyText
#                   reactions(first:20) {
#                     totalCount
#                     nodes {
#                       content
#                     }
#                   }
#                 }
#               }
#               reactions(first:100) {
#                 totalCount
#                 nodes {
#                   content
#                 }
#               }
#               labels(first: 100) {
#                 nodes {
#                   name
#                 }
#               }
#               milestone {
#                 id
#                 title
#                 description
#                 createdAt
#                 dueOn
#                 number
#                 closed
#
#
#               }
#             }
#           }
#         }
#       }
#     }
#
# |-- [2019-07-02 23:22:22.129614] page#11" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# Query failed to run by returning code of 502.
#     {
#       rateLimit {
#         cost
#         remaining
#         resetAt
#       }
#       repository(owner: facebook, name: jest) {
#         issues(first: 100 , after:"Y3Vyc29yOnYyOpHOCu2gtA==",) {
#           totalCount
#           pageInfo {
#             hasNextPage
#             startCursor
#             endCursor
#           }
#           edges {
#             node {
#               repository {
#                 nameWithOwner
#               }
#               number
#               url
#               title
#               bodyText
#               createdAt
#               updatedAt
#               closedAt
#               state
#               closed
#               locked
#               activeLockReason
#               author {
#                 login
#
#               }
#               authorAssociation
#               participants(first: 100) {
#                 totalCount
#                 nodes {
#                   login
#                   company
#                 }
#               }
#               comments(first: 100) {
#                 totalCount
#                 nodes {
#                   author {
#                     login
#                   }
#                   authorAssociation
#                   createdAt
#                   bodyText
#                   reactions(first:20) {
#                     totalCount
#                     nodes {
#                       content
#                     }
#                   }
#                 }
#               }
#               reactions(first:100) {
#                 totalCount
#                 nodes {
#                   content
#                 }
#               }
#               labels(first: 100) {
#                 nodes {
#                   name
#                 }
#               }
#               milestone {
#                 id
#                 title
#                 description
#                 createdAt
#                 dueOn
#                 number
#                 closed
#
#
#               }
#             }
#           }
#         }
#       }
#     }
#
# |-- [2019-07-02 23:24:32.494163] page#11" *****
# * Remaining RateLimit:  4792
# |-- [2019-07-02 23:26:41.170243] page#12" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# Query failed to run by returning code of 502.
#     {
#       rateLimit {
#         cost
#         remaining
#         resetAt
#       }
#       repository(owner: facebook, name: jest) {
#         issues(first: 100 , after:"Y3Vyc29yOnYyOpHOC1BreQ==",) {
#           totalCount
#           pageInfo {
#             hasNextPage
#             startCursor
#             endCursor
#           }
#           edges {
#             node {
#               repository {
#                 nameWithOwner
#               }
#               number
#               url
#               title
#               bodyText
#               createdAt
#               updatedAt
#               closedAt
#               state
#               closed
#               locked
#               activeLockReason
#               author {
#                 login
#
#               }
#               authorAssociation
#               participants(first: 100) {
#                 totalCount
#                 nodes {
#                   login
#                   company
#                 }
#               }
#               comments(first: 100) {
#                 totalCount
#                 nodes {
#                   author {
#                     login
#                   }
#                   authorAssociation
#                   createdAt
#                   bodyText
#                   reactions(first:20) {
#                     totalCount
#                     nodes {
#                       content
#                     }
#                   }
#                 }
#               }
#               reactions(first:100) {
#                 totalCount
#                 nodes {
#                   content
#                 }
#               }
#               labels(first: 100) {
#                 nodes {
#                   name
#                 }
#               }
#               milestone {
#                 id
#                 title
#                 description
#                 createdAt
#                 dueOn
#                 number
#                 closed
#
#
#               }
#             }
#           }
#         }
#       }
#     }
#
# |-- [2019-07-02 23:28:51.439517] page#12" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# Query failed to run by returning code of 502.
#     {
#       rateLimit {
#         cost
#         remaining
#         resetAt
#       }
#       repository(owner: facebook, name: jest) {
#         issues(first: 100 , after:"Y3Vyc29yOnYyOpHOC1BreQ==",) {
#           totalCount
#           pageInfo {
#             hasNextPage
#             startCursor
#             endCursor
#           }
#           edges {
#             node {
#               repository {
#                 nameWithOwner
#               }
#               number
#               url
#               title
#               bodyText
#               createdAt
#               updatedAt
#               closedAt
#               state
#               closed
#               locked
#               activeLockReason
#               author {
#                 login
#
#               }
#               authorAssociation
#               participants(first: 100) {
#                 totalCount
#                 nodes {
#                   login
#                   company
#                 }
#               }
#               comments(first: 100) {
#                 totalCount
#                 nodes {
#                   author {
#                     login
#                   }
#                   authorAssociation
#                   createdAt
#                   bodyText
#                   reactions(first:20) {
#                     totalCount
#                     nodes {
#                       content
#                     }
#                   }
#                 }
#               }
#               reactions(first:100) {
#                 totalCount
#                 nodes {
#                   content
#                 }
#               }
#               labels(first: 100) {
#                 nodes {
#                   name
#                 }
#               }
#               milestone {
#                 id
#                 title
#                 description
#                 createdAt
#                 dueOn
#                 number
#                 closed
#
#
#               }
#             }
#           }
#         }
#       }
#     }
# |-- [2019-07-02 23:31:01.817416] page#12" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# Query failed to run by returning code of 502.
#     {
#       rateLimit {
#         cost
#         remaining
#         resetAt
#       }
#       repository(owner: facebook, name: jest) {
#         issues(first: 100 , after:"Y3Vyc29yOnYyOpHOC1BreQ==",) {
#           totalCount
#           pageInfo {
#             hasNextPage
#             startCursor
#             endCursor
#           }
#           edges {
#             node {
#               repository {
#                 nameWithOwner
#               }
#               number
#               url
#               title
#               bodyText
#               createdAt
#               updatedAt
#               closedAt
#               state
#               closed
#               locked
#               activeLockReason
#               author {
#                 login
#
#               }
#               authorAssociation
#               participants(first: 100) {
#                 totalCount
#                 nodes {
#                   login
#                   company
#                 }
#               }
#               comments(first: 100) {
#                 totalCount
#                 nodes {
#                   author {
#                     login
#                   }
#                   authorAssociation
#                   createdAt
#                   bodyText
#                   reactions(first:20) {
#                     totalCount
#                     nodes {
#                       content
#                     }
#                   }
#                 }
#               }
#               reactions(first:100) {
#                 totalCount
#                 nodes {
#                   content
#                 }
#               }
#               labels(first: 100) {
#                 nodes {
#                   name
#                 }
#               }
#               milestone {
#                 id
#                 title
#                 description
#                 createdAt
#                 dueOn
#                 number
#                 closed
#
#
#               }
#             }
#           }
#         }
#       }
#     }
#
# |-- [2019-07-02 23:33:12.178117] page#12" *****
# * Remaining RateLimit:  4792
# |-- [2019-07-02 23:35:21.932045] page#13" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# Query failed to run by returning code of 502.
#     {
#       rateLimit {
#         cost
#         remaining
#         resetAt
#       }
#       repository(owner: facebook, name: jest) {
#         issues(first: 100 , after:"Y3Vyc29yOnYyOpHOC5sFuQ==",) {
#           totalCount
#           pageInfo {
#             hasNextPage
#             startCursor
#             endCursor
#           }
#           edges {
#             node {
#               repository {
#                 nameWithOwner
#               }
#               number
#               url
#               title
#               bodyText
#               createdAt
#               updatedAt
#               closedAt
#               state
#               closed
#               locked
#               activeLockReason
#               author {
#                 login
#
#               }
#               authorAssociation
#               participants(first: 100) {
#                 totalCount
#                 nodes {
#                   login
#                   company
#                 }
#               }
#               comments(first: 100) {
#                 totalCount
#                 nodes {
#                   author {
#                     login
#                   }
#                   authorAssociation
#                   createdAt
#                   bodyText
#                   reactions(first:20) {
#                     totalCount
#                     nodes {
#                       content
#                     }
#                   }
#                 }
#               }
#               reactions(first:100) {
#                 totalCount
#                 nodes {
#                   content
#                 }
#               }
#               labels(first: 100) {
#                 nodes {
#                   name
#                 }
#               }
#               milestone {
#                 id
#                 title
#                 description
#                 createdAt
#                 dueOn
#                 number
#                 closed
#
#
#               }
#             }
#           }
#         }
#       }
#     }
#
# |-- [2019-07-02 23:37:32.196381] page#13" *****
# * Remaining RateLimit:  4792
# |-- [2019-07-02 23:39:42.033648] page#14" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# Query failed to run by returning code of 502.
#     {
#       rateLimit {
#         cost
#         remaining
#         resetAt
#       }
#       repository(owner: facebook, name: jest) {
#         issues(first: 100 , after:"Y3Vyc29yOnYyOpHOC8-bvw==",) {
#           totalCount
#           pageInfo {
#             hasNextPage
#             startCursor
#             endCursor
#           }
#           edges {
#             node {
#               repository {
#                 nameWithOwner
#               }
#               number
#               url
#               title
#               bodyText
#               createdAt
#               updatedAt
#               closedAt
#               state
#               closed
#               locked
#               activeLockReason
#               author {
#                 login
#
#               }
#               authorAssociation
#               participants(first: 100) {
# ...
# |-- [2019-07-03 04:19:20.292806] page#22" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# Query failed to run by returning code of 502.
#     {
#       rateLimit {
#         cost
#         remaining
#         resetAt
#       }
#       repository(owner: GoogleChrome, name: puppeteer) {
#         issues(first: 100 , after:"Y3Vyc29yOnYyOpHOFWRWsQ==",) {
#           totalCount
#           pageInfo {
#             hasNextPage
#             startCursor
#             endCursor
#           }
#           edges {
#             node {
#               repository {
#                 nameWithOwner
#               }
#               number
#               url
#               title
#               bodyText
#               createdAt
#               updatedAt
#               closedAt
#               state
#               closed
#               locked
#               activeLockReason
#               author {
#                 login
#
#               }
#               authorAssociation
#               participants(first: 100) {
#                 totalCount
#                 nodes {
#                   login
#                   company
#                 }
#               }
#               comments(first: 100) {
#                 totalCount
#                 nodes {
#                   author {
#                     login
#                   }
#                   authorAssociation
#                   createdAt
#                   bodyText
#                   reactions(first:20) {
#                     totalCount
#                     nodes {
#                       content
#                     }
#                   }
#                 }
#               }
#               reactions(first:100) {
#                 totalCount
#                 nodes {
#                   content
#                 }
#               }
#               labels(first: 100) {
#                 nodes {
#                   name
#                 }
#               }
#               milestone {
#                 id
#                 title
#                 description
#                 createdAt
#                 dueOn
#                 number
#                 closed
#
#
#               }
#             }
#           }
#         }
#       }
#     }
#
# |-- [2019-07-03 04:21:30.625354] page#22" *****
# * Remaining RateLimit:  4896
# |-- [2019-07-03 04:23:43.502221] page#23" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# Query failed to run by returning code of 502.
#     {
#       rateLimit {
#         cost
#         remaining
#         resetAt
#       }
#       repository(owner: GoogleChrome, name: puppeteer) {
#         issues(first: 100 , after:"Y3Vyc29yOnYyOpHOFesEpg==",) {
#           totalCount
#           pageInfo {
#             hasNextPage
#             startCursor
#             endCursor
#           }
#           edges {
#             node {
#               repository {
#                 nameWithOwner
#               }
#               number
#               url
#               title
#               bodyText
#               createdAt
#               updatedAt
#               closedAt
#               state
#               closed
#               locked
#               activeLockReason
#               author {
#                 login
#
#               }
#               authorAssociation
#               participants(first: 100) {
#                 totalCount
#                 nodes {
#                   login
#                   company
#                 }
#               }
#               comments(first: 100) {
#                 totalCount
#                 nodes {
#                   author {
#                     login
#                   }
#                   authorAssociation
#                   createdAt
#                   bodyText
#                   reactions(first:20) {
#                     totalCount
#                     nodes {
#                       content
#                     }
#                   }
#                 }
#               }
#               reactions(first:100) {
#                 totalCount
#                 nodes {
#                   content
#                 }
#               }
#               labels(first: 100) {
#                 nodes {
#                   name
#                 }
#               }
#               milestone {
#                 id
#                 title
#                 description
#                 createdAt
#                 dueOn
#                 number
#                 closed
#
#
#               }
#             }
#           }
#         }
#       }
#     }
#
# |-- [2019-07-03 04:25:53.926172] page#23" *****
# * Remaining RateLimit:  4896
# |-- [2019-07-03 04:28:01.733353] page#24" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# Query failed to run by returning code of 502.
#     {
#       rateLimit {
#         cost
#         remaining
#         resetAt
#       }
#       repository(owner: GoogleChrome, name: puppeteer) {
#         issues(first: 100 , after:"Y3Vyc29yOnYyOpHOFoXzgA==",) {
#           totalCount
#           pageInfo {
#             hasNextPage
#             startCursor
#             endCursor
#           }
#           edges {
#             node {
#               repository {
#                 nameWithOwner
#               }
#               number
#               url
#               title
#               bodyText
#               createdAt
#               updatedAt
#               closedAt
#               state
#               closed
#               locked
#               activeLockReason
#               author {
#                 login
#
#               }
#               authorAssociation
#               participants(first: 100) {
#                 totalCount
#                 nodes {
#                   login
#                   company
#                 }
#               }
#               comments(first: 100) {
#                 totalCount
#                 nodes {
#                   author {
#                     login
#                   }
#                   authorAssociation
#                   createdAt
#                   bodyText
#                   reactions(first:20) {
#                     totalCount
#                     nodes {
#                       content
#                     }
#                   }
#                 }
#               }
#               reactions(first:100) {
#                 totalCount
#                 nodes {
#                   content
#                 }
#               }
#               labels(first: 100) {
#                 nodes {
#                   name
#                 }
#               }
#               milestone {
#                 id
#                 title
#                 description
#                 createdAt
#                 dueOn
#                 number
#                 closed
#
#
#               }
#             }
#           }
#         }
#       }
#     }
# |-- [2019-07-03 04:30:12.076995] page#24" *****
# * Remaining RateLimit:  4896
# |-- [2019-07-03 04:32:19.157828] page#25" *****
# * Remaining RateLimit:  4792
# |-- [2019-07-03 04:34:29.095983] page#26" *****
# * Remaining RateLimit:  4896
# |-- [2019-07-03 04:36:34.593853] page#27" *****
# * Remaining RateLimit:  4792
# |-- [2019-07-03 04:38:43.879187] page#28" *****
# * Remaining RateLimit:  4896
# |-- [2019-07-03 04:40:53.552087] page#29" *****
# * Remaining RateLimit:  4792
# |-- [2019-07-03 04:43:01.617668] page#30" *****
# * Remaining RateLimit:  4896
# |-- [2019-07-03 04:45:08.468059] page#31" *****
# * Remaining RateLimit:  4792
# ***** [2019-07-03 04:47:11.236851] START repo#5-cypress-io/cypress" *****
# |-- [2019-07-03 04:47:11.239125] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 04:49:11.470712] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 04:51:11.716336] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 04:53:11.922446] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 04:55:12.175810] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 04:57:12.389888] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 04:59:12.633624] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:01:13.010083] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:03:13.216040] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:05:13.445508] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:07:13.662295] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:09:13.878337] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:11:14.080160] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:13:14.914371] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:15:15.141685] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:17:15.468435] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:19:15.694924] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:21:15.953531] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:23:16.756424] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:25:17.011197] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:27:17.292172] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:29:17.519853] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:31:17.754131] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:33:17.947274] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:35:18.177052] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:37:18.362522] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:39:18.593601] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:41:18.848610] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:43:19.060574] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:45:19.288860] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:47:19.490340] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:49:19.653625] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:51:19.903782] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:53:20.301967] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:55:20.522544] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:57:20.745656] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 05:59:20.918338] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 06:01:21.181395] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 06:03:21.431960] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 06:05:21.646538] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 06:07:21.873378] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 06:09:22.087342] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 06:11:22.293727] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 06:13:22.534026] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 06:15:22.710612] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 06:17:23.000857] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 06:19:23.238404] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 06:21:23.452878] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 06:23:23.667016] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 06:25:23.880593] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 06:27:24.107311] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 06:29:24.367851] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 06:31:24.545275] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 06:33:24.790819] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 06:35:25.009629] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 06:37:25.211679] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 06:39:25.429065] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 06:41:25.652663] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 06:43:25.897371] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 06:45:26.132627] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# |-- [2019-07-03 06:47:26.326320] page#1" *****
# There are errors when retrieving data - Retry the same query again if this happens!
# 'data'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-609-1f0732d4c071> in <module>
#      49
#      50             # Slow down the requests
# ---> 51             time.sleep(120)
#      52
#      53         dict_status[cur_repo]['total_queried_pages'] = cnt_nextPage
#
# KeyboardInterrupt:

# %%
result
# Out:
# {'data': {'rateLimit': {'cost': 3, 'remaining': 4936, 'resetAt': '2019-07-02T23:11:51Z'}, 'search': {'issueCount': 1186, 'pageInfo': {'hasNextPage': False, 'endCursor': 'Y3Vyc29yOjEwMDA='}, 'edges': [{'node': {'number': 495, 'url': 'https://github.com/jasmine/jasmine/issues/495', 'title': 'Feature Request: Collapsable Suites/Describes', 'bodyText': "With 100's or 1000's of tests it is not fun to scroll through them all to find tests.\nWould be easy to have a collapsable set of list items for the specs, by suite.\nWould love to see this added.", 'createdAt': '2014-01-08T07:12:24Z', 'updatedAt': '2014-01-08T23:34:04Z', 'closedAt': '2014-01-08T19:42:45Z', 'state': 'CLOSED', 'closed': True, 'locked': False, 'activeLockReason': None, 'author': {'login': 'johnpapa'}, 'authorAssociation': 'NONE', 'participants': {'totalCount': 2, 'nodes': [{'login': 'johnpapa', 'company': 'JohnPapa.net, LLC'}, {'login': 'infews', 'company': 'Infews LLC & Pivotal Labs'}]}, 'comments': {'totalCount': 3, 'nodes': [{'author': {'login': 'infews'}, 'authorAssociation': 'CONTRIBUTOR', 'createdAt': '2014-01-08T19:42:45Z', 'bodyText': "This feature would be in the HtmlReporter object.\nFeel free to test-drive these features into that object. Please follow the Contributor's guide and maintain compatibility with at least IE8 and we'll take a look at your pull request.\nThanks for the suggestion!"}, {'author': {'login': 'johnpapa'}, 'authorAssociation': 'NONE', 'createdAt': '2014-01-08T20:41:58Z', 'bodyText': 'So is this not anywhere on your roadmap?\nI get the "please contribute", I often do. But it would be nice to know what the roadmap looks like instead of just closing it'}, {'author': {'login': 'infews'}, 'authorAssociation': 'CONTRIBUTOR', 'createdAt': '2014-01-08T23:34:04Z', 'bodyText': '@johnpapa our backlog is public at Pivotal Tracker. The backlog is a little light, but the Icebox does have all of our thinking (just not prioritized).'}]}, 'labels': {'nodes': []}}}, {'node': {'number': 494, 'url': 'https://github.com/jasmine/jasmine/issues/494', 'title': 'version 2.0 document error', 'bodyText': 'Following is the description provided for spy and.throwError in the document.\nBy chaining the spy with and.callThrow, all calls to the spy will throw the specified value.\nIs and.callThrow a document error?', 'createdAt': '2014-01-06T10:55:25Z', 'updatedAt': '2014-01-06T15:55:27Z', 'closedAt': '2014-01-06T15:52:51Z', 'state': 'CLOSED', 'closed': True, 'locked': False, 'activeLockReason': None, 'author': {'login': 'smarigowda'}, 'authorAssociation': 'NONE', 'participants': {'totalCount': 2, 'nodes': [{'login': 'smarigowda', 'company': None}, {'login': 'sheelc', 'company': 'Mayvenn'}]}, 'comments': {'totalCount': 1, 'nodes': [{'author': {'login': 'sheelc'}, 'authorAssociation': 'CONTRIBUTOR', 'createdAt': '2014-01-06T15:52:51Z', 'bodyText': 'Yes, this was a documentation error. I just fixed it. We were considering and.callThrow for a while before deciding to go with and.ThrowError for 2.0 since it read better.\nThanks!'}]}, 'labels': {'nodes': []}}}, {'node': {'number': 493, 'url': 'https://github.com/jasmine/jasmine/issues/493', 'title': 'Jasmine for ExtendScript', 'bodyText': "I've tried to port Jasmine for ExtendScript using the standalone zip file. I have already fixed the errors on that environment which is basically the window object changed to $.global. However I can't get the output displayed on the console. The file console.js doesn't seem to be used. Was this the one responsible for printing the results?\nAlso, is there already an implementation for ExtendScript?", 'createdAt': '2014-01-06T06:25:15Z', 'updatedAt': '2015-04-15T17:53:18Z', 'closedAt': '2014-01-07T16:28:02Z', 'state': 'CLOSED', 'closed': True, 'locked': False, 'activeLockReason': None, 'author': {'login': 'madevelopers'}, 'authorAssociation': 'NONE', 'participants': {'totalCount': 5, 'nodes': [{'login': 'madevelopers', 'company': None}, {'login': 'sheelc', 'company': 'Mayvenn'}, {'login': ...

# %%
last_issue = result['data']['search']['edges'][-1]['node']

# %%
dict_status
# Out:
# {'qunitjs/qunit': {'issueCount': 704, 'total_queried_pages': 15}, 'mochajs/mocha': {'issueCount': 2334, 'total_queried_pages': 20}, 'facebook/jest': {'issueCount': 4513, 'total_queried_pages': 20}, 'jasmine/jasmine': {'issueCount': 1186, 'total_queried_pages': 20}, 'bitovi/funcunit': {'issueCount': 152, 'total_queried_pages': 4}, 'GoogleChrome/puppeteer': {'issueCount': 3058, 'total_queried_pages': 20}, 'cypress-io/cypress': {'issueCount': 3520, 'total_queried_pages': 20}}

# %%
result
# Out:
# {'data': {'rateLimit': {'cost': 104, 'remaining': 4581, 'resetAt': '2019-07-03T00:23:18Z'}, 'repository': {'issues': {'totalCount': 708, 'pageInfo': {'hasNextPage': True, 'startCursor': 'Y3Vyc29yOnYyOpHN-sg=', 'endCursor': 'Y3Vyc29yOnYyOpHOABV1Aw=='}, 'edges': [{'node': {'repository': {'nameWithOwner': 'qunitjs/qunit'}, 'number': 1, 'url': 'https://github.com/qunitjs/qunit/issues/1', 'title': 'noglobals GET parameter ignored', 'bodyText': 'QUnit.init overrides the config var, resetting the noglobals config to false. Since the noglobals get parameter is read before QUnit.init, the noglobals parameter is ignored.', 'createdAt': '2009-10-02T14:16:41Z', 'updatedAt': '2014-05-31T10:55:47Z', 'closedAt': '2009-11-05T13:16:45Z', 'state': 'CLOSED', 'closed': True, 'locked': False, 'activeLockReason': None, 'author': {'login': 'kassens'}, 'authorAssociation': 'CONTRIBUTOR', 'participants': {'totalCount': 2, 'nodes': [{'login': 'kassens', 'company': 'Facebook'}, {'login': 'jeresig', 'company': '@Khan '}]}, 'comments': {'totalCount': 1, 'nodes': [{'author': {'login': 'jeresig'}, 'authorAssociation': 'CONTRIBUTOR', 'createdAt': '2009-11-05T13:16:44Z', 'bodyText': "This shouldn't be the case any more - please let me know if it's still a problem, though.", 'reactions': {'totalCount': 0, 'nodes': []}}]}, 'reactions': {'totalCount': 0, 'nodes': []}, 'labels': {'nodes': []}, 'milestone': None}}, {'node': {'repository': {'nameWithOwner': 'qunitjs/qunit'}, 'number': 2, 'url': 'https://github.com/qunitjs/qunit/issues/2', 'title': 'Test Suite URL Params need their own query string', 'bodyText': 'If you use qunit with testswarm it fails to run tests because testswarm adds url params to the tests. So instead of just looking for /test?this is a test, it should be something like /test?t=this is a test', 'createdAt': '2009-10-12T14:41:46Z', 'updatedAt': '2014-05-31T10:55:47Z', 'closedAt': '2009-11-05T13:09:47Z', 'state': 'CLOSED', 'closed': True, 'locked': False, 'activeLockReason': None, 'author': {'login': 'RyanS'}, 'authorAssociation': 'CONTRIBUTOR', 'participants': {'totalCount': 2, 'nodes': [{'login': 'RyanS', 'company': None}, {'login': 'jeresig', 'company': '@Khan '}]}, 'comments': {'totalCount': 2, 'nodes': [{'author': {'login': 'RyanS'}, 'authorAssociation': 'CONTRIBUTOR', 'createdAt': '2009-10-12T15:32:23Z', 'bodyText': 'nm, it expects the first param to be the test. Guess I just need to modify the task that adds the testswarm test ;)', 'reactions': {'totalCount': 0, 'nodes': []}}, {'author': {'login': 'jeresig'}, 'authorAssociation': 'CONTRIBUTOR', 'createdAt': '2009-11-05T13:09:46Z', 'bodyText': 'I merged in your tweak.', 'reactions': {'totalCount': 0, 'nodes': []}}]}, 'reactions': {'totalCount': 0, 'nodes': []}, 'labels': {'nodes': []}, 'milestone': None}}, {'node': {'repository': {'nameWithOwner': 'qunitjs/qunit'}, 'number': 3, 'url': 'https://github.com/qunitjs/qunit/issues/3', 'title': 'module name is not shown', 'bodyText': 'When modules are defined, their names do not appear (for me) next to the test names in the output.\nThe config object is defined on line 353, and config is assigned to in QUnit.init. config.currentModule is set in the module function and accessed in the test function. It looks like a different config object is being referenced in each of the different functions.', 'createdAt': '2009-10-25T03:48:40Z', 'updatedAt': '2009-11-05T13:08:48Z', 'closedAt': '2009-11-05T13:08:48Z', 'state': 'CLOSED', 'closed': True, 'locked': False, 'activeLockReason': None, 'author': {'login': 'smith'}, 'authorAssociation': 'NONE', 'participants': {'totalCount': 3, 'nodes': [{'login': 'smith', 'company': '@newrelic'}, {'login': 'zhaoz', 'company': None}, {'login': 'jeresig', 'company': '@Khan '}]}, 'comments': {'totalCount': 3, 'nodes': [{'author': {'login': 'zhaoz'}, 'authorAssociation': 'NONE', 'createdAt': '2009-10-29T20:52:03Z', 'bodyText': 'This commit seems to have fixed the issue, although it is untested with asyncTest stuff (which is ...

# %%
result['data']['repository']['issues']['edges']
# Out:
# [{'node': {'repository': {'nameWithOwner': 'qunitjs/qunit'}, 'number': 1, 'url': 'https://github.com/qunitjs/qunit/issues/1', 'title': 'noglobals GET parameter ignored', 'bodyText': 'QUnit.init overrides the config var, resetting the noglobals config to false. Since the noglobals get parameter is read before QUnit.init, the noglobals parameter is ignored.', 'createdAt': '2009-10-02T14:16:41Z', 'updatedAt': '2014-05-31T10:55:47Z', 'closedAt': '2009-11-05T13:16:45Z', 'state': 'CLOSED', 'closed': True, 'locked': False, 'activeLockReason': None, 'author': {'login': 'kassens'}, 'authorAssociation': 'CONTRIBUTOR', 'participants': {'totalCount': 2, 'nodes': [{'login': 'kassens', 'company': 'Facebook'}, {'login': 'jeresig', 'company': '@Khan '}]}, 'comments': {'totalCount': 1, 'nodes': [{'author': {'login': 'jeresig'}, 'authorAssociation': 'CONTRIBUTOR', 'createdAt': '2009-11-05T13:16:44Z', 'bodyText': "This shouldn't be the case any more - please let me know if it's still a problem, though.", 'reactions': {'totalCount': 0, 'nodes': []}}]}, 'reactions': {'totalCount': 0, 'nodes': []}, 'labels': {'nodes': []}, 'milestone': None}}, {'node': {'repository': {'nameWithOwner': 'qunitjs/qunit'}, 'number': 2, 'url': 'https://github.com/qunitjs/qunit/issues/2', 'title': 'Test Suite URL Params need their own query string', 'bodyText': 'If you use qunit with testswarm it fails to run tests because testswarm adds url params to the tests. So instead of just looking for /test?this is a test, it should be something like /test?t=this is a test', 'createdAt': '2009-10-12T14:41:46Z', 'updatedAt': '2014-05-31T10:55:47Z', 'closedAt': '2009-11-05T13:09:47Z', 'state': 'CLOSED', 'closed': True, 'locked': False, 'activeLockReason': None, 'author': {'login': 'RyanS'}, 'authorAssociation': 'CONTRIBUTOR', 'participants': {'totalCount': 2, 'nodes': [{'login': 'RyanS', 'company': None}, {'login': 'jeresig', 'company': '@Khan '}]}, 'comments': {'totalCount': 2, 'nodes': [{'author': {'login': 'RyanS'}, 'authorAssociation': 'CONTRIBUTOR', 'createdAt': '2009-10-12T15:32:23Z', 'bodyText': 'nm, it expects the first param to be the test. Guess I just need to modify the task that adds the testswarm test ;)', 'reactions': {'totalCount': 0, 'nodes': []}}, {'author': {'login': 'jeresig'}, 'authorAssociation': 'CONTRIBUTOR', 'createdAt': '2009-11-05T13:09:46Z', 'bodyText': 'I merged in your tweak.', 'reactions': {'totalCount': 0, 'nodes': []}}]}, 'reactions': {'totalCount': 0, 'nodes': []}, 'labels': {'nodes': []}, 'milestone': None}}, {'node': {'repository': {'nameWithOwner': 'qunitjs/qunit'}, 'number': 3, 'url': 'https://github.com/qunitjs/qunit/issues/3', 'title': 'module name is not shown', 'bodyText': 'When modules are defined, their names do not appear (for me) next to the test names in the output.\nThe config object is defined on line 353, and config is assigned to in QUnit.init. config.currentModule is set in the module function and accessed in the test function. It looks like a different config object is being referenced in each of the different functions.', 'createdAt': '2009-10-25T03:48:40Z', 'updatedAt': '2009-11-05T13:08:48Z', 'closedAt': '2009-11-05T13:08:48Z', 'state': 'CLOSED', 'closed': True, 'locked': False, 'activeLockReason': None, 'author': {'login': 'smith'}, 'authorAssociation': 'NONE', 'participants': {'totalCount': 3, 'nodes': [{'login': 'smith', 'company': '@newrelic'}, {'login': 'zhaoz', 'company': None}, {'login': 'jeresig', 'company': '@Khan '}]}, 'comments': {'totalCount': 3, 'nodes': [{'author': {'login': 'zhaoz'}, 'authorAssociation': 'NONE', 'createdAt': '2009-10-29T20:52:03Z', 'bodyText': 'This commit seems to have fixed the issue, although it is untested with asyncTest stuff (which is when this issue was introduced).\nhttp://github.com/zhaoz/qunit/commit/13eec8f1e6dbbde59aa07ee74dd25ca03ba80e87', 'reactions': {'totalCount': 0, 'nodes': []}}, {'author': {'login': 'smith'}, 'authorAssociation': 'NONE', 'createdAt': '2009-10-29T21:00:41Z', 'bo ...

# %%
list_repos = [
#     "qunitjs/qunit",
#     "mochajs/mocha",
#     "facebook/jest",
#     "jasmine/jasmine",
#     "bitovi/funcunit",
#     "GoogleChrome/puppeteer",
    "cypress-io/cypress"
]

# %%
for cur_idx, cur_repo in enumerate(list_repos):
    
    print('***** [{}] START cleaning data for repo#{}-{}" *****'.format(str(datetime.datetime.now()), cur_idx, cur_repo))
    
    name_repo = cur_repo.split('/')[1]
    raw_data_file_cur_repo = get_raw_data_file(name_repo)
    
    with open(raw_data_file_cur_repo) as f:
        raw_content = f.readlines()
        
    out_json_name_raw = 'temp/github_repo_issues_raw{}.json'.format(name_repo)
    
    # Remove whitespace characters like `\n` at the end of each line
    all_content = [x.strip() for x in raw_content] 

    # Assemble json
    all_json_str = ','.join(all_content)
    out_json_str = '[{}]'.format(all_json_str)


    with open(out_json_name_raw, 'w') as f:  
        f.write(out_json_str)
        
    with open(out_json_name_raw) as json_file:  
        data_repo = json.load(json_file)
        
    clean_data = []

    for cur_data in data_repo:
        new_data = OrderedDict() 

        cur_url = cur_data['url']
        new_data['repo_name'] = cur_data['repository']['nameWithOwner']
        new_data['issue_id'] = cur_data['number']
        new_data['url'] = cur_url
        new_data['title'] = cur_data['title']
        new_data['contents'] = cur_data['bodyText']
        new_data['createdAt'] = cur_data['createdAt']
        new_data['updatedAt'] = cur_data['updatedAt']
        new_data['closedAt'] = cur_data['closedAt']
        new_data['state'] = cur_data['state']
        new_data['closed'] = cur_data['closed']
        new_data['locked'] = cur_data['locked']
        new_data['activeLockReason'] = cur_data['activeLockReason']

        new_data['authorLogin']= cur_data['author']['login'] if cur_data['author'] else ''
        new_data['authorAssociation'] = cur_data['authorAssociation']

        new_data['participants_count'] = cur_data['participants']['totalCount']
        new_data['participants_data'] = cur_data['participants']['nodes']

        new_data['comments_count'] = cur_data['comments']['totalCount']

        cur_all_comments = cur_data['comments']['nodes']
        cur_data_comments = []
        for cur_comment in cur_all_comments:
            new_comment = OrderedDict() 
            new_comment['authorLogin'] = cur_comment['author']['login'] if cur_comment['author'] else ''
            new_comment['authorAssociation'] = cur_comment['authorAssociation']
            new_comment['createdAt'] = cur_comment['createdAt']
            new_comment['contents'] = cur_comment['bodyText']
            
            new_comment['reactions_count'] = cur_comment['reactions']['totalCount']
            new_comment['reactions_data'] = [x['content'] for x in cur_comment['reactions']['nodes']]
            
            cur_data_comments.append(new_comment)


        new_data['comments_data'] = cur_data_comments
        
        
        new_data['reactions_count'] = cur_data['reactions']['totalCount']
        new_data['reactions_data'] = [x['content'] for x in cur_data['reactions']['nodes']]

        new_data['labels'] = [x['name'] for x in cur_data['labels']['nodes']]
        
        new_data['milestone'] = cur_data['milestone']

        clean_data.append(new_data)
        
    out_json_name_clean = 'temp/github_repo_issues_{}.json'.format(name_repo)
    with open(out_json_name_clean, 'w') as fp:
        json.dump(clean_data, fp)
# Out:
# ***** [2019-07-03 06:51:46.915433] START cleaning data for repo#0-mochajs/mocha" *****
# ***** [2019-07-03 06:51:47.643066] START cleaning data for repo#1-facebook/jest" *****
# ***** [2019-07-03 06:51:48.954500] START cleaning data for repo#2-jasmine/jasmine" *****
# ***** [2019-07-03 06:51:49.366246] START cleaning data for repo#3-bitovi/funcunit" *****
# ***** [2019-07-03 06:51:49.402447] START cleaning data for repo#4-GoogleChrome/puppeteer" *****

# %%
# with open(raw_data_file) as f:
#     raw_content = f.readlines()

# %%
# out_json_name_raw = 'temp/github_repo_issues_raw.json'

# %%
# # Remove whitespace characters like `\n` at the end of each line
# all_content = [x.strip() for x in raw_content] 

# # Assemble json
# all_json_str = ','.join(all_content)
# out_json_str = '[{}]'.format(all_json_str)


# with open(out_json_name_raw, 'w') as f:  
#     f.write(out_json_str)

# %%
# with open(out_json_name_raw) as json_file:  
#     data_repo = json.load(json_file)

# %%
# clean_data = []

# for cur_data in data_repo:
#     new_data = OrderedDict() 

#     cur_url = cur_data['url']
#     new_data['repo_name'] = re.findall(r'https:\/\/github.com\/(.*)\/issues/\d', cur_url)[0]
#     new_data['issue_id'] = cur_data['number']
#     new_data['url'] = cur_url
#     new_data['title'] = cur_data['title']
#     new_data['contents'] = cur_url['bodyText']
#     new_data['createdAt'] = cur_data['createdAt']
#     new_data['updatedAt'] = cur_data['updatedAt']
#     new_data['closedAt'] = cur_data['closedAt']
#     new_data['state'] = cur_data['state']
#     new_data['closed'] = cur_data['closed']
#     new_data['locked'] = cur_data['locked']
#     new_data['activeLockReason'] = cur_data['activeLockReason']

#     new_data['authorLogin']= cur_data['author']['login'] if cur_data['author'] else ''
#     new_data['authorAssociation'] = cur_data['authorAssociation']

#     new_data['participants_count'] = cur_data['participants']['totalCount']
#     new_data['participants_data'] = cur_data['participants']['nodes']

#     new_data['comments_count'] = cur_data['comments']['totalCount']

#     cur_all_comments = cur_data['comments']['nodes']
#     cur_data_comments = []
#     for cur_comment in cur_all_comments:
#         new_comment = OrderedDict() 
#         new_comment['authorLogin'] = cur_comment['author']['login'] if cur_comment['author'] else ''
#         new_comment['authorAssociation'] = cur_comment['authorAssociation']
#         new_comment['createdAt'] = cur_comment['createdAt']
#         new_comment['contents'] = cur_comment['bodyText']
#         cur_data_comments.append(new_comment)


#     new_data['comments_data'] = cur_data_comments

#     new_data['labels'] = [x['name'] for x in cur_data['labels']['nodes']]
    
#     clean_data.append(new_data)

# %%
len(clean_data)
# Out:
# 1000

# %%
clean_data[3]
# Out:
# OrderedDict([('repo_name', 'cypress-io/cypress'), ('issue_id', 4630), ('url', 'https://github.com/cypress-io/cypress/issues/4630'), ('title', 'Your framework is f*cking bullsh*t'), ('contents', "It is impossible to configure your f*cking moronic framework to work with TypeScript and Webpack when project is bigger than hello f*cking world example you have. I spent all day tweaking different options and had no success. I'm f*cking done. F*ck you and your stupid framework."), ('createdAt', '2019-07-02T07:31:29Z'), ('updatedAt', '2019-07-02T08:15:11Z'), ('closedAt', '2019-07-02T08:05:30Z'), ('state', 'CLOSED'), ('closed', True), ('locked', False), ('activeLockReason', None), ('authorLogin', 'alexeychikk'), ('authorAssociation', 'NONE'), ('participants_count', 2), ('participants_data', [{'login': 'alexeychikk', 'company': None}, {'login': 'jennifer-shehane', 'company': '@cypress-io '}]), ('comments_count', 2), ('comments_data', [OrderedDict([('authorLogin', 'jennifer-shehane'), ('authorAssociation', 'MEMBER'), ('createdAt', '2019-07-02T08:05:30Z'), ('contents', "Hey @alexeychikk, sorry to hear about the frustrating experience you're obviously having 😞\nWe have a community chat that can be helpful for debugging these types of things.\nWe also have an issue open to improve our documentation with TypeScript + Webpack specifically - so it seems your not alone here. cypress-io/code-coverage#19\nAnd if you think you're encountering some sort of bug on our end, we can look at that if you can post it.\nAlso, as a reminder, our GitHub repo falls under our Code of Conduct which encourages maintaining a positive environment here.")]), OrderedDict([('authorLogin', 'alexeychikk'), ('authorAssociation', 'NONE'), ('createdAt', '2019-07-02T08:15:11Z'), ('contents', "@jennifer-shehane  Well, I'm really sorry. It's open source in the end. I've just had a really bad experience using cypress and gone mad.")])]), ('labels', [])])

# %%
# out_json_name_clean = 'temp/github_repo_issues_2019_July_1.json'

# %%
# with open(out_json_name_clean, 'w') as fp:
#     json.dump(clean_data, fp)

# %%
out_json_name_clean
# Out:
# 'temp/github_repo_issues_puppeteer.json'

# %%
with open(out_json_name_clean) as json_file:  
    data_new = json.load(json_file)

# %%
len(data_new)
# Out:
# 3067

# %%
data_new[707]
# Out:
# {'repo_name': 'GoogleChrome/puppeteer', 'issue_id': 1190, 'url': 'https://github.com/GoogleChrome/puppeteer/issues/1190', 'title': 'Error: Protocol error (Runtime.callFunctionOn): Invalid parameters objectId: string value expected', 'contents': 'I am using "puppeteer": "^0.12.0"\nTrying to\n    const browser = await puppeteer.launch({"executablePath": "/usr/bin/chromium-browser", args: [\'--no-sandbox\', \'--disable-setuid-sandbox\']});\n\n    const page = await browser.newPage();\n    await page.goto(ADMIN_URL);\n\n    await page.click("#input-username");\n\nI get error :\n(node:27918) UnhandledPromiseRejectionWarning: Unhandled promise rejection (rejection id: 1): Error: Protocol error (Runtime.callFunctionOn): Invalid parameters objectId: string value expected\n(node:27918) [DEP0018] DeprecationWarning: Unhandled promise rejections are deprecated. In the future, promise rejections that are not handled will terminate the Node.js process with a non-zero exit code.\n\nChrome version:\n$ apt-cache policy chromium-browser\nchromium-browser:\n  Installed: 62.0.3202.62-0ubuntu0.14.04.1204\n\n$ whereis chromium-browser\nchromium-browser: /usr/bin/chromium-browser /usr/lib/chromium-browser /etc/chromium-browser /usr/share/chromium-browser /usr/share/man/man1/chromium-browser.1.gz', 'createdAt': '2017-10-27T17:38:54Z', 'updatedAt': '2017-11-01T13:43:07Z', 'closedAt': '2017-10-31T18:30:09Z', 'state': 'CLOSED', 'closed': True, 'locked': False, 'activeLockReason': None, 'authorLogin': 'redochka', 'authorAssociation': 'NONE', 'participants_count': 5, 'participants_data': [{'login': 'redochka', 'company': None}, {'login': 'raphi011', 'company': None}, {'login': 'darioalessandro', 'company': 'Deepfield'}, {'login': 'aslushnikov', 'company': '@Google'}, {'login': 'mrbar42', 'company': None}], 'comments_count': 7, 'comments_data': [{'authorLogin': 'raphi011', 'authorAssociation': 'NONE', 'createdAt': '2017-10-31T11:20:53Z', 'contents': 'I have the same error, any ideas?', 'reactions_count': 1, 'reactions_data': ['THUMBS_UP']}, {'authorLogin': 'darioalessandro', 'authorAssociation': 'NONE', 'createdAt': '2017-10-31T15:23:27Z', 'contents': 'Same thing here:\n\n\n\nK\nV\n\n\n\n\nGoogle Chrome\n62.0.3202.75\xa0(Official Build)\xa0(64-bit)\n\n\nRevision\n67b212ffb03c4401235f8961e2d15371b96cde27-refs/branch-heads/3202@{#750}\n\n\nOS\nMac OS X\n\n\nJavaScript\nV8\xa06.2.414.36\n\n\nFlash\n27.0.0.183 /Users/darioalessandro/Library/Application\n\n\nUser Agent\nMozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.75 Safari/537.36\n\n\nCommand Line\n/Applications/Google Chrome.app/Contents/MacOS/Google Chrome -psn_0_10328537 --flag-switches-begin --flag-switches-end\n\n\nExecutable Path\n/Applications/Google Chrome.app/Contents/MacOS/Google Chrome\n\n\nProfile Path\n/Users/darioalessandro/Library/Application Support/Google/Chrome/Default\n\n\n\nSeems like the browser launches and then:\nError: Protocol error (Runtime.callFunctionOn): Invalid parameters objectId: string value expected\n      at Session._onMessage (node_modules/puppeteer/node6/Connection.js:272:25)\n      at Connection.<anonymous> (node_modules/puppeteer/node6/Connection.js:150:19)\n      at undefined.next (native)\n      at step (node_modules/puppeteer/node6/Connection.js:113:24)\n      at Promise (node_modules/puppeteer/node6/Connection.js:131:12)\n      at fn (node_modules/puppeteer/node6/Connection.js:109:10)\n      at Connection._onMessage (node_modules/puppeteer/node6/Connection.js:133:3)\n      at Receiver._receiver.onmessage (node_modules/puppeteer/node_modules/ws/lib/WebSocket.js:143:47)\n      at Receiver.dataMessage (node_modules/puppeteer/node_modules/ws/lib/Receiver.js:389:14)\n      at Receiver.getData (node_modules/puppeteer/node_modules/ws/lib/Receiver.js:330:12)\n      at Receiver.startLoop (node_modules/puppeteer/node_modules/ws/lib/Receiver.js:165:16)\n      at Receiver.add (node_modules/puppeteer/node_modules/ws/lib/R ...

# %%
dict_status
# Out:
# {'qunitjs/qunit': {'issueCount': 704, 'total_queried_pages': 15}, 'mochajs/mocha': {'issueCount': 2334, 'total_queried_pages': 20}, 'facebook/jest': {'issueCount': 4513, 'total_queried_pages': 20}, 'jasmine/jasmine': {'issueCount': 1186, 'total_queried_pages': 20}, 'bitovi/funcunit': {'issueCount': 152, 'total_queried_pages': 4}, 'GoogleChrome/puppeteer': {'issueCount': 3058, 'total_queried_pages': 20}, 'cypress-io/cypress': {'issueCount': 3520, 'total_queried_pages': 20}}

# %%
url = "https://api.github.com/repos/jasmine/jasmine/issues?state=all&q=is:issue&page=17&per_page=100"
# url = "https://api.github.com/search/issues?q=repo:jasmine/jasmine+is:issue&page=11&per_page=100"
res=requests.get(url,headers=headers)
result=res.json()

# %%
len(result)
# Out:
# 100

# %%
result
# Out:
# [{'url': 'https://api.github.com/repos/jasmine/jasmine/issues/128', 'repository_url': 'https://api.github.com/repos/jasmine/jasmine', 'labels_url': 'https://api.github.com/repos/jasmine/jasmine/issues/128/labels{/name}', 'comments_url': 'https://api.github.com/repos/jasmine/jasmine/issues/128/comments', 'events_url': 'https://api.github.com/repos/jasmine/jasmine/issues/128/events', 'html_url': 'https://github.com/jasmine/jasmine/issues/128', 'id': 1592341, 'node_id': 'MDU6SXNzdWUxNTkyMzQx', 'number': 128, 'title': 'support for .with() modifier for spies', 'user': {'login': 'davidwkeith', 'id': 97965, 'node_id': 'MDQ6VXNlcjk3OTY1', 'avatar_url': 'https://avatars2.githubusercontent.com/u/97965?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/davidwkeith', 'html_url': 'https://github.com/davidwkeith', 'followers_url': 'https://api.github.com/users/davidwkeith/followers', 'following_url': 'https://api.github.com/users/davidwkeith/following{/other_user}', 'gists_url': 'https://api.github.com/users/davidwkeith/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/davidwkeith/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/davidwkeith/subscriptions', 'organizations_url': 'https://api.github.com/users/davidwkeith/orgs', 'repos_url': 'https://api.github.com/users/davidwkeith/repos', 'events_url': 'https://api.github.com/users/davidwkeith/events{/privacy}', 'received_events_url': 'https://api.github.com/users/davidwkeith/received_events', 'type': 'User', 'site_admin': False}, 'labels': [], 'state': 'closed', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 3, 'created_at': '2011-09-07T18:57:52Z', 'updated_at': '2013-05-29T17:06:46Z', 'closed_at': '2013-05-29T17:06:46Z', 'author_association': 'NONE', 'body': "RSpec supports a mocking syntax that allows the developer to define expected parameters, in Jasmine I would expect this to be written as:\n\nspyOn(foo, 'bar').with('bat').andReturn('baz');\nspyOn(foo, 'bar').with('baz').andReturn('bat');\n\nThis allows me to avoid writing a andCallFake() with a switch statement in it for functions that call helper functions multiple times with different parameters.\n\nIt would be an failure if foo.bar() was never called with the expected argument\nIf there was not a spyOn without a with modifier it would be an failure to call the function with any other argument than those specified\n\nThis avoids needing to use .toHaveBeenCalledWith() in many circumstances.\n"}, {'url': 'https://api.github.com/repos/jasmine/jasmine/issues/127', 'repository_url': 'https://api.github.com/repos/jasmine/jasmine', 'labels_url': 'https://api.github.com/repos/jasmine/jasmine/issues/127/labels{/name}', 'comments_url': 'https://api.github.com/repos/jasmine/jasmine/issues/127/comments', 'events_url': 'https://api.github.com/repos/jasmine/jasmine/issues/127/events', 'html_url': 'https://github.com/jasmine/jasmine/issues/127', 'id': 1544033, 'node_id': 'MDU6SXNzdWUxNTQ0MDMz', 'number': 127, 'title': 'TAP output for Jasmine?', 'user': {'login': 'michaelsbradleyjr', 'id': 194260, 'node_id': 'MDQ6VXNlcjE5NDI2MA==', 'avatar_url': 'https://avatars0.githubusercontent.com/u/194260?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/michaelsbradleyjr', 'html_url': 'https://github.com/michaelsbradleyjr', 'followers_url': 'https://api.github.com/users/michaelsbradleyjr/followers', 'following_url': 'https://api.github.com/users/michaelsbradleyjr/following{/other_user}', 'gists_url': 'https://api.github.com/users/michaelsbradleyjr/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/michaelsbradleyjr/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/michaelsbradleyjr/subscriptions', 'organizations_url': 'https://api.github.com/users/michaelsbradleyjr/orgs', 'repos_url': 'https://api.github.com/users/michaelsbradleyjr/repos', 'events_url': 'https://api.github.com/users/michaelsbradleyjr/events{/privacy}', 'recei ...

# %%
len(result['items'])
# Out:
# 100

# %%
result
# Out:
# {'message': 'Only the first 1000 search results are available', 'documentation_url': 'https://developer.github.com/v3/search/'}
